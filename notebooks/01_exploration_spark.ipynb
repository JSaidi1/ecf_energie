# %% [markdown]
# # Etape 1.1 : Exploration initiale
#
# **Livrables** :
# - Notebook `01_exploration_spark.ipynb`
# - Rapport d'audit (format markdown ou DataFrame - `rapport_audit_donnees.md`)
#
# ---
# ---

# %% [markdown]
# ## Imports

# %%
import os
import sys
import platform
from pathlib import Path
import psutil
import time
from datetime import datetime
import asyncio
import sys
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %% [markdown]
# ---

# %% [markdown]
# ## Utils

# %%
# To avoid this warning (asyncio.set_event_loop_policy ...) when executing pipeline
if sys.platform.startswith("win"):
    try:
        asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
    except AttributeError:
        # Fallback for environments where it's not available
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

# %% [markdown]
# ---

# %% [markdown]
# ## Mesure du temps de traitement global pour ce script - enregistrement de l'heure de début + estimation instantanée des ressources machine libres

# %%
## Heure de début
start_time = time.time()

## Machine: current available RAM (in GB)
ram_available_01 = psutil.virtual_memory().available / (1024**3)

## Machine: current available CPU
logical = psutil.cpu_count()
physical = psutil.cpu_count(logical=False) or logical

cpu_used = psutil.cpu_percent(interval=2)
cpu_available_pct_01 = 100 - cpu_used

available_logical_01 = logical * cpu_available_pct_01 / 100
available_physical_01 = physical * cpu_available_pct_01 / 100

## Show available resources
print(f"- Current machine RAM available : {ram_available_01:.2f} GB")
print(f"- Current machine CPU available : {cpu_available_pct_01:.1f}%")
print(f"    Approx logical cores free  : {available_logical_01:.2f}")
print(f"    Approx physical cores free : {available_physical_01:.2f}")
# Out:
# - Current machine RAM available : 13.22 GB
# - Current machine CPU available : 91.9%
#     Approx logical cores free  : 14.70
#     Approx physical cores free : 7.35

# %% [markdown]
# ---

# %% [markdown]
# ## Chemins des données

# %%
# ==============================================================================================================
#                                                    DIRS
# ==============================================================================================================
DATA_DIR_PATH = (Path.cwd() / ".." / "data").resolve()
OUTPUT_DIR_PATH = (Path.cwd() / ".." / "output").resolve()
TMP_DIR_PATH = (Path.cwd() / ".." / "my_tmp").resolve()

## Ensure DATA_DIR_PATH
DATA_DIR_PATH.mkdir(parents=True, exist_ok=True)
## Ensure OUTPUT_DIR_PATH
OUTPUT_DIR_PATH.mkdir(parents=True, exist_ok=True)

# ==============================================================================================================
#                                                  INPUTS
# ==============================================================================================================
#CONSOMMATION_FILE_DATA_PATH = os.path.join(DATA_DIR_PATH, "consommations_raw.csv")
CONSOMMATION_FILE_DATA_PATH = os.path.join(DATA_DIR_PATH, "consommations_raw-light-test.csv")
BATIMENTS_FILE_DATA_PATH = os.path.join(DATA_DIR_PATH, "batiments.csv")

## Check if inputs exists:
if not os.path.exists(CONSOMMATION_FILE_DATA_PATH):
    print("Error: CONSOMMATION_FILE_DATA_PATH does not exist:", CONSOMMATION_FILE_DATA_PATH)
    sys.exit(1)
if not os.path.exists(BATIMENTS_FILE_DATA_PATH):
    print("Error: BATIMENTS_FILE_DATA_PATH does not exist:", BATIMENTS_FILE_DATA_PATH)

# ==============================================================================================================
#                                                OUTPUTS
# ==============================================================================================================
RAPPORT_AUDIT_FILE_DATA_PATH = os.path.join(OUTPUT_DIR_PATH, "01_rapport_audit_donnees.md")

# ==============================================================================================================
#                                                OTHERS
# ==============================================================================================================
TMP_FILE_PATH = TMP_DIR_PATH / "tmp_01_resources.txt" # Enregistrer les metrics pour ce script

# %% [markdown]
# ---

# %% [markdown]
# ## Création d'une session Spark locale

# %%
## Creer une session Spark locale
spark = SparkSession.builder \
    .appName("ECF 2 - ENERGIE - Etape 1.1 : Exploration initiale") \
    .master("local[*]") \
    .config("spark.driver.memory", "4g") \
    .config("spark.sql.shuffle.partitions", "8") \
    .getOrCreate()

## Reduire les logs
spark.sparkContext.setLogLevel("WARN")

## Affichage de l'actuelle version de Spark & de l'url de Spark UI ainsi que python & java
print(f"Spark version  : {spark.version}")
print(f"Spark UI       : {spark.sparkContext.uiWebUrl}")
print()
print(f"Python version : {platform.python_version()}")
print(f"Python path    : { sys.executable}")
print()
print(f"Java version   : {spark._jvm.java.lang.System.getProperty('java.version')}")
print(f"Java home      : { spark._jvm.java.lang.System.getProperty('java.home')}")
# Out:
# Spark version  : 3.5.7
# Spark UI       : http://joel:4041
#
# Python version : 3.11.9
# Python path    : C:\Users\joel\Desktop\ecf_energie\.venv\Scripts\python.exe
#
# Java version   : 11.0.28
# Java home      : C:\Users\joel\data-info\dev-tools\languages\java\jdk-11

# %% [markdown]
# ---

# %% [markdown]
# ## 1.1.1 Chargement des donnees de consommation avec PySpark

# %%
## Chargement du CSV avec inference de schema
df_consommation_raw = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv(CONSOMMATION_FILE_DATA_PATH)

print(f"- Les données de consommation ont été chargées avec succès: {CONSOMMATION_FILE_DATA_PATH}")

## Information sur le nombre de lignes et de colonnes
print(f"- Nombre de lignes : {df_consommation_raw.count():,}")
print("- Nombre de colonnes :", len(df_consommation_raw.columns))

## Apercu des donnees
print("- Apercu des donnees :")
df_consommation_raw.show(10, truncate=False)
# Out:
# - Les données de consommation ont été chargées avec succès: C:\Users\joel\Desktop\ecf_energie\data\consommations_raw-light-test.csv
# - Nombre de lignes : 999
# - Nombre de colonnes : 5
# - Apercu des donnees :
# +-----------+-------------------+------------+------------+-----+
# |batiment_id|timestamp          |type_energie|consommation|unite|
# +-----------+-------------------+------------+------------+-----+
# |BAT0141    |2023-12-21 13:00:00|gaz         |342.34      |kWh  |
# |BAT0080    |08/08/2023 13:00   |gaz         |1256.73     |kWh  |
# |BAT0122    |06/13/2024 11:00:00|eau         |133.57      |m3   |
# |BAT0033    |2023-06-25 00:00:00|eau         |0.23        |m3   |
# |BAT0064    |11/29/2024 04:00:00|gaz         |12.26       |kWh  |
# |BAT0052    |09/15/2024 18:00:00|gaz         |701.01      |kWh  |
# |BAT0097    |2024-01-25 12:00:00|gaz         |444.87      |kWh  |
# |BAT0073    |27/03/2023 13:00   |electricite |123.97      |kWh  |
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 1.1.2 Analyse de schema infere et identification des problemes de typage

# %% [markdown]
# * **Schema infere**

# %%
df_consommation_raw.printSchema()
# Out:
# root
#  |-- batiment_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- type_energie: string (nullable = true)
#  |-- consommation: string (nullable = true)
#  |-- unite: string (nullable = true)

# %% [markdown]
# * **Analyse du schema infere & identification des problemes de typage**

# %% [markdown]
# Ce shema révèle que les données des deux colonnes ``timestamp`` & ``consommation`` ont besoin de transformations pour corriger leurs types :
#
# - ``timestamp`` deviendera (après les futures nécéssaires transformations) de type timestamp ;
# - ``consommation`` deviendera (après les futures nécéssaires transformations) de type double.
#
# *timestamp :*

# %% [markdown]
# Problème : La forme des ``timestamp`` n'est pas unifiée :

# %%
print("Exemples de formats de timestamp:")
df_consommation_raw.select("timestamp").distinct().show(10, truncate=False)
# Out:
# Exemples de formats de timestamp:
# +-------------------+
# |timestamp          |
# +-------------------+
# |2023-12-21 13:00:00|
# |11/29/2024 04:00:00|
# |09/15/2024 18:00:00|
# |20/12/2023 07:00   |
# |29/04/2024 13:00   |
# |2024-06-15T14:00:00|
# |22/03/2024 11:00   |
# |2023-04-07 13:00:00|
# |2024-03-11T11:00:00|
# |08/21/2024 17:00:00|
# +-------------------+
# only showing top 10 rows

# %% [markdown]
# *consommation :*
#
# Problème : elle contient des valeurs "non double" :

# %%
## Les valeurs qui ne peuvent pas etre converties en nombre
df_non_numeric = df_consommation_raw.filter(
    ~F.col("consommation").rlike("^-?[0-9]+[.,]?[0-9]*$")
)

nbre_vals_non_numeric = df_non_numeric.count() 

if nbre_vals_non_numeric == 0:
    print("- La colonne 'consommation' ne contient pas de valeurs non numeriques")
else:
    print(f"- Nombre de valeurs non numeriques : {nbre_vals_non_numeric:,}")
    print(f"- Differents valeurs non numeriques :")
    df_consommation_raw.select("consommation").distinct().show()
# Out:
# - Nombre de valeurs non numeriques : 4
# - Differents valeurs non numeriques :
# +------------+
# |consommation|
# +------------+
# |      133.57|
# |        9.25|
# |      866.26|
# |      427.68|
# |        7.31|
# |       10.60|
# |       62.97|
# |       11.40|
# |      306.11|
# |      665.85|
# |      134.10|
# |      712.43|
# |        1.74|
# |        5.18|
# |       20,38|
# |       14.01|
# |       49.12|
# |       19,14|
# |        1,28|
# |     3824.79|
# +------------+
# only showing top 20 rows

# %%
## Valeurs avec virgule comme separateur decimal
df_with_comma = df_consommation_raw.filter(F.col("consommation").contains(","))

nbre_vals_with_comma = df_with_comma.count() 

if nbre_vals_with_comma == 0:
    print("- La colonne 'consommation' ne contient pas de valeurs avec des virgules décimales")
else:
    print(f"- Nombre de valeurs avec virgule : {nbre_vals_with_comma:,}")
    ## Affichages d'exemples
    print(f"- Exemples :")
    df_with_comma.select("consommation").show(5)
# Out:
# - Nombre de valeurs avec virgule : 135
# - Exemples :
# +------------+
# |consommation|
# +------------+
# |       10,10|
# |       72,29|
# |       17,82|
# |        0,92|
# |      290,65|
# +------------+
# only showing top 5 rows

# %% [markdown]
# ---

# %% [markdown]
# ## 1.1.3 Calculer les statistiques descriptives par type d'energie

# %% [markdown]
# Initialement on a la colonne ``consommation`` en string.
#
# Pour calculer les statistiques descriptives, on va créer une dataFrame 'df_consommation_numeric' qui contient les mêmes données que 'df_consommations_raw' plus une colonne ``consommation_clean`` qui contient les valeurs de la colonne 'consommation' converties en double.

# %%
## Nombre des valeurs Nulls initiales dans df_consommations_raw
nbre_vals_nulles = df_consommation_raw.filter(F.col("consommation").isNull()).count()
print("- Nombre de valeurs nulles dans la colonne 'consommation' de la df_consommations_raw :", nbre_vals_nulles)

## Ajouter de la colonne 'consommation_clean' dans la dataFrame df_consommations_raw
## & convertion de value en double (en remplacant la virgule par un point)
df_consommation_numeric = df_consommation_raw.withColumn(
    "consommation_clean",
    F.regexp_replace(F.col("consommation"), ",", ".").cast("double")
)

## Apercu de la df_consommation_numeric
print("- Apercu de la df_consommation_numeric :")
df_consommation_numeric.show(10)

## Nombre des valeurs Nulls dans df_consommation_numeric
print(f"- Nombre des valeurs Nulls dans la colonne 'consommation_clean' : {df_consommation_numeric.filter(F.col('consommation_clean').isNull()).count():,}")

## Calcul des statistiques descriptives par type d'energie (en ignorant les valeurs nulles de 'consommation_clean')
stats_by_type_energie = df_consommation_numeric.filter(F.col("consommation_clean").isNotNull()) \
    .groupBy("type_energie") \
    .agg(
        F.count("*").alias("count"),
        F.round(F.mean("consommation_clean"), 2).alias("mean"),
        F.round(F.stddev("consommation_clean"), 2).alias("stddev"),
        F.round(F.min("consommation_clean"), 2).alias("min"),
        F.round(F.max("consommation_clean"), 2).alias("max"),
        F.round(F.expr("percentile(consommation_clean, 0.5)"), 2).alias("median")
    ) \
    .orderBy("type_energie")

print("\n- Statistiques par type d'energie (en ignorant les valeurs nulles) :")
stats_by_type_energie.show()
# Out:
# - Nombre de valeurs nulles dans la colonne 'consommation' de la df_consommations_raw : 0
# - Apercu de la df_consommation_numeric :
# +-----------+-------------------+------------+------------+-----+------------------+
# |batiment_id|          timestamp|type_energie|consommation|unite|consommation_clean|
# +-----------+-------------------+------------+------------+-----+------------------+
# |    BAT0141|2023-12-21 13:00:00|         gaz|      342.34|  kWh|            342.34|
# |    BAT0080|   08/08/2023 13:00|         gaz|     1256.73|  kWh|           1256.73|
# |    BAT0122|06/13/2024 11:00:00|         eau|      133.57|   m3|            133.57|
# |    BAT0033|2023-06-25 00:00:00|         eau|        0.23|   m3|              0.23|
# |    BAT0064|11/29/2024 04:00:00|         gaz|       12.26|  kWh|             12.26|
# |    BAT0052|09/15/2024 18:00:00|         gaz|      701.01|  kWh|            701.01|
# ...

# %%
## Identification des valeurs négatives & aberrantes
print("- Valeurs negatives :")
df_consommation_numeric.filter(F.col("consommation_clean") < 0).groupBy("type_energie").count().show()

print("- Valeurs abberantes > 15000 :")
df_consommation_numeric.filter(F.col("consommation_clean") > 15000).groupBy("type_energie").count().show()
# Out:
# - Valeurs negatives :
# +------------+-----+
# |type_energie|count|
# +------------+-----+
# |         eau|    1|
# +------------+-----+
#
# - Valeurs abberantes > 15000 :
# +------------+-----+
# |type_energie|count|
# +------------+-----+
# |         eau|    1|
# |         gaz|    2|
# | electricite|    1|
# +------------+-----+

# %% [markdown]
# ---

# %% [markdown]
# ## 1.1.4 Identifier les batiments avec le plus de mesures

# %%
## Batiments ids avec le plus de mesures (affichage par ordre décroissant du nombre de mesures)
print("- Les batiments ids avec le plus de mesures (odre décroissant + affichage de seulement les 10 premiers) :")
df_batiments_mesures_count = df_consommation_raw.groupBy('batiment_id').count().withColumnRenamed("count", "nbre_de_mesures").orderBy(F.col("count").desc())
df_batiments_mesures_count.show(10)
# Out:
# - Les batiments ids avec le plus de mesures (odre décroissant + affichage de seulement les 10 premiers) :
# +-----------+---------------+
# |batiment_id|nbre_de_mesures|
# +-----------+---------------+
# |    BAT0117|             13|
# |    BAT0082|             13|
# |    BAT0074|             13|
# |    BAT0052|             13|
# |    BAT0059|             12|
# |    BAT0093|             11|
# |    BAT0011|             11|
# |    BAT0121|             11|
# |    BAT0071|             11|
# |    BAT0003|             11|
# +-----------+---------------+
# only showing top 10 rows

# %%
## Chargement du CSV des batiments avec inference de schema
df_batiments = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv(BATIMENTS_FILE_DATA_PATH)

print(f"- Fichier de des batiments a été chargé avec succès : {BATIMENTS_FILE_DATA_PATH}")

## Information sur le nombre de lignes et de colonnes
print("- Nombre de lignes :", df_batiments.count())
print("- Nombre de colonnes :", len(df_batiments.columns))

## Apercu des donnees
print("- Apercu des donnees :")
df_batiments.show(10, truncate=False)
# Out:
# - Fichier de des batiments a été chargé avec succès : C:\Users\joel\Desktop\ecf_energie\data\batiments.csv
# - Nombre de lignes : 146
# - Nombre de colonnes : 8
# - Apercu des donnees :
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# |batiment_id|nom                |type       |commune|surface_m2|annee_construction|classe_energetique|nb_occupants_moyen|
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# |BAT0001    |Ecole Paris 1      |ecole      |Paris  |1926      |1978              |E                 |225               |
# |BAT0002    |Ecole Paris 2      |ecole      |Paris  |1156      |2004              |C                 |402               |
# |BAT0003    |Ecole Paris 3      |ecole      |Paris  |1695      |2014              |D                 |219               |
# ...

# %%
## Affichage des batiments (avec leurs données) avec le plus de mesures (ordre décroissant)
df_batiments_mesures_count.join(df_batiments, on="batiment_id", how="left").orderBy(F.col("nbre_de_mesures").desc()).show()
# Out:
# +-----------+---------------+--------------------+-----------+-------------+----------+------------------+------------------+------------------+
# |batiment_id|nbre_de_mesures|                 nom|       type|      commune|surface_m2|annee_construction|classe_energetique|nb_occupants_moyen|
# +-----------+---------------+--------------------+-----------+-------------+----------+------------------+------------------+------------------+
# |    BAT0117|             13| Mairie Le Havre 117|     mairie|     Le Havre|      1257|              2018|                 A|                36|
# |    BAT0082|             13|Gymnase Montpelli...|    gymnase|  Montpellier|      1719|              2015|                 C|               214|
# |    BAT0074|             13|Mairie Strasbourg 74|     mairie|   Strasbourg|      1180|              1955|                 F|                36|
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 1.1.5 Production d'un rapport d'audit de qualite des donnees

# %%
## Nombre total des enregistrements
total_enregistrements = df_consommation_raw.count()

## Valeurs non numeriques
non_numeric = df_consommation_raw.filter(
    ~F.col("consommation").rlike("^-?[0-9]+[.,]?[0-9]*$")
).count()

## Valeurs avec virgule
with_comma = df_consommation_raw.filter(F.col("consommation").contains(",")).count()

## Valeurs negatives (apres conversion)
negative = df_consommation_numeric.filter(F.col("consommation_clean") < 0).count()

## Valeurs aberrantes > 15000
outliers = df_consommation_numeric.filter(F.col("consommation_clean") > 15000).count()

## Doublons
duplicates = total_enregistrements - df_consommation_raw.dropDuplicates(["batiment_id", "timestamp", "type_energie"]).count()

## Optional : Temps d'execution de ce script + ressources allouées au départ
temps_execution_01 = time.time() - start_time

## Generer le rapport markdown
rapport_audit = f"""# Rapport d'audit qualité des données de consommation énergétique des bâtiments

## Total enregistrements
{total_enregistrements:,}

## Problemes identifies
- Valeurs non numeriques : {non_numeric:,} ({non_numeric/total_enregistrements*100:.2f}%)
- Valeurs avec virgule decimale : {with_comma:,} ({with_comma/total_enregistrements*100:.2f}%)
- Valeurs negatives : {negative:,} ({negative/total_enregistrements*100:.2f}%)
- Valeurs aberrantes (>15000) : {outliers:,} ({outliers/total_enregistrements*100:.2f}%)
- Doublons : {duplicates:,} ({duplicates/total_enregistrements*100:.2f}%)
- Formats de dates multiples : 4 formats differents detectes

---
*Rapport genere automatiquement - Audit de qualite des donnees de consommation énergetique des batiments*  
*Données brutes : consommations_raw.csv*  
*Script de traitement : 01_exploration_spark.ipynb*  
*Temps de traitement : {temps_execution_01:.2f} secondes*  
*Ressources machine approximatives allouées à ce traitement : (RAM : {ram_available_01:.2f} GB, CPU : {cpu_available_pct_01:.2f}% - Approx logical cores free({available_logical_01:.2f}) - Approx physical cores free : {available_physical_01:.2f})*  
*Date : {datetime.now().strftime("%d/%m/%Y %H:%M:%S")} (FR)* 
"""

# Sauvegarder le rapport d'audit
with open(f"{RAPPORT_AUDIT_FILE_DATA_PATH}", 'w', encoding='utf-8') as f:
    f.write(rapport_audit)

print(f"Rapport d'audit sauvegarde : {RAPPORT_AUDIT_FILE_DATA_PATH}")
print("\n" + "="*60)
print(rapport_audit)
# Out:
# Rapport d'audit sauvegarde : C:\Users\joel\Desktop\ecf_energie\output\01_rapport_audit_donnees.md
#
# ...
# # Rapport d'audit qualité des données de consommation énergétique des bâtiments
#
# ## Total enregistrements
# 999
#
# ## Problemes identifies
# - Valeurs non numeriques : 4 (0.40%)
# - Valeurs avec virgule decimale : 135 (13.51%)
# - Valeurs negatives : 1 (0.10%)
# - Valeurs aberrantes (>15000) : 4 (0.40%)
# - Doublons : 0 (0.00%)
# - Formats de dates multiples : 4 formats differents detectes
#
# ---
# *Rapport genere automatiquement - Audit de qualite des donnees de consommation énergetique des batiments*
# *Données brutes : consommations_raw.csv*
# *Script de traitement : 01_exploration_spark.ipynb*
# *Temps de traitement : 23.87 secondes*
# *Ressources machine approximatives allouées à ce traitement : (RAM : 13.22 GB, CPU : 91.90% - Approx logical cores free(14.70) - Approx physical cores free : 7.35)*
# *Date : 14/02/2026 16:08:49 (FR)*

# %%
# --- Optionel : enregistrement dans un fichier temporaire du temps d'execution + ressources pour 
#                utilisation ultérieure (dans le script run_pipeline_hybride.py ou autres.)

temps_resources = f"""
    Date : {datetime.now().strftime("%d/%m/%Y %H:%M:%S")} (FR)

    temps_exec_sec={temps_execution_01:.2f}
    ram_gb={ram_available_01:.2f}
    cpu_pct={cpu_available_pct_01:.2f}
    logi_cores={available_logical_01:.1f}
    physi_cores={available_physical_01:.1f}
"""
# Ecrire des données du temps d'execution + ressources dans le fichier TMP_FILE_PATH
TMP_FILE_PATH.write_text(temps_resources, encoding="utf-8")
# Out:
# 138

# %% [markdown]
# ---

# %% [markdown]
# ## Fermer la session Spark

# %%
spark.stop()
