# %% [markdown]
# # Etape 2.2 : Fusion et enrichissement
#
# ---
# ---

# %% [markdown]
# ## Import

# %%
import sys
import os
from pathlib import Path
import warnings 
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ## Utils

# %%
# --- Fnc. pour savoir la qualité (completude, ...) des dataframes
def quality_report(df):
    print(f"    - Lignes: {len(df):,}")
    print(f"    - Colonnes: {len(df.columns)}")
    
    report = []
    for col in df.columns:
        total = len(df)
        missing = df[col].isna().sum() + (df[col] == '').sum() if df[col].dtype == 'object' else df[col].isna().sum()
        completude = (1 - missing / total) * 100
        unique = df[col].nunique()
        dtype = df[col].dtype
        
        report.append({
            'Colonne': col,
            'Type': str(dtype),
            'Manquants': missing,
            'Completude %': round(completude, 2),
            'Uniques': unique
        })
    
    return pd.DataFrame(report)

# --- Python cfg.: 
# cacher (ignorer) les warnings
warnings.filterwarnings('ignore') 

# --- Pandas cfg.:
# show ALL rows
pd.set_option('display.max_rows', None)
# show ALL columns
pd.set_option('display.max_columns', None)
# prevent column text from being truncated
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ---

# %% [markdown]
# ## Chemins des données

# %%
# ==============================================================================================================
#                                                    DIRS
# ==============================================================================================================
DIR_DATA_PATH = (Path.cwd() / ".." / "data").resolve()
DIR_OUTPUT_PATH = (Path.cwd() / ".." / "output").resolve()

# ==============================================================================================================
#                                                   INPUTS
# ==============================================================================================================
IN_CONSO_CLEAN_PARQUET = os.path.join(DIR_OUTPUT_PATH, "02_consommations_clean")
IN_METEO_CLEAN_PATH = os.path.join(DIR_OUTPUT_PATH, "meteo_clean.csv")
IN_BATIMENT_PATH = os.path.join(DIR_DATA_PATH, "batiments.csv")
IN_TARIF_PATH = os.path.join(DIR_DATA_PATH, "tarifs_energie.csv")

# ==============================================================================================================
#                                                   OUTPUTS
# ==============================================================================================================
OUT_CONSO_ENRICHIES_CSV =  os.path.join(DIR_OUTPUT_PATH, "consommations_enrichies.csv")
OUT_CONSO_ENRICHIES_PARQUET = os.path.join(DIR_OUTPUT_PATH, "consommations_enrichies.parquet")

# %% [markdown]
# ---

# %% [markdown]
# ## Charger les consommations nettoyees (depuis Parquet)

# %%
df_conso = pd.read_parquet(IN_CONSO_CLEAN_PARQUET)

## Affichage de quelques infos
print("df_conso :")
print(f"    - Shape: {df_conso.shape}")
print(f"    - Colonnes: {df_conso.columns.tolist()}")
print()
# Info sur les types
print("    - Infos sur les types : ")
df_conso.info()
print()
## Appercu des donnees
print("    - Appercu des donnees : ")
df_conso.head()
# Out:
# df_conso :
#     - Shape: (6996788, 6)
#     - Colonnes: ['batiment_id', 'heure', 'consommation_moyenne', 'unite', 'date', 'type_energie']
#
#     - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 6996788 entries, 0 to 6996787
# Data columns (total 6 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   batiment_id           str
#  1   heure                 int32
#  2   consommation_moyenne  float64
#  3   unite                 str
#  4   date                  category
#  5   type_energie          category
# dtypes: category(2), float64(1), int32(1), str(2)
# memory usage: 271.4 MB
#
#     - Appercu des donnees :
#   batiment_id  heure  consommation_moyenne unite        date type_energie
# 0     BAT0001      7                  2.28    m3  2023-01-01          eau
# 1     BAT0001      9                  2.91    m3  2023-01-01          eau
# 2     BAT0001     15                  3.42    m3  2023-01-01          eau
# 3     BAT0001     23                  0.20    m3  2023-01-01          eau
# 4     BAT0002      4                  0.13    m3  2023-01-01          eau

# %% [markdown]
# ---

# %% [markdown]
# ## Charger les données météo nettoyees

# %%
df_meteo = pd.read_csv(IN_METEO_CLEAN_PATH)

## Affichage de quelques infos
print("df_meteo :")
print(f"    - Shape: {df_meteo.shape}")
print(f"    - Colonnes: {df_meteo.columns.tolist()}")
print()
# Info sur les types
print("    - Infos sur les types : ")
df_meteo.info()
print()
## Appercu des donnees
print("    - Appercu des donnees : ")
df_meteo.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_meteo = pd.read_csv(IN_METEO_CLEAN_PATH)
#       3 ## Affichage de quelques infos
#       4 print("df_meteo :")
#
# File c:\Users\Administrateur\Desktop\ecf_energie\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Administrateur\Desktop\ecf_energie\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Administrateur\Desktop\ecf_energie\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Administrateur\Desktop\ecf_energie\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Administrateur\Desktop\ecf_energie\.venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Administrateur\\Desktop\\ecf_energie\\output\\meteo_clean.csv'

# %% [markdown]
# ---

# %% [markdown]
# ## Chargement du referenciel batiments

# %%
df_bat = pd.read_csv(IN_BATIMENT_PATH)

## Affichage de quelques infos
print("df_bat :")
print(f"    - Shape: {df_bat.shape}")
print(f"    - Colonnes: {df_bat.columns.tolist()}")
print()
# Info sur les types
print("    - Infos sur les types : ")
df_bat.info()
print()
## Appercu des donnees
print("    - Appercu des donnees : ")
df_bat.head()
# Out:
# df_bat :
#     - Shape: (146, 8)
#     - Colonnes: ['batiment_id', 'nom', 'type', 'commune', 'surface_m2', 'annee_construction', 'classe_energetique', 'nb_occupants_moyen']
#
#     - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   batiment_id         146 non-null    str
#  1   nom                 146 non-null    str
#  2   type                146 non-null    str
#  3   commune             146 non-null    str
#  4   surface_m2          146 non-null    int64
#  5   annee_construction  146 non-null    int64
#  6   classe_energetique  146 non-null    str
#  7   nb_occupants_moyen  146 non-null    int64
# dtypes: int64(3), str(5)
# memory usage: 15.1 KB
#
#     - Appercu des donnees :
#   batiment_id                  nom         type commune  surface_m2  \
# 0     BAT0001        Ecole Paris 1        ecole   Paris        1926
# 1     BAT0002        Ecole Paris 2        ecole   Paris        1156
# 2     BAT0003        Ecole Paris 3        ecole   Paris        1695
# 3     BAT0004  Mediatheque Paris 4  mediatheque   Paris         907
# 4     BAT0005      Piscine Paris 5      piscine   Paris        3913
#
#    annee_construction classe_energetique  nb_occupants_moyen
# 0                1978                  E                 225
# 1                2004                  C                 402
# 2                2014                  D                 219
# 3                2019                  C                 121
# 4                1950                  G                 242

# %% [markdown]
# ---

# %% [markdown]
# ## Chargement des tarifs

# %%
df_tarifs = pd.read_csv(IN_TARIF_PATH)

## Affichage de quelques infos
print("df_tarifs :")
print(f"    - Shape: {df_tarifs.shape}")
print(f"    - Colonnes: {df_tarifs.columns.tolist()}")
print()
# Info sur les types
print("    - Infos sur les types : ")
df_tarifs.info()
print()
## Appercu des donnees
print("    - Appercu des donnees : ")
# df_tarifs.head()
print(df_tarifs)
# Out:
# df_tarifs :
#     - Shape: (10, 4)
#     - Colonnes: ['date_debut', 'date_fin', 'type_energie', 'tarif_unitaire']
#
#     - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date_debut      10 non-null     str
#  1   date_fin        10 non-null     str
#  2   type_energie    10 non-null     str
#  3   tarif_unitaire  10 non-null     float64
# dtypes: float64(1), str(3)
# memory usage: 714.0 bytes
#
#     - Appercu des donnees :
#    date_debut    date_fin type_energie  tarif_unitaire
# 0  2023-01-01  2023-06-30  electricite            0.18
# 1  2023-07-01  2023-12-31  electricite            0.20
# 2  2023-01-01  2023-06-30          gaz            0.09
# 3  2023-07-01  2023-12-31          gaz            0.10
# 4  2023-01-01  2023-12-31          eau            3.50
# 5  2024-01-01  2024-06-30  electricite            0.21
# 6  2024-07-01  2024-12-31  electricite            0.22
# 7  2024-01-01  2024-06-30          gaz            0.11
# 8  2024-07-01  2024-12-31          gaz            0.12
# 9  2024-01-01  2024-12-31          eau            3.75

# %% [markdown]
# ---

# %% [markdown]
# ## Fusionner des données de consommation (clean) avec les donnees meteo (sur commune et timestamp arrondi a l'heure)
#
# df_conso & df_meteo n'ont pas pour le momment de colonnes communes. Donc les étapes de la fusion (après le traitemet des timestamps) serons :
# 1. Fusion de df_conso & df_bat pour obtenir 'commune' (result: *df_conso_bat*)
# 2. Fusion avec df_meteo (result: *df*)

# %%
# --- Traitement des timestamps (de df_conso & df_meteo)
# df_conso
df_conso["date"] = pd.to_datetime(df_conso["date"])
df_conso["heure"] = pd.to_numeric(df_conso["heure"], errors="coerce").astype("Int64")
    # Construire ts_h côté conso (date + heure)
df_conso["ts_h"] = pd.to_datetime(df_conso['date'].astype(str) + ' ' + df_conso['heure'].astype(str) + ':00:00')

# df_meteo
df_meteo["ts_h"] = pd.to_datetime(df_meteo["ts_h"])
#df_meteo["ts_h"] = df_meteo["timestamp"].dt.floor("h")

# --- Check de la qualité des données des df_conso & df_meteo
# df_conso :
print("Check de la qualité des données des df_conso")
df_report_conso = quality_report(df_conso)
print("    df_report_conso : ")
print(df_report_conso)

cols_non_zero = df_report_conso.loc[
    df_report_conso["Manquants"] != 0, "Colonne"
].tolist()

if len(cols_non_zero) != 0:
    print("    [ko]: les colonnes avec des valeurs manquantes : ", cols_non_zero)
    sys.exit(0)
else:
    print("    [ok]: pas de colonnes avec des valeurs manquantes dans df_conso")

# df_meteo :
print()
print("Check de la qualité des données des df_meteo")
df_report_meteo = quality_report(df_meteo)
print("    df_report_meteo : ")
print(df_report_meteo)

cols_non_zero = df_report_meteo.loc[
    df_report_meteo["Manquants"] != 0, "Colonne"
].tolist()

if len(cols_non_zero) != 0:
    print("    [ko]: les colonnes avec des valeurs manquantes : ", cols_non_zero)
    sys.exit(0)
else:
    print("    [ok]: pas de colonnes avec des valeurs manquantes dans df_meteo")
# Out:
# Check de la qualité des données des df_conso
#     - Lignes: 6,996,788
#     - Colonnes: 7
#     df_report_conso :
#                 Colonne            Type  Manquants  Completude %  Uniques
# 0           batiment_id             str          0         100.0      146
# 1                 heure           Int64          0         100.0       24
# 2  consommation_moyenne         float64          0         100.0   275523
# 3                 unite             str          0         100.0        2
# 4                  date        category          0         100.0      731
# 5          type_energie        category          0         100.0        3
# 6                  ts_h  datetime64[us]          0         100.0    17544
#     [ok]: pas de colonnes avec des valeurs manquantes dans df_conso
#
# Check de la qualité des données des df_meteo
#     - Lignes: 236,232
#     - Colonnes: 11
#     df_report_meteo :
#                     Colonne            Type  Manquants  Completude %  Uniques
# 0                   commune             str          0         100.0       15
# 1                      ts_h  datetime64[us]          0         100.0    17544
# 2             temperature_c         float64          0         100.0      921
# 3              humidite_pct         float64          0         100.0      652
# 4   rayonnement_solaire_wm2         float64          0         100.0     1094
# 5          vitesse_vent_kmh         float64          0         100.0      401
# 6          precipitation_mm         float64          0         100.0      151
# 7                      jour             str          0         100.0      731
# 8                      mois           int64          0         100.0       12
# 9                    saison             str          0         100.0        4
# 10          jour_de_semaine           int64          0         100.0        7
#     [ok]: pas de colonnes avec des valeurs manquantes dans df_meteo

# %%
# --- Fusion de df_conso & df_bat pour obtenir 'commune'
df_conso_bat = df_conso.merge(df_bat, on="batiment_id", how="left", validate="many_to_one")

#N.B: - avec validate="many_to_one" => pandas vérifie que df_bat["batiment_id"] est unique (Sinon => erreur immédiate :)
#     - on peut avoir plusieurs 'conso' pour le même batiment

# check
print()
if (df_conso_bat["commune"].isna().sum() != 0):
    print("[ko]: Batiments non matchés :", df_conso_bat["commune"].isna().sum()) 
    sys.exit(1)
else:
    print("[ok]: Batiments non matchés :", df_conso_bat["commune"].isna().sum()) 

# Apperçu de df_conso_bat
print()
print("Apperçu de df_conso_bat :")
# df_conso_bat.head()
df_conso_bat.info()
# Out:
# [ok]: Batiments non matchés : 0
#
# Apperçu de df_conso_bat :
# <class 'pandas.DataFrame'>
# RangeIndex: 6996788 entries, 0 to 6996787
# Data columns (total 14 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   batiment_id           str
#  1   heure                 Int64
#  2   consommation_moyenne  float64
#  3   unite                 str
#  4   date                  category
#  5   type_energie          category
#  6   ts_h                  datetime64[us]
#  7   nom                   str
#  8   type                  str
#  9   commune               str
#  10  surface_m2            int64
#  11  annee_construction    int64
#  12  classe_energetique    str
#  13  nb_occupants_moyen    int64
# dtypes: Int64(1), category(2), datetime64[us](1), float64(1), int64(3), str(6)
# memory usage: 960.6 MB

# %%
# --- Fusion (de df_conso_bat) avec df_meteo
df = df_conso_bat.merge(df_meteo, on=["commune", "ts_h"], how="left", validate="many_to_one")

print("Infos sur df : ")
df.info()
# Out:
# Infos sur df :
# <class 'pandas.DataFrame'>
# RangeIndex: 6996788 entries, 0 to 6996787
# Data columns (total 23 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   batiment_id              str
#  1   heure                    Int64
#  2   consommation_moyenne     float64
#  3   unite                    str
#  4   date                     category
#  5   type_energie             category
#  6   ts_h                     datetime64[us]
#  7   nom                      str
#  8   type                     str
#  9   commune                  str
#  10  surface_m2               int64
#  11  annee_construction       int64
#  12  classe_energetique       str
#  13  nb_occupants_moyen       int64
#  14  temperature_c            float64
#  15  humidite_pct             float64
#  16  rayonnement_solaire_wm2  float64
#  17  vitesse_vent_kmh         float64
#  18  precipitation_mm         float64
#  19  jour                     str
#  20  mois                     float64
#  21  saison                   str
#  22  jour_de_semaine          float64
# dtypes: Int64(1), category(2), datetime64[us](1), float64(8), int64(3), str(8)
# memory usage: 1.5 GB

# %%
print("Aperçu de df : ")
df.head()
# Out:
# Aperçu de df :
#   batiment_id  heure  consommation_moyenne unite       date type_energie  \
# 0     BAT0001      7                  2.28    m3 2023-01-01          eau
# 1     BAT0001      9                  2.91    m3 2023-01-01          eau
# 2     BAT0001     15                  3.42    m3 2023-01-01          eau
# 3     BAT0001     23                  0.20    m3 2023-01-01          eau
# 4     BAT0002      4                  0.13    m3 2023-01-01          eau
#
#                  ts_h            nom   type commune  surface_m2  \
# 0 2023-01-01 07:00:00  Ecole Paris 1  ecole   Paris        1926
# 1 2023-01-01 09:00:00  Ecole Paris 1  ecole   Paris        1926
# 2 2023-01-01 15:00:00  Ecole Paris 1  ecole   Paris        1926
# 3 2023-01-01 23:00:00  Ecole Paris 1  ecole   Paris        1926
# 4 2023-01-01 04:00:00  Ecole Paris 2  ecole   Paris        1156
#
#    annee_construction classe_energetique  nb_occupants_moyen  temperature_c  \
# 0                1978                  E                 225            NaN
# 1                1978                  E                 225            3.8
# 2                1978                  E                 225           -1.2
# 3                1978                  E                 225           -1.9
# 4                2004                  C                 402            9.9
#
#    humidite_pct  rayonnement_solaire_wm2  vitesse_vent_kmh  precipitation_mm  \
# 0           NaN                      NaN               NaN               NaN
# 1          49.7                     49.7              18.1               0.0
# 2          92.1                     92.1              39.4               0.0
# 3          30.9                     30.9              19.2               0.0
# 4          41.2                     41.2               4.4               1.3
#
#          jour  mois saison  jour_de_semaine
# 0         NaN   NaN    NaN              NaN
# 1  2023-01-01   1.0  Hiver              6.0
# 2  2023-01-01   1.0  Hiver              6.0
# 3  2023-01-01   1.0  Hiver              6.0
# 4  2023-01-01   1.0  Hiver              6.0

# %%
# Infos suplementaire (Audit) : 
print("Météo manquante (%) :", df["temperature_c"].isna().mean() * 100)
# Out:
# Météo manquante (%) : 9.454123806523794

# %% [markdown]
# ---

# %% [markdown]
# ## Fusionner avec les tarifs pour calculer le cout financier

# %%
# Ensure les types
    # date dans df
df["date"] = pd.to_datetime(df["date"].astype("string"), errors="coerce")
if df["date"].isna().mean() * 100 != 0.0:
    print("[ko]: dates manquantes dans df (%) :", df["date"].isna().mean() * 100)
    sys.exit(1)

    # dates début & fin dans df_tarifs
df_tarifs["date_debut"] = pd.to_datetime(df_tarifs["date_debut"].astype("string"), errors="coerce")
df_tarifs["date_fin"] = pd.to_datetime(df_tarifs["date_fin"].astype("string"), errors="coerce")
if df_tarifs["date_debut"].isna().mean() * 100 != 0.0:
    print("[ko]: dates de début manquantes dans df_tarifs (%) :", df["date_debut"].isna().mean() * 100)
    sys.exit(1)
if df_tarifs["date_fin"].isna().mean() * 100 != 0.0:
    print("[ko]: dates de fin manquantes dans df_tarifs (%) :", df["date_fin"].isna().mean() * 100)
    sys.exit(1)

# Join (sur type_energie)
df_tmp = df.merge(df_tarifs, on="type_energie", how="left")

# Filtre intervalle
df_tmp = df_tmp[(df_tmp["date"] >= df_tmp["date_debut"]) & (df_tmp["date"] <= df_tmp["date_fin"])].copy()

# Retirer les doublons s’il y a eu plusieurs périodes
df_tmp = df_tmp.sort_values(["batiment_id", "date", "heure", "type_energie", "date_debut"])
df_tmp = df_tmp.drop_duplicates(subset=["batiment_id", "date", "heure", "type_energie"], keep="last")

# Coût
df_tmp["cout"] = df_tmp["consommation_moyenne"] * df_tmp["tarif_unitaire"]
df = df_tmp

# Show
df.head()
# Out:
#       batiment_id  heure  consommation_moyenne unite       date type_energie  \
# 5572      BAT0001      0                  0.32    m3 2023-01-01          eau
# 11250     BAT0001      0                  5.70   kWh 2023-01-01  electricite
# 27438     BAT0001      0                  7.84   kWh 2023-01-01          gaz
# 3340      BAT0001      1                  0.26    m3 2023-01-01          eau
# 6826      BAT0001      1                  7.55   kWh 2023-01-01  electricite
#
#                      ts_h            nom   type commune  surface_m2  \
# 5572  2023-01-01 00:00:00  Ecole Paris 1  ecole   Paris        1926
# 11250 2023-01-01 00:00:00  Ecole Paris 1  ecole   Paris        1926
# 27438 2023-01-01 00:00:00  Ecole Paris 1  ecole   Paris        1926
# 3340  2023-01-01 01:00:00  Ecole Paris 1  ecole   Paris        1926
# 6826  2023-01-01 01:00:00  Ecole Paris 1  ecole   Paris        1926
#
#        annee_construction classe_energetique  nb_occupants_moyen  \
# 5572                 1978                  E                 225
# 11250                1978                  E                 225
# 27438                1978                  E                 225
# 3340                 1978                  E                 225
# 6826                 1978                  E                 225
#
#        temperature_c  humidite_pct  rayonnement_solaire_wm2  vitesse_vent_kmh  \
# 5572             2.5          31.8                     31.8              11.0
# 11250            2.5          31.8                     31.8              11.0
# 27438            2.5          31.8                     31.8              11.0
# 3340             2.7          90.9                     90.9              22.5
# 6826             2.7          90.9                     90.9              22.5
#
#        precipitation_mm        jour  mois saison  jour_de_semaine date_debut  \
# 5572                6.9  2023-01-01   1.0  Hiver              6.0 2023-01-01
# 11250               6.9  2023-01-01   1.0  Hiver              6.0 2023-01-01
# 27438               6.9  2023-01-01   1.0  Hiver              6.0 2023-01-01
# 3340                0.0  2023-01-01   1.0  Hiver              6.0 2023-01-01
# 6826                0.0  2023-01-01   1.0  Hiver              6.0 2023-01-01
#
#         date_fin  tarif_unitaire    cout
# 5572  2023-12-31            3.50  1.1200
# 11250 2023-06-30            0.18  1.0260
# 27438 2023-06-30            0.09  0.7056
# 3340  2023-12-31            3.50  0.9100
# 6826  2023-06-30            0.18  1.3590

# %% [markdown]
# ##

# %% [markdown]
# ---

# %%
## Preparer les donnees pour la fusion

## Verifier si les donnees de consommation sont vides
if len(df_consommations) == 0:
    print("ATTENTION: Les donnees de consommation sont vides!")
    print("Veuillez d'abord executer le notebook 02 pour generer les donnees Parquet.")
    # Creer un DataFrame vide avec les bonnes colonnes pour eviter les erreurs
    df_consommations['datetime_hour'] = pd.to_datetime([])
else:
    ## Pour la consommation: creer une colonne datetime arrondie a l'heure
    if 'date' in df_consommations.columns and 'hour' in df_consommations.columns:
        df_consommations['datetime_hour'] = pd.to_datetime(
            df_consommations['date'].astype(str) + ' ' + df_consommations['hour'].astype(str) + ':00:00'
        )
    elif 'timestamp_start' in df_consommations.columns:
        df_consommations['datetime_hour'] = df_consommations['timestamp_start'].dt.floor('h')
    elif 'timestamp' in df_consommations.columns:
        df_consommations['datetime_hour'] = df_consommations['timestamp'].dt.floor('h')
    else:
        print("- ERREUR: Aucune colonne temporelle trouvee dans df_consommation")
        df_consommations['datetime_hour'] = pd.to_datetime([])

## Pour la meteo: arrondir a l'heure
df_meteo['timestamp'] = pd.to_datetime(
    df_meteo['timestamp'],
    errors='coerce'
)

df_meteo['datetime_hour'] = df_meteo['timestamp'].dt.floor('h')

if len(df_consommations) > 0:
    print(f"- Consommations : {df_consommations['datetime_hour'].min()} -> {df_consommations['datetime_hour'].max()}")
print(f"- Meteo: {df_meteo['datetime_hour'].min()} -> {df_meteo['datetime_hour'].max()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[196], line 4
#       1 ## Preparer les donnees pour la fusion
#       2
#       3 ## Verifier si les donnees de consommation sont vides
# ----> 4 if len(df_consommations) == 0:
#       5     print("ATTENTION: Les donnees de consommation sont vides!")
#       6     print("Veuillez d'abord executer le notebook 02 pour generer les donnees Parquet.")
#
# NameError: name 'df_consommations' is not defined

# %%
## Agreger la meteo par commune et heure (au cas ou il y aurait des doublons)
df_meteo_hourly = df_meteo.groupby(['commune', 'datetime_hour']).agg({
    'temperature_c': 'mean', # → smooths multiple measurements in the same hour
    'humidite_pct': 'mean',
    "rayonnement_solaire_wm2": 'mean',
    'vitesse_vent_kmh': 'mean',
    'precipitation_mm': 'sum', # → correct: rainfall accumulates
    'precipitation_mm': 'first', # → assumes these don’t change within the hour
    'saison': 'first'
}).reset_index() # Converts group keys back into normal columns => Makes the DataFrame easier to work with later

print(f"- Meteo agregee: {len(df_meteo_hourly):,} lignes")

# %%
## Fusion sur commune et datetime_hour
if len(df_consommations) == 0:
    print("ERREUR: Impossible de fusionner - les donnees de consommations sont vides!")
    print("Veuillez d'abord executer le notebook 02_nettoyage_spark.ipynb")
    df_merged = pd.DataFrame()
else:
    df_merged = df_consommations.merge(
        df_meteo_hourly,
        on=['commune', 'datetime_hour'],
        how='left'
    )

    print(f"\nResultat de la fusion:")
    print(f"  - Lignes consommations: {len(df_consommations):,}")
    print(f"  - Lignes apres fusion: {len(df_merged):,}")
    print(f"  - Lignes avec meteo: {df_merged['temperature_c'].notna().sum():,}")
    print(f"  - Lignes sans meteo: {df_merged['temperature_c'].isna().sum():,}")

# %%
## Apercu du dataset fusionne
df_merged.head(10)

# %% [markdown]
# ---

# %% [markdown]
# ## Fusionner avec le referentiel batiments

# %%
df_conso_bat = df_merged.merge(
        df_bat,
        on=['batiment_id'],
        how='left'
)

## Affichage de quelques infos
print(f"- Shape: {df_conso_bat.shape}")
print(f"- Colonnes: {df_conso_bat.columns.tolist()}")
df_conso_bat.head(10)

# %% [markdown]
# ---

# %% [markdown]
# ## Fusionner avec les tarifs pour calculer le cout financier

# %%
df_merge = df_conso_bat.merge(df_tarifs, on="type_energie", how="left")

for col in ["date", "date_debut", "date_fin"]:
    df_merge[col] = pd.to_datetime(df_merge[col].astype(str), errors="coerce")

df_merge = df_merge[
    (df_merge["date"] >= df_merge["date_debut"]) &
    (df_merge["date"] <= df_merge["date_fin"])
]

df_merge["cout_financier"] = (
    df_merge["consommation_mean"] * df_merge["tarif_unitaire"]
)
df_merge.head(10)

# %% [markdown]
# ---

# %% [markdown]
# ## Creer des features derivees :
#   - Consommation par occupant
#   - Consommation par m2
#   - Cout journalier, mensuel, annuel
#   - Indice de performance energetique (IPE)
#   - Ecart a la moyenne de la categorie

# %%
## Consommation par occupant
print("- Consommation par occupant :")
df_merge["conso_par_occupant"] = (
    df_merge["consommation_mean"] / df_merge["nb_occupants_moyen"]
).replace([float("inf"), -float("inf")], pd.NA)
df_merge.head()

# %%
## Consommation par m²
df_merge["conso_par_m2"] = (
    df_merge["consommation_mean"] / df_merge["surface_m2"]
).replace([float("inf"), -float("inf")], pd.NA)

## Coûts temporels
    # Coût journalier
df_merge["cout_journalier"] = df_merge["cout_financier"]
    # Coût mensuel
df_cout_mensuel = (
    df_merge
    .groupby(
        ["batiment_id", "year", "month", "type_energie"],
        as_index=False
    )
    .agg(cout_mensuel=("cout_financier", "sum"))
)
    # Coût annuel
df_cout_annuel = (
    df_merge
    .groupby(
        ["batiment_id", "year", "type_energie"],
        as_index=False
    )
    .agg(cout_annuel=("cout_financier", "sum"))
)

    # Indice de Performance Énergétique (IPE) (IPE = consommation annuelle / surface (kWh/m²/an))
        # conso annuelle
df_conso_annuelle = (
    df_merge
    .groupby(
        ["batiment_id", "year", "type_energie"],
        as_index=False
    )
    .agg(conso_annuelle=("consommation_mean", "sum"))
)
        # Calcul de l’IPE
df_conso_annuelle = df_conso_annuelle.merge(
    df_merge[["batiment_id", "surface_m2"]].drop_duplicates(),
    on="batiment_id",
    how="left"
)

df_conso_annuelle["IPE_kwh_m2_an"] = (
    df_conso_annuelle["conso_annuelle"] / df_conso_annuelle["surface_m2"]
).round(2)

## Écart à la moyenne de la catégorie
    # Moyenne par catégorie
mean_by_category = (
    df_merge
    .groupby("type_y", as_index=False)
    .agg(conso_moyenne_categorie=("conso_par_m2", "mean"))
)
    # Écart absolu et relatif
df_merge = df_merge.merge(
    mean_by_category,
    on="type_y",
    how="left"
)

df_merge["ecart_moyenne_categorie"] = (
    df_merge["conso_par_m2"] - df_merge["conso_moyenne_categorie"]
)

df_merge["ecart_moyenne_categorie_pct"] = (
    df_merge["ecart_moyenne_categorie"] / df_merge["conso_moyenne_categorie"]
).round(2)

df_merge.head()

# %% [markdown]
# ---

# %% [markdown]
# ## Creation de consommations_enrichies.csv & consommations_enrichies.parquet

# %%
csv_consommations_enrichies_path = os.path.join(OUTPUT_DIR,"consommations_enrichies.csv")
parquet_consommations_enrichies_path = os.path.join(OUTPUT_DIR,"consommations_enrichies.parquet")

## Écriture en CSV
df_merge.to_csv(csv_consommations_enrichies_path, index=False)

## Écriture en Parquet
df_merge.to_parquet(
    parquet_consommations_enrichies_path,
    engine="pyarrow",
    index=False
)
