# %% [markdown]
# # Etape 2.2 : Fusion et enrichissement
#
# ---
# ---

# %% [markdown]
# ## Import

# %%
import sys
import os
from pathlib import Path
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---

# %% [markdown]
# ## Chemins des données

# %%
DATA_DIR = (Path.cwd() / ".." / "data").resolve()
OUTPUT_DIR = os.path.join(DATA_DIR, "output")
PARQUET_DIR = os.path.join(OUTPUT_DIR, "consommations_clean")
WEATHER_CLEAN_PATH = os.path.join(OUTPUT_DIR, "meteo_clean.csv")
BATIMENT_PATH = os.path.join(DATA_DIR, "batiments.csv")
TARIF_PATH = os.path.join(DATA_DIR, "tarifs_energie.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## Charger les consommations nettoyees (depuis Parquet)

# %%
df_consommations = pd.read_parquet(PARQUET_DIR)

## Affichage de quelques infos
print(f"- Shape: {df_consommations.shape}")
print(f"- Colonnes: {df_consommations.columns.tolist()}")
print()
# Info sur les types
print("- Infos sur les types : ")
df_consommations.info()
print()
## Appercu des donnees
print("- Appercu des donnees : ")
df_consommations.head(10)
# Out:
# - Shape: (320178, 14)
# - Colonnes: ['batiment_id', 'unite', 'year', 'month', 'timestamp_start', 'consommation_mean', 'consommation_min', 'consommation_max', 'measurement_count', 'nom', 'commune', 'type', 'date', 'type_energie']
#
# - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 320178 entries, 0 to 320177
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   batiment_id        320178 non-null  str
#  1   unite              320178 non-null  str
#  2   year               320178 non-null  int32
#  3   month              320178 non-null  int32
#  4   timestamp_start    320178 non-null  datetime64[ns]
#  5   consommation_mean  320178 non-null  float64
#  6   consommation_min   320178 non-null  float64
#  7   consommation_max   320178 non-null  float64
#  8   measurement_count  320178 non-null  int64
#  9   nom                320178 non-null  str
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Charger les données météo nettoyees

# %%
df_weather = pd.read_csv(WEATHER_CLEAN_PATH)

## Affichage de quelques infos
print(f"- Shape: {df_weather.shape}")
print(f"- Colonnes: {df_weather.columns.tolist()}")
print()
# Info sur les types
print("- Infos sur les types : ")
df_weather.info()
print()
## Appercu des donnees
print("- Appercu des donnees : ")
df_weather.head(10)
# Out:
# - Shape: (252612, 11)
# - Colonnes: ['commune', 'timestamp', 'temperature_c', 'humidite_pct', 'rayonnement_solaire_wm2', 'vitesse_vent_kmh', 'precipitation_mm', 'jour', 'jour_de_semaine', 'mois', 'saison']
#
# - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 252612 entries, 0 to 252611
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   commune                  252612 non-null  str
#  1   timestamp                252612 non-null  str
#  2   temperature_c            252612 non-null  float64
#  3   humidite_pct             252612 non-null  float64
#  4   rayonnement_solaire_wm2  252612 non-null  float64
#  5   vitesse_vent_kmh         252612 non-null  float64
#  6   precipitation_mm         252612 non-null  float64
#  7   jour                     252612 non-null  str
#  8   jour_de_semaine          252612 non-null  int64
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Chargement du referenciel batiments

# %%
df_batiments = pd.read_csv(BATIMENT_PATH)

## Affichage de quelques infos
print(f"- Shape: {df_batiments.shape}")
print(f"- Colonnes: {df_batiments.columns.tolist()}")
print()
# Info sur les types
print("- Infos sur les types : ")
df_batiments.info()
print()
## Appercu des donnees
print("- Appercu des donnees : ")
df_batiments.head(10)
# Out:
# - Shape: (146, 8)
# - Colonnes: ['batiment_id', 'nom', 'type', 'commune', 'surface_m2', 'annee_construction', 'classe_energetique', 'nb_occupants_moyen']
#
# - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   batiment_id         146 non-null    str
#  1   nom                 146 non-null    str
#  2   type                146 non-null    str
#  3   commune             146 non-null    str
#  4   surface_m2          146 non-null    int64
#  5   annee_construction  146 non-null    int64
#  6   classe_energetique  146 non-null    str
#  7   nb_occupants_moyen  146 non-null    int64
# dtypes: int64(3), str(5)
# memory usage: 15.1 KB
#
# - Appercu des donnees :
#   batiment_id                  nom         type commune  surface_m2  \
# 0     BAT0001        Ecole Paris 1        ecole   Paris        1926
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Chargement des tarifs

# %%
df_tarifs = pd.read_csv(TARIF_PATH)

## Affichage de quelques infos
print(f"- Shape: {df_tarifs.shape}")
print(f"- Colonnes: {df_tarifs.columns.tolist()}")
print()
# Info sur les types
print("- Infos sur les types : ")
df_tarifs.info()
print()
## Appercu des donnees
print("- Appercu des donnees : ")
df_tarifs.head()
# Out:
# - Shape: (10, 4)
# - Colonnes: ['date_debut', 'date_fin', 'type_energie', 'tarif_unitaire']
#
# - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date_debut      10 non-null     str
#  1   date_fin        10 non-null     str
#  2   type_energie    10 non-null     str
#  3   tarif_unitaire  10 non-null     float64
# dtypes: float64(1), str(3)
# memory usage: 714.0 bytes
#
# - Appercu des donnees :
#    date_debut    date_fin type_energie  tarif_unitaire
# 0  2023-01-01  2023-06-30  electricite            0.18
# 1  2023-07-01  2023-12-31  electricite            0.20
# 2  2023-01-01  2023-06-30          gaz            0.09
# 3  2023-07-01  2023-12-31          gaz            0.10
# 4  2023-01-01  2023-12-31          eau            3.50

# %% [markdown]
# ---

# %% [markdown]
# ## Fusionner avec les donnees meteo (sur commune et timestamp arrondi a l'heure)

# %%
## Preparer les donnees pour la fusion

## Verifier si les donnees de consommation sont vides
if len(df_consommations) == 0:
    print("ATTENTION: Les donnees de consommation sont vides!")
    print("Veuillez d'abord executer le notebook 02 pour generer les donnees Parquet.")
    # Creer un DataFrame vide avec les bonnes colonnes pour eviter les erreurs
    df_consommations['datetime_hour'] = pd.to_datetime([])
else:
    ## Pour la consommation: creer une colonne datetime arrondie a l'heure
    if 'date' in df_consommations.columns and 'hour' in df_consommations.columns:
        df_consommations['datetime_hour'] = pd.to_datetime(
            df_consommations['date'].astype(str) + ' ' + df_consommations['hour'].astype(str) + ':00:00'
        )
    elif 'timestamp_start' in df_consommations.columns:
        df_consommations['datetime_hour'] = df_consommations['timestamp_start'].dt.floor('h')
    elif 'timestamp' in df_consommations.columns:
        df_consommations['datetime_hour'] = df_consommations['timestamp'].dt.floor('h')
    else:
        print("- ERREUR: Aucune colonne temporelle trouvee dans df_consommation")
        df_consommations['datetime_hour'] = pd.to_datetime([])

## Pour la meteo: arrondir a l'heure
df_weather['timestamp'] = pd.to_datetime(
    df_weather['timestamp'],
    errors='coerce'
)

df_weather['datetime_hour'] = df_weather['timestamp'].dt.floor('h')

if len(df_consommations) > 0:
    print(f"- Consommations : {df_consommations['datetime_hour'].min()} -> {df_consommations['datetime_hour'].max()}")
print(f"- Meteo: {df_weather['datetime_hour'].min()} -> {df_weather['datetime_hour'].max()}")
# Out:
# - Consommations : 2023-01-01 00:00:00 -> 2024-12-31 01:00:00
# - Meteo: 2023-01-01 00:00:00 -> 2024-12-31 23:00:00

# %%
## Agreger la meteo par commune et heure (au cas ou il y aurait des doublons)
df_weather_hourly = df_weather.groupby(['commune', 'datetime_hour']).agg({
    'temperature_c': 'mean', # → smooths multiple measurements in the same hour
    'humidite_pct': 'mean',
    'vitesse_vent_kmh': 'mean',
    'precipitation_mm': 'sum', # → correct: rainfall accumulates
    'precipitation_mm': 'first', # → assumes these don’t change within the hour
    'saison': 'first'
}).reset_index() # Converts group keys back into normal columns => Makes the DataFrame easier to work with later

print(f"- Meteo agregee: {len(df_weather_hourly):,} lignes")
# Out:
# - Meteo agregee: 252,612 lignes

# %%
## Fusion sur commune et datetime_hour
if len(df_consommations) == 0:
    print("ERREUR: Impossible de fusionner - les donnees de consommations sont vides!")
    print("Veuillez d'abord executer le notebook 02_nettoyage_spark.ipynb")
    df_merged = pd.DataFrame()
else:
    df_merged = df_consommations.merge(
        df_weather_hourly,
        on=['commune', 'datetime_hour'],
        how='left'
    )

    print(f"\nResultat de la fusion:")
    print(f"  - Lignes consommations: {len(df_consommations):,}")
    print(f"  - Lignes apres fusion: {len(df_merged):,}")
    print(f"  - Lignes avec meteo: {df_merged['temperature_c'].notna().sum():,}")
    print(f"  - Lignes sans meteo: {df_merged['temperature_c'].isna().sum():,}")
# Out:
# Resultat de la fusion:
#   - Lignes consommations: 320,178
#   - Lignes apres fusion: 320,178
#   - Lignes avec meteo: 307,733
#   - Lignes sans meteo: 12,445

# %%
## Apercu du dataset fusionne
df_merged.head(10)
# Out:
#   batiment_id unite  year  month timestamp_start  consommation_mean  \
# 0     BAT0029    m3  2023      1      2023-01-01               1.60
# 1     BAT0003    m3  2023      1      2023-01-01               1.41
# 2     BAT0096    m3  2023      1      2023-01-01               0.24
# 3     BAT0036    m3  2023      1      2023-01-01              12.14
# 4     BAT0004    m3  2023      1      2023-01-01               2.34
# 5     BAT0034    m3  2023      1      2023-01-01               2.57
# 6     BAT0131    m3  2023      1      2023-01-01               1.73
# 7     BAT0018    m3  2023      1      2023-01-01               1.34
# 8     BAT0070    m3  2023      1      2023-01-01               1.31
# 9     BAT0005    m3  2023      1      2023-01-01             305.53
#
#    consommation_min  consommation_max  measurement_count  \
# 0              0.14              3.38                 24
# 1              0.13              2.74                 24
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Fusionner avec le referentiel batiments

# %%
df_conso_bat = df_merged.merge(
        df_batiments,
        on=['batiment_id'],
        how='left'
)

## Affichage de quelques infos
print(f"- Shape: {df_conso_bat.shape}")
print(f"- Colonnes: {df_conso_bat.columns.tolist()}")
df_conso_bat.head(10)
# Out:
# - Shape: (320178, 27)
# - Colonnes: ['batiment_id', 'unite', 'year', 'month', 'timestamp_start', 'consommation_mean', 'consommation_min', 'consommation_max', 'measurement_count', 'nom_x', 'commune_x', 'type_x', 'date', 'type_energie', 'datetime_hour', 'temperature_c', 'humidite_pct', 'vitesse_vent_kmh', 'precipitation_mm', 'saison', 'nom_y', 'type_y', 'commune_y', 'surface_m2', 'annee_construction', 'classe_energetique', 'nb_occupants_moyen']
#   batiment_id unite  year  month timestamp_start  consommation_mean  \
# 0     BAT0029    m3  2023      1      2023-01-01               1.60
# 1     BAT0003    m3  2023      1      2023-01-01               1.41
# 2     BAT0096    m3  2023      1      2023-01-01               0.24
# 3     BAT0036    m3  2023      1      2023-01-01              12.14
# 4     BAT0004    m3  2023      1      2023-01-01               2.34
# 5     BAT0034    m3  2023      1      2023-01-01               2.57
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Fusionner avec les tarifs pour calculer le cout financier

# %%
df_merge = df_conso_bat.merge(df_tarifs, on="type_energie", how="left")

for col in ["date", "date_debut", "date_fin"]:
    df_merge[col] = pd.to_datetime(df_merge[col].astype(str), errors="coerce")

df_merge = df_merge[
    (df_merge["date"] >= df_merge["date_debut"]) &
    (df_merge["date"] <= df_merge["date_fin"])
]

df_merge["cout_financier"] = (
    df_merge["consommation_mean"] * df_merge["tarif_unitaire"]
)
df_merge.head(10)
# Out:
#    batiment_id unite  year  month timestamp_start  consommation_mean  \
# 0      BAT0029    m3  2023      1      2023-01-01               1.60
# 2      BAT0003    m3  2023      1      2023-01-01               1.41
# 4      BAT0096    m3  2023      1      2023-01-01               0.24
# 6      BAT0036    m3  2023      1      2023-01-01              12.14
# 8      BAT0004    m3  2023      1      2023-01-01               2.34
# 10     BAT0034    m3  2023      1      2023-01-01               2.57
# 12     BAT0131    m3  2023      1      2023-01-01               1.73
# 14     BAT0018    m3  2023      1      2023-01-01               1.34
# 16     BAT0070    m3  2023      1      2023-01-01               1.31
# 18     BAT0005    m3  2023      1      2023-01-01             305.53
#
#     consommation_min  consommation_max  measurement_count  \
# 0               0.14              3.38                 24
# 2               0.13              2.74                 24
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Creer des features derivees :
#   - Consommation par occupant
#   - Consommation par m2
#   - Cout journalier, mensuel, annuel
#   - Indice de performance energetique (IPE)
#   - Ecart a la moyenne de la categorie

# %%
## Consommation par occupant
print("- Consommation par occupant :")
df_merge["conso_par_occupant"] = (
    df_merge["consommation_mean"] / df_merge["nb_occupants_moyen"]
).replace([float("inf"), -float("inf")], pd.NA)
df_merge.head()
# Out:
# - Consommation par occupant :
#   batiment_id unite  year  month timestamp_start  consommation_mean  \
# 0     BAT0029    m3  2023      1      2023-01-01               1.60
# 2     BAT0003    m3  2023      1      2023-01-01               1.41
# 4     BAT0096    m3  2023      1      2023-01-01               0.24
# 6     BAT0036    m3  2023      1      2023-01-01              12.14
# 8     BAT0004    m3  2023      1      2023-01-01               2.34
#
#    consommation_min  consommation_max  measurement_count  \
# 0              0.14              3.38                 24
# 2              0.13              2.74                 24
# 4              0.02              0.46                 24
# 6              1.41             26.12                 24
# 8              0.23              5.29                 23
#
#                      nom_x  commune_x       type_x       date type_energie  \
# 0       Ecole Marseille 29  Marseille        ecole 2023-01-01          eau
# ...

# %%
## Consommation par m²
df_merge["conso_par_m2"] = (
    df_merge["consommation_mean"] / df_merge["surface_m2"]
).replace([float("inf"), -float("inf")], pd.NA)

## Coûts temporels
    # Coût journalier
df_merge["cout_journalier"] = df_merge["cout_financier"]
    # Coût mensuel
df_cout_mensuel = (
    df_merge
    .groupby(
        ["batiment_id", "year", "month", "type_energie"],
        as_index=False
    )
    .agg(cout_mensuel=("cout_financier", "sum"))
)
    # Coût annuel
df_cout_annuel = (
    df_merge
    .groupby(
        ["batiment_id", "year", "type_energie"],
        as_index=False
    )
    .agg(cout_annuel=("cout_financier", "sum"))
)

    # Indice de Performance Énergétique (IPE) (IPE = consommation annuelle / surface (kWh/m²/an))
        # conso annuelle
df_conso_annuelle = (
    df_merge
    .groupby(
        ["batiment_id", "year", "type_energie"],
        as_index=False
    )
    .agg(conso_annuelle=("consommation_mean", "sum"))
)
        # Calcul de l’IPE
df_conso_annuelle = df_conso_annuelle.merge(
    df_merge[["batiment_id", "surface_m2"]].drop_duplicates(),
    on="batiment_id",
    how="left"
)

df_conso_annuelle["IPE_kwh_m2_an"] = (
    df_conso_annuelle["conso_annuelle"] / df_conso_annuelle["surface_m2"]
).round(2)

## Écart à la moyenne de la catégorie
    # Moyenne par catégorie
mean_by_category = (
    df_merge
    .groupby("type_y", as_index=False)
    .agg(conso_moyenne_categorie=("conso_par_m2", "mean"))
)
    # Écart absolu et relatif
df_merge = df_merge.merge(
    mean_by_category,
    on="type_y",
    how="left"
)

df_merge["ecart_moyenne_categorie"] = (
    df_merge["conso_par_m2"] - df_merge["conso_moyenne_categorie"]
)

df_merge["ecart_moyenne_categorie_pct"] = (
    df_merge["ecart_moyenne_categorie"] / df_merge["conso_moyenne_categorie"]
).round(2)

df_merge.head()
# Out:
#   batiment_id unite  year  month timestamp_start  consommation_mean  \
# 0     BAT0029    m3  2023      1      2023-01-01               1.60
# 1     BAT0003    m3  2023      1      2023-01-01               1.41
# 2     BAT0096    m3  2023      1      2023-01-01               0.24
# 3     BAT0036    m3  2023      1      2023-01-01              12.14
# 4     BAT0004    m3  2023      1      2023-01-01               2.34
#
#    consommation_min  consommation_max  measurement_count  \
# 0              0.14              3.38                 24
# 1              0.13              2.74                 24
# 2              0.02              0.46                 24
# 3              1.41             26.12                 24
# 4              0.23              5.29                 23
#
#                      nom_x  commune_x       type_x       date type_energie  \
# 0       Ecole Marseille 29  Marseille        ecole 2023-01-01          eau
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Creation de consommations_enrichies.csv & consommations_enrichies.parquet

# %%
csv_consommations_enrichies_path = os.path.join(OUTPUT_DIR,"consommations_enrichies.csv")
parquet_consommations_enrichies_path = os.path.join(OUTPUT_DIR,"consommations_enrichies.parquet")

## Écriture en CSV
df_merge.to_csv(csv_consommations_enrichies_path, index=False)

## Écriture en Parquet
df_merge.to_parquet(
    parquet_consommations_enrichies_path,
    engine="pyarrow",
    index=False
)
