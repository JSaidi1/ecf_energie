# %% [markdown]
# # Etape 1.3 : Agregations avancees Spark
#
# ---
# ---

# %% [markdown]
# ## Imports

# %%
import sys
import os
import platform
from pathlib import Path
from pyspark.sql import SparkSession, functions as F, Window

# %% [markdown]
# ---

# %% [markdown]
# ## Chemins des données

# %%
# ==============================================================================================================
#                                                    DIRS
# ==============================================================================================================
DATA_DIR_PATH = (Path.cwd() / ".." / "data").resolve()
OUTPUT_DIR_PATH = (Path.cwd() / ".." / "output").resolve()

# ==============================================================================================================
#                                                   INPUTS
# ==============================================================================================================
IN_BAT_PATH = os.path.join(DATA_DIR_PATH, "batiments.csv")
IN_CONSO_CLEAN_PATH = os.path.join(OUTPUT_DIR_PATH, "02_consommations_clean") # parquet partitionné

# Check if inputs exists:
if not os.path.exists(IN_BAT_PATH):
    print("Error: IN_BAT_PATH does not exist:", IN_BAT_PATH)
    sys.exit(1)
if not os.path.exists(IN_CONSO_CLEAN_PATH):
    print("Error: IN_CONSO_CLEAN_PATH does not exist:", IN_CONSO_CLEAN_PATH)
    sys.exit(1)

# ==============================================================================================================
#                                                   OUTPUTS
# ==============================================================================================================
OUT_AGG_PARQUET =  os.path.join(OUTPUT_DIR_PATH, "consommations_agregees.parquet")

# %% [markdown]
# ---

# %% [markdown]
# ## Création d'une session Spark locale

# %%
# --- Creer une session Spark locale
spark = SparkSession.builder \
    .appName("ECF 2 - ENERGIE - Etape 1.3 : Agregations avancees Spark") \
    .master("local[*]") \
    .config("spark.driver.memory", "4g") \
    .config("spark.sql.shuffle.partitions", "8") \
    .getOrCreate()

# Reduire les logs
spark.sparkContext.setLogLevel("WARN")

# Affichage de l'actuelle version de Spark & de l'url de Spark UI ainsi que python & java
print(f"Spark version  : {spark.version}")
print(f"Spark UI       : {spark.sparkContext.uiWebUrl}")
print()
print(f"Hadoop version : {spark._jvm.org.apache.hadoop.util.VersionInfo.getVersion()}")
print(f"Hadoop home    : {spark._jvm.java.lang.System.getenv('HADOOP_HOME')}")
print()
print(f"Python version : {platform.python_version()}")
print(f"Python path    : { sys.executable}")
print()
print(f"Java version   : {spark._jvm.java.lang.System.getProperty('java.version')}")
print(f"Java home      : { spark._jvm.java.lang.System.getProperty('java.home')}")

# Check du module winutils.exe
print()
if os.path.exists(os.path.join(os.environ["HADOOP_HOME"], "bin", "winutils.exe")):
        print("[ok]: Hadoop module 'winutils.exe' exists at path:", os.path.join(os.environ["HADOOP_HOME"], "bin", "winutils.exe"))
else:
        print("[ko]: Required hadoop module 'winutils.exe' do not exists")
        sys.exit(1)
# Out:
# Spark version  : 3.5.7
# Spark UI       : http://NvSiecle-3-2.m2iformation.local:4041
#
# Hadoop version : 3.3.4
# Hadoop home    : C:\Users\Administrateur\data-info-m2i\installed-tools\app-big-data\hadoop
#
# Python version : 3.11.9
# Python path    : c:\Users\Administrateur\Desktop\ecf_energie\.venv\Scripts\python.exe
#
# Java version   : 11.0.29
# Java home      : C:\Users\Administrateur\data-info-m2i\installed-tools\languages\java\java-11-0-29
#
# [ok]: Hadoop module 'winutils.exe' exists at path: C:\Users\Administrateur\data-info-m2i\installed-tools\app-big-data\hadoop\bin\winutils.exe

# %% [markdown]
# ---

# %% [markdown]
# ## Chargement des données

# %%
# --- Chargement du référentil bâtiments
df_bat = (spark.read
          .option("header", True)
          .option("inferSchema", True)
          .csv(IN_BAT_PATH))

df_bat.printSchema()
df_bat.show(5, truncate=False)

# Information sur le nombre de lignes et de colonnes
print(f"- Nombre de lignes : {df_bat.count():,}")
print("- Nombre de colonnes :", len(df_bat.columns))
# Out:
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
#
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# |batiment_id|nom                |type       |commune|surface_m2|annee_construction|classe_energetique|nb_occupants_moyen|
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# |BAT0001    |Ecole Paris 1      |ecole      |Paris  |1926      |1978              |E                 |225               |
# |BAT0002    |Ecole Paris 2      |ecole      |Paris  |1156      |2004              |C                 |402               |
# |BAT0003    |Ecole Paris 3      |ecole      |Paris  |1695      |2014              |D                 |219               |
# |BAT0004    |Mediatheque Paris 4|mediatheque|Paris  |907       |2019              |C                 |121               |
# |BAT0005    |Piscine Paris 5    |piscine    |Paris  |3913      |1950              |G                 |242               |
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# only showing top 5 rows
#
# - Nombre de lignes : 146
# - Nombre de colonnes : 8

# %%
# --- Chargement des données de consommation clean (à partir du parquet consommations_clean)
df_conso = spark.read.parquet(IN_CONSO_CLEAN_PATH)

# Information sur le schema, nombre de lignes et de colonnes
df_conso.printSchema()
df_conso.show(5, truncate=False)
print(f"- Nombre de lignes : {df_conso.count():,}")
print("- Nombre de colonnes :", len(df_conso.columns))
# Out:
# root
#  |-- batiment_id: string (nullable = true)
#  |-- heure: integer (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- type_energie: string (nullable = true)
#
# +-----------+-----+--------------------+-----+----------+------------+
# |batiment_id|heure|consommation_moyenne|unite|date      |type_energie|
# +-----------+-----+--------------------+-----+----------+------------+
# |BAT0001    |1    |2.88                |kWh  |2024-03-31|electricite |
# |BAT0001    |9    |39.42               |kWh  |2024-03-31|electricite |
# |BAT0001    |10   |48.8                |kWh  |2024-03-31|electricite |
# |BAT0002    |10   |23.78               |kWh  |2024-03-31|electricite |
# |BAT0002    |13   |17.69               |kWh  |2024-03-31|electricite |
# +-----------+-----+--------------------+-----+----------+------------+
# only showing top 5 rows
#
# - Nombre de lignes : 6,996,788
# - Nombre de colonnes : 6

# %% [markdown]
# ---

# %% [markdown]
# ## Joindre consommations avec referentiel batiments

# %%
df_join = df_conso.join(df_bat, on="batiment_id", how="left").select("batiment_id", "nom", "type", "surface_m2", "nb_occupants_moyen", "commune", "annee_construction", "classe_energetique", "date", "type_energie", "consommation_moyenne", "unite")

# Information sur le schema, nombre de lignes et de colonnes
print("Infos sur df_join : ")
df_join.printSchema()
df_join.show(5, truncate=False)
print(f"- Nombre de lignes : {df_join.count():,}")
print("- Nombre de colonnes :", len(df_join.columns))

# Contrôle qualité jointure
print()
print("Contrôle qualité jointure :")
unmatched = df_join.filter(F.col("nom").isNull()).select("batiment_id").distinct().count()
if unmatched == 0:
    print("[ok]: Batiments non matchés (id inconnus) :", unmatched)
else:
    print("[ko]: Batiments non matchés (id inconnus) :", unmatched)
# Out:
# Infos sur df_join :
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- type_energie: string (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
#
# +-----------+-------------+-----+----------+------------------+-------+------------------+------------------+----------+------------+--------------------+-----+
# |batiment_id|nom          |type |surface_m2|nb_occupants_moyen|commune|annee_construction|classe_energetique|date      |type_energie|consommation_moyenne|unite|
# +-----------+-------------+-----+----------+------------------+-------+------------------+------------------+----------+------------+--------------------+-----+
# |BAT0001    |Ecole Paris 1|ecole|1926      |225               |Paris  |1978              |E                 |2024-03-31|electricite |2.88                |kWh  |
# |BAT0001    |Ecole Paris 1|ecole|1926      |225               |Paris  |1978              |E                 |2024-03-31|electricite |39.42               |kWh  |
# |BAT0001    |Ecole Paris 1|ecole|1926      |225               |Paris  |1978              |E                 |2024-03-31|electricite |48.8                |kWh  |
# |BAT0002    |Ecole Paris 2|ecole|1156      |402               |Paris  |2004              |C                 |2024-03-31|electricite |23.78               |kWh  |
# |BAT0002    |Ecole Paris 2|ecole|1156      |402               |Paris  |2004              |C                 |2024-03-31|electricite |17.69               |kWh  |
# +-----------+-------------+-----+----------+------------------+-------+------------------+------------------+----------+------------+--------------------+-----+
# only showing top 5 rows
#
# - Nombre de lignes : 6,996,788
# - Nombre de colonnes : 12
#
# Contrôle qualité jointure :
# [ok]: Batiments non matchés (id inconnus) : 0

# %% [markdown]
# ---

# %% [markdown]
# ## Calculer l'intensite energetique (kWh/m2)
# ``kWh/m²`` n’a du sens que pour l’électricité + gaz (pas pour l’eau en m³).
# => Donc on calcule ``intensite_kwh_m2`` uniquement sur electricite et gaz.

# %%
df_journaliere = df_join.withColumn(
    "intensite_kwh_m2",
    F.when(F.col("type_energie").isin("electricite", "gaz"),
           F.col("consommation_moyenne") / F.col("surface_m2"))
     .otherwise(F.lit(None))
)

# Information sur le schema, nombre de lignes et de colonnes
print("Infos sur df_journaliere : ")
df_journaliere.printSchema()
df_journaliere.show(5, truncate=False)
print(f"- Nombre de lignes : {df_journaliere.count():,}")
print("- Nombre de colonnes :", len(df_journaliere.columns))
# Out:
# Infos sur df_journaliere :
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- type_energie: string (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
#  |-- intensite_kwh_m2: double (nullable = true)
#
# +-----------+-------------+-----+----------+------------------+-------+------------------+------------------+----------+------------+--------------------+-----+---------------------+
# |batiment_id|nom          |type |surface_m2|nb_occupants_moyen|commune|annee_construction|classe_energetique|date      |type_energie|consommation_moyenne|unite|intensite_kwh_m2     |
# +-----------+-------------+-----+----------+------------------+-------+------------------+------------------+----------+------------+--------------------+-----+---------------------+
# |BAT0001    |Ecole Paris 1|ecole|1926      |225               |Paris  |1978              |E                 |2024-03-31|electricite |2.88                |kWh  |0.0014953271028037382|
# |BAT0001    |Ecole Paris 1|ecole|1926      |225               |Paris  |1978              |E                 |2024-03-31|electricite |39.42               |kWh  |0.02046728971962617  |
# |BAT0001    |Ecole Paris 1|ecole|1926      |225               |Paris  |1978              |E                 |2024-03-31|electricite |48.8                |kWh  |0.025337487019730008 |
# |BAT0002    |Ecole Paris 2|ecole|1156      |402               |Paris  |2004              |C                 |2024-03-31|electricite |23.78               |kWh  |0.020570934256055363 |
# |BAT0002    |Ecole Paris 2|ecole|1156      |402               |Paris  |2004              |C                 |2024-03-31|electricite |17.69               |kWh  |0.015302768166089966 |
# +-----------+-------------+-----+----------+------------------+-------+------------------+------------------+----------+------------+--------------------+-----+---------------------+
# only showing top 5 rows
#
# - Nombre de lignes : 6,996,788
# - Nombre de colonnes : 13

# %% [markdown]
# ---

# %% [markdown]
# ## Identifier les batiments hors norme (>3x la mediane de leur categorie)
# 'Catégorie' => type de bâtiment (ecole, mairie, etc.).
# On calcule la médiane de l’intensité par type et type_energie, puis on marque hors norme.
#
# => En Spark, médiane = percentile_approx(col, 0.5) (standard).

# %%
df_med = (df_journaliere
    .filter(F.col("type_energie").isin("electricite", "gaz"))
    .groupBy("type", "type_energie")
    .agg(F.expr("percentile_approx(intensite_kwh_m2, 0.5)").alias("mediane_intensite"))
)

df_scored = (df_journaliere
    .join(df_med, on=["type", "type_energie"], how="left")
    .withColumn(
        "hors_norme",
        F.when(
            (F.col("type_energie").isin("electricite", "gaz")) &
            (F.col("intensite_kwh_m2") > 3 * F.col("mediane_intensite")),
            F.lit(True)
        ).otherwise(F.lit(False))
    )
)

# Top batiments les plus hors norme :
df_outliers = (df_scored
    .filter(F.col("hors_norme") == True)
    .select("batiment_id","nom","type","commune","date","type_energie","consommation_moyenne","surface_m2",
            "intensite_kwh_m2","mediane_intensite")
    .orderBy(F.desc("intensite_kwh_m2"))
)

df_outliers.show(20, truncate=False)
# Out:
# +-----------+-------------------------+-------+-------------+----------+------------+--------------------+----------+------------------+-------------------+
# |batiment_id|nom                      |type   |commune      |date      |type_energie|consommation_moyenne|surface_m2|intensite_kwh_m2  |mediane_intensite  |
# +-----------+-------------------------+-------+-------------+----------+------------+--------------------+----------+------------------+-------------------+
# |BAT0005    |Piscine Paris 5          |piscine|Paris        |2024-12-25|gaz         |6348.19             |3913      |1.6223332481472015|0.35770752384316495|
# |BAT0122    |Piscine Le Havre 122     |piscine|Le Havre     |2024-11-06|gaz         |2561.65             |1579      |1.622324255858138 |0.35770752384316495|
# |BAT0112    |Piscine Reims 112        |piscine|Reims        |2023-11-04|gaz         |5021.01             |3095      |1.622297253634895 |0.35770752384316495|
# |BAT0122    |Piscine Le Havre 122     |piscine|Le Havre     |2024-12-17|gaz         |2561.57             |1579      |1.622273590880304 |0.35770752384316495|
# |BAT0005    |Piscine Paris 5          |piscine|Paris        |2024-01-13|gaz         |6347.45             |3913      |1.6221441349348327|0.35770752384316495|
# |BAT0121    |Piscine Le Havre 121     |piscine|Le Havre     |2024-12-31|gaz         |4280.28             |2639      |1.621932550208412 |0.35770752384316495|
# |BAT0134    |Piscine Saint-Etienne 134|piscine|Saint-Etienne|2023-01-30|gaz         |3447.93             |2126      |1.6217920978363123|0.35770752384316495|
# |BAT0121    |Piscine Le Havre 121     |piscine|Le Havre     |2023-12-03|gaz         |4279.88             |2639      |1.6217809776430467|0.35770752384316495|
# |BAT0122    |Piscine Le Havre 122     |piscine|Le Havre     |2023-12-06|gaz         |2560.66             |1579      |1.6216972767574414|0.35770752384316495|
# |BAT0005    |Piscine Paris 5          |piscine|Paris        |2023-12-23|gaz         |6345.51             |3913      |1.6216483516483517|0.35770752384316495|
# |BAT0134    |Piscine Saint-Etienne 134|piscine|Saint-Etienne|2024-12-03|gaz         |3447.51             |2126      |1.6215945437441206|0.35770752384316495|
# |BAT0043    |Piscine Bordeaux 43      |piscine|Bordeaux     |2023-01-19|gaz         |3695.56             |2279      |1.6215708644142168|0.35770752384316495|
# |BAT0122    |Piscine Le Havre 122     |piscine|Le Havre     |2024-01-01|gaz         |2560.22             |1579      |1.6214186193793538|0.35770752384316495|
# |BAT0122    |Piscine Le Havre 122     |piscine|Le Havre     |2023-02-19|gaz         |2560.14             |1579      |1.6213679544015198|0.35770752384316495|
# |BAT0048    |Piscine Lille 48         |piscine|Lille        |2024-02-14|gaz         |6086.58             |3754      |1.6213585508790622|0.35770752384316495|
# |BAT0048    |Piscine Lille 48         |piscine|Lille        |2023-01-04|gaz         |6086.25             |3754      |1.6212706446457112|0.35770752384316495|
# |BAT0005    |Piscine Paris 5          |piscine|Paris        |2023-11-13|gaz         |6343.9              |3913      |1.6212369026322513|0.35770752384316495|
# |BAT0112    |Piscine Reims 112        |piscine|Reims        |2024-02-23|gaz         |5017.66             |3095      |1.6212148626817446|0.35770752384316495|
# |BAT0112    |Piscine Reims 112        |piscine|Reims        |2023-12-08|gaz         |5017.58             |3095      |1.62118901453958  |0.35770752384316495|
# |BAT0121    |Piscine Le Havre 121     |piscine|Le Havre     |2024-01-06|gaz         |4278.11             |2639      |1.6211102690413035|0.35770752384316495|
# +-----------+-------------------------+-------+-------------+----------+------------+--------------------+----------+------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ---

# %% [markdown]
# ## Calculer les totaux par commune et par type de batiment

# %%
# --- Total par commune et type de bâtiment (toutes énergies confondues) :
print("=> Total par commune et type de bâtiment (toutes énergies confondues) : ")
df_tot_commune_typebat = (
    df_join
    .groupBy("commune", "type")
    .agg(
        F.sum("consommation_moyenne").alias("consommation_totale"),
        F.countDistinct("batiment_id").alias("nb_batiments")
    )
    .orderBy("commune", "type")
)

df_tot_commune_typebat.show(truncate=False)
# Out:
# => Total par commune et type de bâtiment (toutes énergies confondues) :
# +---------+-----------+--------------------+------------+
# |commune  |type       |consommation_totale |nb_batiments|
# +---------+-----------+--------------------+------------+
# |Bordeaux |ecole      |1.067598615E7       |2           |
# |Bordeaux |gymnase    |1.1874866410000006E7|1           |
# |Bordeaux |mairie     |6602388.669999997   |3           |
# |Bordeaux |mediatheque|8469111.090000002   |1           |
# |Bordeaux |piscine    |3.617180499000002E7 |1           |
# |Le Havre |ecole      |1.203518457E7       |2           |
# |Le Havre |gymnase    |1.0926127779999997E7|1           |
# |Le Havre |mairie     |2270645.6599999988  |2           |
# |Le Havre |mediatheque|3489806.2999999984  |1           |
# |Le Havre |piscine    |1.5120684846000004E8|5           |
# |Lille    |gymnase    |9205507.8           |1           |
# |Lille    |mairie     |1851516.7899999993  |1           |
# |Lille    |mediatheque|5770757.299999999   |3           |
# |Lille    |piscine    |1.2096002578E8      |3           |
# |Lyon     |ecole      |2.0775376160000004E7|4           |
# |Lyon     |gymnase    |4.0568800619999975E7|3           |
# |Lyon     |mairie     |1.049281748E7       |3           |
# |Lyon     |mediatheque|6265302.930000001   |1           |
# |Lyon     |piscine    |4.191958550999993E7 |1           |
# |Marseille|ecole      |2.1435816240000002E7|4           |
# +---------+-----------+--------------------+------------+
# only showing top 20 rows

# %%
# --- Total par commune et type de bâtiment (pour chaque type d'énergies) :
print("=> Total par commune et type de bâtiment (pour chaque type d'énergies) : ")
df_tot_commune_typebat_energie = (
    df_join
    .groupBy("commune", "type", "type_energie")
    .agg(
        F.sum("consommation_moyenne").alias("consommation_totale"),
        F.countDistinct("batiment_id").alias("nb_batiments"),
        F.first("unite").alias("unite")
    )
    .select(
        "commune", "type", "type_energie", "consommation_totale", "unite"
    )
)

df_tot_commune_typebat_energie.show(truncate=False)
# Out:
# => Total par commune et type de bâtiment (pour chaque type d'énergies) :
# +--------+-----------+------------+--------------------+-----+
# |commune |type       |type_energie|consommation_totale |unite|
# +--------+-----------+------------+--------------------+-----+
# |Bordeaux|gymnase    |gaz         |6928381.880000006   |kWh  |
# |Bordeaux|mediatheque|eau         |174061.4100000002   |m3   |
# |Bordeaux|mediatheque|gaz         |4877140.059999999   |kWh  |
# |Bordeaux|piscine    |gaz         |1.9955536960000005E7|kWh  |
# |Le Havre|ecole      |electricite |4710374.369999997   |kWh  |
# |Le Havre|ecole      |gaz         |7062311.120000004   |kWh  |
# |Le Havre|gymnase    |eau         |301920.0599999996   |m3   |
# |Le Havre|gymnase    |electricite |4263100.189999998   |kWh  |
# |Le Havre|mairie     |eau         |39838.17000000003   |m3   |
# |Le Havre|piscine    |eau         |1.2332294330000013E7|m3   |
# |Le Havre|piscine    |gaz         |8.335350626000006E7 |kWh  |
# |Lille   |gymnase    |electricite |3580991.630000003   |kWh  |
# |Lille   |gymnase    |gaz         |5369408.020000001   |kWh  |
# |Lille   |mairie     |eau         |32290.39999999999   |m3   |
# |Lille   |mediatheque|eau         |118798.14000000004  |m3   |
# |Lille   |mediatheque|electricite |2324706.550000003   |kWh  |
# |Lyon    |ecole      |eau         |451591.79999999993  |m3   |
# |Lyon    |ecole      |gaz         |1.219054791000001E7 |kWh  |
# |Lyon    |gymnase    |eau         |1125013.8999999997  |m3   |
# |Lyon    |gymnase    |gaz         |2.369097489999998E7 |kWh  |
# +--------+-----------+------------+--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ---

# %% [markdown]
# ## Creer une vue SQL exploitable

# %%
# Création d’une vue SQL permettant l’exploration des consommations agrégées par commune et type de bâtiment.
df_tot_commune_typebat.createOrReplaceTempView("vw_totaux_commune_type")

# démo :
spark.sql("""
SELECT *
FROM vw_totaux_commune_type
ORDER BY consommation_totale DESC
LIMIT 10;
""").show(truncate=False)
# Out:
# +-------------+-------+--------------------+------------+
# |commune      |type   |consommation_totale |nb_batiments|
# +-------------+-------+--------------------+------------+
# |Toulon       |piscine|2.0458342419000006E8|6           |
# |Le Havre     |piscine|1.5120684846000004E8|5           |
# |Lille        |piscine|1.2096002578E8      |3           |
# |Saint-Etienne|piscine|8.091685260000004E7 |2           |
# |Paris        |piscine|6.223831664000006E7 |1           |
# |Nice         |piscine|6.070507642000004E7 |3           |
# |Marseille    |piscine|6.0335302529999964E7|2           |
# |Rennes       |piscine|4.971365140999999E7 |2           |
# |Reims        |piscine|4.898747136999999E7 |1           |
# |Lyon         |piscine|4.191958550999993E7 |1           |
# +-------------+-------+--------------------+------------+

# %%
# Création d’une autre vue SQL permettant l’exploration des consommations agrégées par commune et type de bâtiment (par type d'energie).
df_tot_commune_typebat_energie.createOrReplaceTempView("vw_totaux_commune_type_energie")

# démo :
spark.sql("""
SELECT *
FROM vw_totaux_commune_type_energie
ORDER BY consommation_totale DESC
LIMIT 10;
""").show(truncate=False)
# Out:
# +-------------+-------+------------+--------------------+-----+
# |commune      |type   |type_energie|consommation_totale |unite|
# +-------------+-------+------------+--------------------+-----+
# |Toulon       |piscine|gaz         |1.1268752067000002E8|kWh  |
# |Le Havre     |piscine|gaz         |8.335350626000006E7 |kWh  |
# |Toulon       |piscine|electricite |7.515912852999991E7 |kWh  |
# |Lille        |piscine|gaz         |6.6618435739999995E7|kWh  |
# |Le Havre     |piscine|electricite |5.552104786999998E7 |kWh  |
# |Saint-Etienne|piscine|gaz         |4.454200539E7       |kWh  |
# |Lille        |piscine|electricite |4.4438357329999976E7|kWh  |
# |Paris        |piscine|gaz         |3.435952024000002E7 |kWh  |
# |Nice         |piscine|gaz         |3.3417021550000012E7|kWh  |
# |Marseille    |piscine|gaz         |3.332502965999999E7 |kWh  |
# +-------------+-------+------------+--------------------+-----+

# %% [markdown]
# ---

# %% [markdown]
# ## Table agregee consommations_agregees.parquet

# %%
df_tot_commune_typebat_energie.coalesce(1).write.mode("overwrite").parquet(OUT_AGG_PARQUET)
#df_tot_commune_typebat_energie.write.mode("overwrite").parquet(OUT_AGG_PARQUET)
print(f"[ok]: Creation avec succès de la table agregee consommations_agregees.parquet : {OUT_AGG_PARQUET}")
# Out:
# [ok]: Creation avec succès de la table agregee consommations_agregees.parquet : C:\Users\Administrateur\Desktop\ecf_energie\output\consommations_agregees.parquet

# %% [markdown]
# ---

# %% [markdown]
# ## Fermer la session Spark

# %%
spark.stop()
