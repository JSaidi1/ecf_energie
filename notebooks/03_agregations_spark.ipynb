# %% [markdown]
# # Etape 1.3 : Agregations avancees Spark
#
# **Livrables** :
# - Ce notebook `03_agregations_spark.ipynb`
# - Table agregee `03_consommations_agregees.parquet`
# - Requetes Spark SQL demonstrant l'utilisation de la vue
#
# ---
# ---

# %% [markdown]
# ## Imports

# %%
import sys
import os
import platform
from pathlib import Path
import time
from datetime import datetime
import psutil
from pyspark.sql import SparkSession, functions as F, Window

# %% [markdown]
# ---

# %% [markdown]
# ## (optionnel) Enregistrement de la date de la dernière execution de ce notebook

# %%
print(f"- Date de la dernière execution de ce notebook : {datetime.now().strftime('%d/%m/%Y %H:%M:%S')} (FR)")
# Out:
# - Date de la dernière execution de ce notebook : 20/02/2026 20:32:09 (FR)

# %% [markdown]
# ---

# %% [markdown]
# ## (optionnel) Mesure du temps de traitement global pour ce script - enregistrement de l'heure de début + estimation instantanée des ressources machine libres

# %%
## Heure de début
start_time_03 = time.time()

## Machine: current available RAM (in GB)
ram_available_03 = psutil.virtual_memory().available / (1024**3)

## Machine: current available CPU
logical = psutil.cpu_count()
physical = psutil.cpu_count(logical=False) or logical

cpu_used = psutil.cpu_percent(interval=2)
cpu_available_pct_03 = 100 - cpu_used

available_logical_03 = logical * cpu_available_pct_03 / 100
available_physical_03 = physical * cpu_available_pct_03 / 100

## Show available resources
print(f"- Current machine RAM available : {ram_available_03:.2f} GB")
print(f"- Current machine CPU available : {cpu_available_pct_03:.1f}%")
print(f"    Approx logical cores free  : {available_logical_03:.2f}")
print(f"    Approx physical cores free : {available_physical_03:.2f}")
# Out:
# - Current machine RAM available : 8.31 GB
# - Current machine CPU available : 71.9%
#     Approx logical cores free  : 11.50
#     Approx physical cores free : 5.75

# %% [markdown]
# ---

# %% [markdown]
# ## Chemins des données

# %%
# ==============================================================================================================
#                                                   OUTPUTS
# ==============================================================================================================
OUT_DIR = (Path.cwd() / ".." / "output").resolve()
OUT_CONSO_AGG_PARQUET =  os.path.join(OUT_DIR, "03_consommations_agregees.parquet")

# ==============================================================================================================
#                                                   INPUTS
# ==============================================================================================================
IN_DIR = (Path.cwd() / ".." / "data").resolve()
IN_BAT_CSV = os.path.join(IN_DIR, "batiments.csv")
IN_CONSO_CLEAN_PARQUET = os.path.join(OUT_DIR, "02_consommations_clean") # parquet partitionné

# ==============================================================================================================
#                                                   OTHERS
# ==============================================================================================================
TMP_DIR = (Path.cwd() / ".." / "my_tmp").resolve()
TMP_FILE_TXT = TMP_DIR / "tmp_03_resources.txt" # Enregistrer les metrics pour ce script

# %% [markdown]
# ---

# %% [markdown]
# ## Création d'une session Spark locale

# %%
# --- Creer une session Spark locale
spark = SparkSession.builder \
    .appName("ECF 2 - ENERGIE - Etape 1.3 : Agregations avancees Spark") \
    .master("local[*]") \
    .config("spark.driver.memory", "4g") \
    .config("spark.sql.shuffle.partitions", "8") \
    .getOrCreate()

# Reduire les logs
spark.sparkContext.setLogLevel("WARN")

# Affichage de l'actuelle version de Spark & de l'url de Spark UI ainsi que python & java
print(f"Spark version  : {spark.version}")
print(f"Spark UI       : {spark.sparkContext.uiWebUrl}")
print()
print(f"Hadoop version : {spark._jvm.org.apache.hadoop.util.VersionInfo.getVersion()}")
print(f"Hadoop home    : {spark._jvm.java.lang.System.getenv('HADOOP_HOME')}")
print()
print(f"Python version : {platform.python_version()}")
print(f"Python path    : { sys.executable}")
print()
print(f"Java version   : {spark._jvm.java.lang.System.getProperty('java.version')}")
print(f"Java home      : { spark._jvm.java.lang.System.getProperty('java.home')}")

# Check du module winutils.exe
print()
if os.path.exists(os.path.join(os.environ["HADOOP_HOME"], "bin", "winutils.exe")):
        print("[ok]: Hadoop module 'winutils.exe' exists at path:", os.path.join(os.environ["HADOOP_HOME"], "bin", "winutils.exe"))
else:
        print("[ko]: Required hadoop module 'winutils.exe' do not exists")
        sys.exit(1)
# Out:
# Spark version  : 3.5.7
# Spark UI       : http://joel:4041
#
# Hadoop version : 3.3.4
# Hadoop home    : C:\Users\joel\data-info\dev-tools\data-tools\hadoop
#
# Python version : 3.11.9
# Python path    : C:\Users\joel\Downloads\ecf_energie\.venv\Scripts\python.exe
#
# Java version   : 11.0.28
# Java home      : C:\Users\joel\data-info\dev-tools\languages\java\jdk-11
#
# [ok]: Hadoop module 'winutils.exe' exists at path: C:\Users\joel\data-info\dev-tools\data-tools\hadoop\bin\winutils.exe

# %% [markdown]
# ---

# %% [markdown]
# ## Chargement des données

# %%
# --- Chargement du référentil bâtiments
df_bat = (spark.read
          .option("header", True)
          .option("inferSchema", True)
          .csv(IN_BAT_CSV))

# Information sur le nombre de lignes et de colonnes
print("df_bat :")
print(f"- Nombre de lignes : {df_bat.count():,}")
print("- Nombre de colonnes :", len(df_bat.columns))
print("- Schema :")
df_bat.printSchema()
print("- Apperçu :")
df_bat.show(5, truncate=False)
# Out:
# df_bat :
# - Nombre de lignes : 146
# - Nombre de colonnes : 8
# - Schema :
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
#
# - Apperçu :
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# |batiment_id|nom                |type       |commune|surface_m2|annee_construction|classe_energetique|nb_occupants_moyen|
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# |BAT0001    |Ecole Paris 1      |ecole      |Paris  |1926      |1978              |E                 |225               |
# |BAT0002    |Ecole Paris 2      |ecole      |Paris  |1156      |2004              |C                 |402               |
# |BAT0003    |Ecole Paris 3      |ecole      |Paris  |1695      |2014              |D                 |219               |
# |BAT0004    |Mediatheque Paris 4|mediatheque|Paris  |907       |2019              |C                 |121               |
# |BAT0005    |Piscine Paris 5    |piscine    |Paris  |3913      |1950              |G                 |242               |
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# only showing top 5 rows

# %%
# --- Chargement des données de consommation clean (à partir du parquet consommations_clean)
df_conso = spark.read.parquet(IN_CONSO_CLEAN_PARQUET)

# Information sur le schema, nombre de lignes et de colonnes
print("df_conso :")
print(f"- Nombre de lignes : {df_conso.count():,}")
print("- Nombre de colonnes :", len(df_conso.columns))
print("- Schema :")
df_conso.printSchema()
print("- Apperçu :")
df_conso.show(5, truncate=False)
# Out:
# df_conso :
# - Nombre de lignes : 991
# - Nombre de colonnes : 6
# - Schema :
# root
#  |-- batiment_id: string (nullable = true)
#  |-- heure: integer (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- type_energie: string (nullable = true)
#
# - Apperçu :
# +-----------+-----+--------------------+-----+----------+------------+
# |batiment_id|heure|consommation_moyenne|unite|date      |type_energie|
# +-----------+-----+--------------------+-----+----------+------------+
# |BAT0097    |21   |250.98              |kWh  |2024-09-17|gaz         |
# |BAT0106    |21   |178.72              |kWh  |2024-09-17|gaz         |
# |BAT0141    |21   |199.88              |kWh  |2024-09-17|gaz         |
# |BAT0081    |0    |30.93               |kWh  |2023-11-12|gaz         |
# |BAT0081    |10   |60.31               |kWh  |2023-11-12|gaz         |
# +-----------+-----+--------------------+-----+----------+------------+
# only showing top 5 rows

# %% [markdown]
# ---

# %% [markdown]
# ## Joindre consommations avec referentiel batiments

# %%
df_join = df_conso.join(df_bat, on="batiment_id", how="left").select(
    "batiment_id", 
    "nom", 
    "type", 
    "surface_m2", 
    "nb_occupants_moyen", 
    "commune", 
    "annee_construction", 
    "classe_energetique", 
    "date", 
    "heure",
    "type_energie", 
    "consommation_moyenne", 
    "unite")

# Information sur le schema, nombre de lignes et de colonnes
print("df_join :")
print(f"- Nombre de lignes : {df_join.count():,}")
print("- Nombre de colonnes :", len(df_join.columns))
print("- Schema :")
df_join.printSchema()
print("- Apperçu :")
df_join.show(5, truncate=False)

# Contrôle qualité jointure
print()
print("Contrôle qualité jointure :")
unmatched = df_join.filter(F.col("nom").isNull()).select("batiment_id").distinct().count()
if unmatched == 0:
    print("[ok]: Batiments non matchés (id inconnus) :", unmatched)
else:
    print("[ko]: Batiments non matchés (id inconnus) :", unmatched)
# Out:
# df_join :
# - Nombre de lignes : 991
# - Nombre de colonnes : 13
# - Schema :
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- heure: integer (nullable = true)
#  |-- type_energie: string (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
#
# - Apperçu :
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+-----+------------+--------------------+-----+
# |batiment_id|nom                   |type       |surface_m2|nb_occupants_moyen|commune    |annee_construction|classe_energetique|date      |heure|type_energie|consommation_moyenne|unite|
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+-----+------------+--------------------+-----+
# |BAT0097    |Mediatheque Nice 97   |mediatheque|1186      |41                |Nice       |1980              |G                 |2024-09-17|21   |gaz         |250.98              |kWh  |
# |BAT0106    |Mairie Rennes 106     |mairie     |1272      |77                |Rennes     |1983              |G                 |2024-09-17|21   |gaz         |178.72              |kWh  |
# |BAT0141    |Mediatheque Toulon 141|mediatheque|891       |40                |Toulon     |1980              |G                 |2024-09-17|21   |gaz         |199.88              |kWh  |
# |BAT0081    |Mairie Montpellier 81 |mairie     |1116      |62                |Montpellier|1985              |G                 |2023-11-12|0    |gaz         |30.93               |kWh  |
# |BAT0081    |Mairie Montpellier 81 |mairie     |1116      |62                |Montpellier|1985              |G                 |2023-11-12|10   |gaz         |60.31               |kWh  |
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+-----+------------+--------------------+-----+
# only showing top 5 rows
#
#
# Contrôle qualité jointure :
# [ok]: Batiments non matchés (id inconnus) : 0

# %% [markdown]
# ---

# %% [markdown]
# ## Calculer l'intensite energetique (kWh/m2)
# ``kWh/m²`` n’a du sens que pour l’électricité + gaz (pas pour l’eau en m³).
# => Donc on calcule ``intensite_kwh_m2`` uniquement sur electricite et gaz.

# %%
df = df_join.withColumn(
    "intensite_kwh_m2",
    F.when(F.col("type_energie").isin("electricite", "gaz"),
        F.round(F.col("consommation_moyenne") / F.col("surface_m2"), 3),
    )
    .otherwise(F.lit(None))
)

# Information sur le schema, nombre de lignes et de colonnes
print("df :")
print(f"- Nombre de lignes : {df.count():,}")
print("- Nombre de colonnes :", len(df.columns))
print("- Schema :")
df.printSchema()
print("- Apperçu :")
df.show(500, truncate=False)
# Out:
# df :
# - Nombre de lignes : 991
# - Nombre de colonnes : 14
# - Schema :
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- heure: integer (nullable = true)
#  |-- type_energie: string (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
#  |-- intensite_kwh_m2: double (nullable = true)
#
# - Apperçu :
# +-----------+-----------------------------+-----------+----------+------------------+-------------+------------------+------------------+----------+-----+------------+--------------------+-----+----------------+
# |batiment_id|nom                          |type       |surface_m2|nb_occupants_moyen|commune      |annee_construction|classe_energetique|date      |heure|type_energie|consommation_moyenne|unite|intensite_kwh_m2|
# +-----------+-----------------------------+-----------+----------+------------------+-------------+------------------+------------------+----------+-----+------------+--------------------+-----+----------------+
# |BAT0097    |Mediatheque Nice 97          |mediatheque|1186      |41                |Nice         |1980              |G                 |2024-09-17|21   |gaz         |250.98              |kWh  |0.212           |
# |BAT0106    |Mairie Rennes 106            |mairie     |1272      |77                |Rennes       |1983              |G                 |2024-09-17|21   |gaz         |178.72              |kWh  |0.141           |
# |BAT0141    |Mediatheque Toulon 141       |mediatheque|891       |40                |Toulon       |1980              |G                 |2024-09-17|21   |gaz         |199.88              |kWh  |0.224           |
# |BAT0081    |Mairie Montpellier 81        |mairie     |1116      |62                |Montpellier  |1985              |G                 |2023-11-12|0    |gaz         |30.93               |kWh  |0.028           |
# |BAT0081    |Mairie Montpellier 81        |mairie     |1116      |62                |Montpellier  |1985              |G                 |2023-11-12|10   |gaz         |60.31               |kWh  |0.054           |
# |BAT0125    |Mediatheque Le Havre 125     |mediatheque|812       |60                |Le Havre     |1966              |F                 |2024-05-07|13   |electricite |118.57              |kWh  |0.146           |
# |BAT0070    |Ecole Strasbourg 70          |ecole      |814       |270               |Strasbourg   |1966              |G                 |2024-05-07|8    |electricite |122.68              |kWh  |0.151           |
# |BAT0140    |Gymnase Toulon 140           |gymnase    |1697      |121               |Toulon       |1985              |F                 |2024-05-07|0    |electricite |30.24               |kWh  |0.018           |
# |BAT0043    |Piscine Bordeaux 43          |piscine    |2279      |148               |Bordeaux     |1962              |G                 |2024-05-07|20   |electricite |1066.5              |kWh  |0.468           |
# |BAT0080    |Piscine Montpellier 80       |piscine    |2932      |256               |Montpellier  |1979              |F                 |2024-10-18|8    |electricite |1030.65             |kWh  |0.352           |
# |BAT0022    |Mairie Marseille 22          |mairie     |1343      |83                |Marseille    |1961              |G                 |2024-10-18|1    |electricite |18.14               |kWh  |0.014           |
# |BAT0086    |Ecole Nice 86                |ecole      |2377      |395               |Nice         |1974              |F                 |2024-10-18|16   |electricite |394.75              |kWh  |0.166           |
# |BAT0117    |Mairie Le Havre 117          |mairie     |1257      |36                |Le Havre     |2018              |A                 |2024-10-18|18   |electricite |44.2                |kWh  |0.035           |
# |BAT0052    |Piscine Lille 52             |piscine    |2668      |316               |Lille        |2012              |B                 |2023-07-06|4    |gaz         |49.89               |kWh  |0.019           |
# |BAT0138    |Mediatheque Toulon 138       |mediatheque|1749      |115               |Toulon       |1998              |D                 |2023-07-06|4    |gaz         |14.31               |kWh  |0.008           |
# |BAT0121    |Piscine Le Havre 121         |piscine    |2639      |315               |Le Havre     |1982              |G                 |2024-01-03|5    |gaz         |176.55              |kWh  |0.067           |
# |BAT0093    |Ecole Nice 93                |ecole      |2044      |246               |Nice         |1976              |F                 |2024-01-03|5    |gaz         |64.31               |kWh  |0.031           |
# |BAT0082    |Gymnase Montpellier 82       |gymnase    |1719      |214               |Montpellier  |2015              |C                 |2024-05-22|4    |electricite |19.58               |kWh  |0.011           |
# |BAT0063    |Ecole Nantes 63              |ecole      |1800      |289               |Nantes       |1986              |E                 |2024-05-22|4    |electricite |20.91               |kWh  |0.012           |
# |BAT0141    |Mediatheque Toulon 141       |mediatheque|891       |40                |Toulon       |1980              |G                 |2023-05-24|7    |eau         |6.23                |m3   |NULL            |
# |BAT0010    |Mediatheque Lyon 10          |mediatheque|1240      |103               |Lyon         |1974              |G                 |2023-05-24|7    |eau         |7.82                |m3   |NULL            |
# |BAT0066    |Mairie Nantes 66             |mairie     |841       |34                |Nantes       |1963              |G                 |2023-12-31|20   |eau         |1.09                |m3   |NULL            |
# |BAT0074    |Mairie Strasbourg 74         |mairie     |1180      |36                |Strasbourg   |1955              |F                 |2023-12-31|20   |eau         |1.5                 |m3   |NULL            |
# |BAT0080    |Piscine Montpellier 80       |piscine    |2932      |256               |Montpellier  |1979              |F                 |2023-08-18|17   |eau         |295.31              |m3   |NULL            |
# |BAT0039    |Mediatheque Toulouse 39      |mediatheque|971       |105               |Toulouse     |1978              |E                 |2023-08-18|17   |eau         |4.0                 |m3   |NULL            |
# |BAT0114    |Gymnase Reims 114            |gymnase    |1798      |268               |Reims        |2003              |E                 |2023-07-11|11   |electricite |204.15              |kWh  |0.114           |
# |BAT0061    |Ecole Nantes 61              |ecole      |838       |334               |Nantes       |1962              |E                 |2023-07-11|22   |electricite |54.15               |kWh  |0.065           |
# |BAT0071    |Gymnase Strasbourg 71        |gymnase    |1330      |239               |Strasbourg   |2006              |E                 |2023-07-11|5    |electricite |13.42               |kWh  |0.01            |
# |BAT0146    |Piscine Toulon 146           |piscine    |2609      |256               |Toulon       |1982              |F                 |2024-02-04|15   |gaz         |1399.94             |kWh  |0.537           |
# |BAT0034    |Mediatheque Toulouse 34      |mediatheque|757       |46                |Toulouse     |2010              |D                 |2024-02-04|2    |gaz         |13.72               |kWh  |0.018           |
# |BAT0007    |Gymnase Paris 7              |gymnase    |1209      |73                |Paris        |1998              |C                 |2024-02-04|7    |gaz         |321.97              |kWh  |0.266           |
# |BAT0055    |Mediatheque Lille 55         |mediatheque|1476      |94                |Lille        |2017              |B                 |2024-01-13|11   |electricite |103.22              |kWh  |0.07            |
# |BAT0113    |Mediatheque Reims 113        |mediatheque|1279      |91                |Reims        |1950              |G                 |2024-01-13|19   |electricite |364.46              |kWh  |0.285           |
# |BAT0063    |Ecole Nantes 63              |ecole      |1800      |289               |Nantes       |1986              |E                 |2024-01-13|7    |electricite |45.94               |kWh  |0.026           |
# |BAT0124    |Ecole Le Havre 124           |ecole      |927       |226               |Le Havre     |1975              |G                 |2024-07-11|18   |electricite |83.34               |kWh  |0.09            |
# |BAT0004    |Mediatheque Paris 4          |mediatheque|907       |121               |Paris        |2019              |C                 |2024-07-11|5    |electricite |4.54                |kWh  |0.005           |
# |BAT0021    |Mediatheque Marseille 21     |mediatheque|1317      |76                |Marseille    |1978              |G                 |2024-07-11|8    |electricite |427.5               |kWh  |0.325           |
# |BAT0066    |Mairie Nantes 66             |mairie     |841       |34                |Nantes       |1963              |G                 |2024-01-26|5    |gaz         |23.27               |kWh  |0.028           |
# |BAT0141    |Mediatheque Toulon 141       |mediatheque|891       |40                |Toulon       |1980              |G                 |2024-01-26|4    |gaz         |27.61               |kWh  |0.031           |
# |BAT0125    |Mediatheque Le Havre 125     |mediatheque|812       |60                |Le Havre     |1966              |F                 |2024-01-26|6    |gaz         |162.39              |kWh  |0.2             |
# |BAT0103    |Mairie Rennes 103            |mairie     |548       |78                |Rennes       |1967              |G                 |2023-11-02|23   |electricite |13.65               |kWh  |0.025           |
# |BAT0023    |Ecole Marseille 23           |ecole      |1426      |421               |Marseille    |1970              |G                 |2023-11-02|19   |electricite |460.9               |kWh  |0.323           |
# |BAT0075    |Ecole Strasbourg 75          |ecole      |2265      |207               |Strasbourg   |1981              |G                 |2023-11-02|16   |electricite |889.98              |kWh  |0.393           |
# |BAT0049    |Mediatheque Lille 49         |mediatheque|530       |41                |Lille        |1980              |E                 |2024-08-26|12   |gaz         |44.68               |kWh  |0.084           |
# |BAT0021    |Mediatheque Marseille 21     |mediatheque|1317      |76                |Marseille    |1978              |G                 |2024-08-26|9    |gaz         |283.17              |kWh  |0.215           |
# |BAT0018    |Ecole Lyon 18                |ecole      |1664      |390               |Lyon         |1990              |D                 |2024-08-26|13   |gaz         |114.17              |kWh  |0.069           |
# |BAT0027    |Gymnase Marseille 27         |gymnase    |1228      |125               |Marseille    |2005              |D                 |2024-02-05|13   |electricite |204.19              |kWh  |0.166           |
# |BAT0067    |Mairie Nantes 67             |mairie     |857       |56                |Nantes       |1976              |G                 |2024-02-05|2    |electricite |21.2                |kWh  |0.025           |
# |BAT0099    |Piscine Rennes 99            |piscine    |1798      |333               |Rennes       |2003              |F                 |2024-02-05|12   |electricite |1126.73             |kWh  |0.627           |
# |BAT0092    |Piscine Nice 92              |piscine    |2212      |391               |Nice         |1988              |F                 |2023-12-26|8    |gaz         |1788.87             |kWh  |0.809           |
# |BAT0057    |Mairie Nantes 57             |mairie     |1126      |35                |Nantes       |1981              |F                 |2023-12-26|9    |gaz         |275.54              |kWh  |0.245           |
# |BAT0115    |Mediatheque Reims 115        |mediatheque|1735      |144               |Reims        |1978              |F                 |2023-12-26|2    |gaz         |33.97               |kWh  |0.02            |
# |BAT0085    |Mediatheque Montpellier 85   |mediatheque|1389      |74                |Montpellier  |1990              |E                 |2023-01-09|15   |gaz         |267.6               |kWh  |0.193           |
# |BAT0124    |Ecole Le Havre 124           |ecole      |927       |226               |Le Havre     |1975              |G                 |2023-01-09|7    |gaz         |269.27              |kWh  |0.29            |
# |BAT0012    |Mairie Lyon 12               |mairie     |506       |68                |Lyon         |1985              |F                 |2023-01-09|23   |gaz         |12.94               |kWh  |0.026           |
# |BAT0121    |Piscine Le Havre 121         |piscine    |2639      |315               |Le Havre     |1982              |G                 |2024-03-17|5    |gaz         |150.22              |kWh  |0.057           |
# |BAT0133    |Piscine Saint-Etienne 133    |piscine    |3507      |154               |Saint-Etienne|2005              |F                 |2024-03-17|12   |gaz         |2175.31             |kWh  |0.62            |
# |BAT0052    |Piscine Lille 52             |piscine    |2668      |316               |Lille        |2012              |B                 |2024-03-17|10   |gaz         |781.44              |kWh  |0.293           |
# |BAT0056    |Ecole Nantes 56              |ecole      |1561      |135               |Nantes       |1958              |G                 |2023-03-16|20   |gaz         |269.75              |kWh  |0.173           |
# |BAT0108    |Ecole Reims 108              |ecole      |1970      |220               |Reims        |1984              |F                 |2023-03-16|10   |gaz         |420.16              |kWh  |0.213           |
# |BAT0051    |Mairie Lille 51              |mairie     |1076      |20                |Lille        |1999              |D                 |2023-03-16|6    |gaz         |95.05               |kWh  |0.088           |
# |BAT0066    |Mairie Nantes 66             |mairie     |841       |34                |Nantes       |1963              |G                 |2023-08-17|3    |electricite |8.07                |kWh  |0.01            |
# |BAT0042    |Mediatheque Bordeaux 42      |mediatheque|1680      |90                |Bordeaux     |1981              |G                 |2023-08-17|19   |electricite |148.15              |kWh  |0.088           |
# |BAT0062    |Mairie Nantes 62             |mairie     |1336      |53                |Nantes       |1966              |G                 |2023-08-17|1    |electricite |13.8                |kWh  |0.01            |
# |BAT0085    |Mediatheque Montpellier 85   |mediatheque|1389      |74                |Montpellier  |1990              |E                 |2024-12-16|11   |electricite |197.41              |kWh  |0.142           |
# |BAT0017    |Ecole Lyon 17                |ecole      |1738      |116               |Lyon         |1990              |E                 |2024-12-16|13   |electricite |347.24              |kWh  |0.2             |
# |BAT0119    |Piscine Le Havre 119         |piscine    |2055      |336               |Le Havre     |1973              |E                 |2024-12-16|10   |electricite |934.41              |kWh  |0.455           |
# |BAT0142    |Piscine Toulon 142           |piscine    |3774      |223               |Toulon       |2010              |D                 |2024-10-16|5    |gaz         |104.09              |kWh  |0.028           |
# |BAT0145    |Mediatheque Toulon 145       |mediatheque|1204      |84                |Toulon       |2020              |C                 |2024-10-16|23   |gaz         |8.34                |kWh  |0.007           |
# |BAT0114    |Gymnase Reims 114            |gymnase    |1798      |268               |Reims        |2003              |E                 |2024-10-16|14   |gaz         |334.43              |kWh  |0.186           |
# |BAT0106    |Mairie Rennes 106            |mairie     |1272      |77                |Rennes       |1983              |G                 |2024-06-24|1    |gaz         |19.8                |kWh  |0.016           |
# |BAT0134    |Piscine Saint-Etienne 134    |piscine    |2126      |322               |Saint-Etienne|1972              |G                 |2024-06-24|21   |gaz         |870.91              |kWh  |0.41            |
# |BAT0133    |Piscine Saint-Etienne 133    |piscine    |3507      |154               |Saint-Etienne|2005              |F                 |2024-06-24|0    |gaz         |112.69              |kWh  |0.032           |
# |BAT0043    |Piscine Bordeaux 43          |piscine    |2279      |148               |Bordeaux     |1962              |G                 |2023-02-20|10   |gaz         |2592.59             |kWh  |1.138           |
# |BAT0041    |Mairie Bordeaux 41           |mairie     |870       |82                |Bordeaux     |1977              |F                 |2023-02-20|20   |gaz         |275.09              |kWh  |0.316           |
# |BAT0084    |Gymnase Montpellier 84       |gymnase    |1365      |198               |Montpellier  |1983              |E                 |2023-02-20|1    |gaz         |37.7                |kWh  |0.028           |
# |BAT0045    |Ecole Bordeaux 45            |ecole      |1203      |131               |Bordeaux     |2001              |E                 |2024-02-03|11   |eau         |1.59                |m3   |NULL            |
# |BAT0129    |Mairie Saint-Etienne 129     |mairie     |455       |95                |Saint-Etienne|1981              |E                 |2024-02-03|19   |eau         |0.43                |m3   |NULL            |
# |BAT0112    |Piscine Reims 112            |piscine    |3095      |399               |Reims        |1952              |G                 |2024-02-03|17   |eau         |259.92              |m3   |NULL            |
# |BAT0019    |Piscine Lyon 19              |piscine    |3120      |334               |Lyon         |1968              |F                 |2023-11-22|7    |eau         |320.03              |m3   |NULL            |
# |BAT0111    |Mediatheque Reims 111        |mediatheque|1454      |83                |Reims        |1957              |F                 |2023-11-22|22   |eau         |8.01                |m3   |NULL            |
# |BAT0062    |Mairie Nantes 62             |mairie     |1336      |53                |Nantes       |1966              |G                 |2023-11-22|21   |eau         |9.37                |m3   |NULL            |
# |BAT0050    |Piscine Lille 50             |piscine    |3471      |209               |Lille        |2001              |F                 |2024-06-13|12   |eau         |353.23              |m3   |NULL            |
# |BAT0122    |Piscine Le Havre 122         |piscine    |1579      |376               |Le Havre     |1956              |G                 |2024-06-13|11   |eau         |133.57              |m3   |NULL            |
# |BAT0067    |Mairie Nantes 67             |mairie     |857       |56                |Nantes       |1976              |G                 |2024-06-13|1    |eau         |0.65                |m3   |NULL            |
# |BAT0101    |Mairie Rennes 101            |mairie     |602       |20                |Rennes       |1963              |G                 |2023-12-16|7    |eau         |0.8                 |m3   |NULL            |
# |BAT0044    |Gymnase Bordeaux 44          |gymnase    |1867      |155               |Bordeaux     |2009              |F                 |2023-12-16|18   |eau         |29.54               |m3   |NULL            |
# |BAT0003    |Ecole Paris 3                |ecole      |1695      |219               |Paris        |2014              |D                 |2023-12-16|20   |eau         |2.13                |m3   |NULL            |
# |BAT0017    |Ecole Lyon 17                |ecole      |1738      |116               |Lyon         |1990              |E                 |2024-08-08|15   |eau         |16.38               |m3   |NULL            |
# |BAT0019    |Piscine Lyon 19              |piscine    |3120      |334               |Lyon         |1968              |F                 |2024-08-08|23   |eau         |23.81               |m3   |NULL            |
# |BAT0091    |Gymnase Nice 91              |gymnase    |2135      |82                |Nice         |1974              |F                 |2024-08-08|2    |eau         |2.91                |m3   |NULL            |
# |BAT0059    |Gymnase Nantes 59            |gymnase    |1418      |221               |Nantes       |1990              |D                 |2024-04-26|8    |eau         |12.25               |m3   |NULL            |
# |BAT0073    |Mairie Strasbourg 73         |mairie     |1417      |24                |Strasbourg   |1997              |E                 |2024-04-26|16   |eau         |7.03                |m3   |NULL            |
# |BAT0014    |Gymnase Lyon 14              |gymnase    |2437      |289               |Lyon         |1959              |G                 |2024-04-26|10   |eau         |37.4                |m3   |NULL            |
# |BAT0054    |Mediatheque Lille 54         |mediatheque|624       |125               |Lille        |1990              |C                 |2024-03-07|7    |eau         |2.12                |m3   |NULL            |
# |BAT0038    |Mairie Toulouse 38           |mairie     |760       |28                |Toulouse     |1993              |C                 |2024-03-07|13   |eau         |2.62                |m3   |NULL            |
# |BAT0099    |Piscine Rennes 99            |piscine    |1798      |333               |Rennes       |2003              |F                 |2024-03-07|6    |eau         |115.22              |m3   |NULL            |
# |BAT0104    |Mediatheque Rennes 104       |mediatheque|1644      |106               |Rennes       |1990              |F                 |2024-03-09|9    |eau         |12.2                |m3   |NULL            |
# |BAT0100    |Mediatheque Rennes 100       |mediatheque|898       |121               |Rennes       |1999              |E                 |2024-03-09|20   |eau         |3.65                |m3   |NULL            |
# |BAT0139    |Piscine Toulon 139           |piscine    |2831      |193               |Toulon       |2012              |B                 |2024-03-09|21   |eau         |97.76               |m3   |NULL            |
# |BAT0057    |Mairie Nantes 57             |mairie     |1126      |35                |Nantes       |1981              |F                 |2024-06-13|1    |electricite |7.36                |kWh  |0.007           |
# |BAT0040    |Mairie Bordeaux 40           |mairie     |438       |24                |Bordeaux     |1992              |C                 |2024-06-13|9    |electricite |22.94               |kWh  |0.052           |
# |BAT0117    |Mairie Le Havre 117          |mairie     |1257      |36                |Le Havre     |2018              |A                 |2023-11-20|15   |electricite |87.25               |kWh  |0.069           |
# |BAT0122    |Piscine Le Havre 122         |piscine    |1579      |376               |Le Havre     |1956              |G                 |2023-11-20|17   |electricite |1305.85             |kWh  |0.827           |
# |BAT0045    |Ecole Bordeaux 45            |ecole      |1203      |131               |Bordeaux     |2001              |E                 |2024-02-03|7    |electricite |44.65               |kWh  |0.037           |
# |BAT0064    |Mediatheque Nantes 64        |mediatheque|1940      |68                |Nantes       |2017              |A                 |2024-02-03|0    |electricite |8.62                |kWh  |0.004           |
# |BAT0069    |Ecole Strasbourg 69          |ecole      |1178      |424               |Strasbourg   |2004              |F                 |2024-07-26|10   |gaz         |201.63              |kWh  |0.171           |
# |BAT0088    |Mairie Nice 88               |mairie     |1045      |75                |Nice         |1958              |G                 |2024-07-26|6    |gaz         |128.66              |kWh  |0.123           |
# |BAT0003    |Ecole Paris 3                |ecole      |1695      |219               |Paris        |2014              |D                 |2023-12-20|6    |gaz         |275.01              |kWh  |0.162           |
# |BAT0050    |Piscine Lille 50             |piscine    |3471      |209               |Lille        |2001              |F                 |2023-12-20|7    |gaz         |3201.91             |kWh  |0.922           |
# |BAT0064    |Mediatheque Nantes 64        |mediatheque|1940      |68                |Nantes       |2017              |A                 |2023-06-01|20   |electricite |100.44              |kWh  |0.052           |
# |BAT0029    |Ecole Marseille 29           |ecole      |2022      |427               |Marseille    |2014              |D                 |2023-06-01|17   |electricite |115.36              |kWh  |0.057           |
# |BAT0082    |Gymnase Montpellier 82       |gymnase    |1719      |214               |Montpellier  |2015              |C                 |2023-12-25|11   |gaz         |308.01              |kWh  |0.179           |
# |BAT0016    |Gymnase Lyon 16              |gymnase    |2310      |226               |Lyon         |1978              |G                 |2023-12-25|1    |gaz         |113.57              |kWh  |0.049           |
# |BAT0091    |Gymnase Nice 91              |gymnase    |2135      |82                |Nice         |1974              |F                 |2024-09-07|15   |electricite |368.91              |kWh  |0.173           |
# |BAT0010    |Mediatheque Lyon 10          |mediatheque|1240      |103               |Lyon         |1974              |G                 |2024-09-07|5    |electricite |21.49               |kWh  |0.017           |
# |BAT0111    |Mediatheque Reims 111        |mediatheque|1454      |83                |Reims        |1957              |F                 |2023-03-06|12   |gaz         |207.0               |kWh  |0.142           |
# |BAT0073    |Mairie Strasbourg 73         |mairie     |1417      |24                |Strasbourg   |1997              |E                 |2023-03-06|7    |gaz         |128.59              |kWh  |0.091           |
# |BAT0056    |Ecole Nantes 56              |ecole      |1561      |135               |Nantes       |1958              |G                 |2024-01-02|3    |gaz         |70.97               |kWh  |0.045           |
# |BAT0021    |Mediatheque Marseille 21     |mediatheque|1317      |76                |Marseille    |1978              |G                 |2024-01-02|12   |gaz         |373.95              |kWh  |0.284           |
# |BAT0074    |Mairie Strasbourg 74         |mairie     |1180      |36                |Strasbourg   |1955              |F                 |2024-01-20|18   |gaz         |40.52               |kWh  |0.034           |
# |BAT0045    |Ecole Bordeaux 45            |ecole      |1203      |131               |Bordeaux     |2001              |E                 |2024-01-20|4    |gaz         |4.82                |kWh  |0.004           |
# |BAT0058    |Ecole Nantes 58              |ecole      |1135      |314               |Nantes       |2016              |C                 |2023-08-25|10   |electricite |96.54               |kWh  |0.085           |
# |BAT0093    |Ecole Nice 93                |ecole      |2044      |246               |Nice         |1976              |F                 |2023-08-25|15   |electricite |212.47              |kWh  |0.104           |
# |BAT0013    |Gymnase Lyon 13              |gymnase    |1333      |144               |Lyon         |1995              |D                 |2023-09-24|5    |gaz         |24.79               |kWh  |0.019           |
# |BAT0075    |Ecole Strasbourg 75          |ecole      |2265      |207               |Strasbourg   |1981              |G                 |2023-09-24|8    |gaz         |155.83              |kWh  |0.069           |
# |BAT0109    |Mediatheque Reims 109        |mediatheque|665       |47                |Reims        |1969              |F                 |2024-07-20|20   |electricite |39.91               |kWh  |0.06            |
# |BAT0124    |Ecole Le Havre 124           |ecole      |927       |226               |Le Havre     |1975              |G                 |2024-07-20|2    |electricite |1.67                |kWh  |0.002           |
# |BAT0005    |Piscine Paris 5              |piscine    |3913      |242               |Paris        |1950              |G                 |2023-03-15|14   |electricite |1569.65             |kWh  |0.401           |
# |BAT0058    |Ecole Nantes 58              |ecole      |1135      |314               |Nantes       |2016              |C                 |2023-03-15|12   |electricite |97.62               |kWh  |0.086           |
# |BAT0043    |Piscine Bordeaux 43          |piscine    |2279      |148               |Bordeaux     |1962              |G                 |2023-05-22|18   |gaz         |1312.26             |kWh  |0.576           |
# |BAT0005    |Piscine Paris 5              |piscine    |3913      |242               |Paris        |1950              |G                 |2023-05-22|17   |gaz         |1918.04             |kWh  |0.49            |
# |BAT0071    |Gymnase Strasbourg 71        |gymnase    |1330      |239               |Strasbourg   |2006              |E                 |2024-01-10|11   |gaz         |494.22              |kWh  |0.372           |
# |BAT0039    |Mediatheque Toulouse 39      |mediatheque|971       |105               |Toulouse     |1978              |E                 |2024-01-10|6    |gaz         |170.75              |kWh  |0.176           |
# |BAT0019    |Piscine Lyon 19              |piscine    |3120      |334               |Lyon         |1968              |F                 |2023-05-21|20   |gaz         |1456.33             |kWh  |0.467           |
# |BAT0116    |Gymnase Reims 116            |gymnase    |1892      |174               |Reims        |1953              |F                 |2023-05-21|23   |gaz         |60.03               |kWh  |0.032           |
# |BAT0028    |Ecole Marseille 28           |ecole      |1878      |356               |Marseille    |1972              |F                 |2024-01-29|10   |electricite |542.21              |kWh  |0.289           |
# |BAT0143    |Piscine Toulon 143           |piscine    |3335      |108               |Toulon       |1961              |F                 |2024-01-29|2    |electricite |234.38              |kWh  |0.07            |
# |BAT0049    |Mediatheque Lille 49         |mediatheque|530       |41                |Lille        |1980              |E                 |2024-12-01|16   |electricite |72.28               |kWh  |0.136           |
# |BAT0113    |Mediatheque Reims 113        |mediatheque|1279      |91                |Reims        |1950              |G                 |2024-12-01|17   |electricite |369.87              |kWh  |0.289           |
# |BAT0133    |Piscine Saint-Etienne 133    |piscine    |3507      |154               |Saint-Etienne|2005              |F                 |2024-10-31|0    |gaz         |155.42              |kWh  |0.044           |
# |BAT0082    |Gymnase Montpellier 82       |gymnase    |1719      |214               |Montpellier  |2015              |C                 |2024-10-31|6    |gaz         |172.85              |kWh  |0.101           |
# |BAT0058    |Ecole Nantes 58              |ecole      |1135      |314               |Nantes       |2016              |C                 |2023-11-09|1    |electricite |9.89                |kWh  |0.009           |
# |BAT0132    |Gymnase Saint-Etienne 132    |gymnase    |1141      |179               |Saint-Etienne|1993              |C                 |2023-11-09|12   |electricite |100.15              |kWh  |0.088           |
# |BAT0123    |Gymnase Le Havre 123         |gymnase    |1459      |216               |Le Havre     |1958              |G                 |2023-05-18|9    |gaz         |508.38              |kWh  |0.348           |
# |BAT0021    |Mediatheque Marseille 21     |mediatheque|1317      |76                |Marseille    |1978              |G                 |2023-05-18|6    |gaz         |307.2               |kWh  |0.233           |
# |BAT0094    |Mediatheque Nice 94          |mediatheque|1742      |113               |Nice         |1991              |E                 |2023-03-17|8    |gaz         |365.32              |kWh  |0.21            |
# |BAT0103    |Mairie Rennes 103            |mairie     |548       |78                |Rennes       |1967              |G                 |2023-03-17|12   |gaz         |73.9                |kWh  |0.135           |
# |BAT0009    |Ecole Lyon 9                 |ecole      |2350      |140               |Lyon         |2020              |B                 |2023-11-27|18   |electricite |181.83              |kWh  |0.077           |
# |BAT0024    |Piscine Marseille 24         |piscine    |3942      |132               |Marseille    |1999              |D                 |2023-11-27|5    |electricite |158.57              |kWh  |0.04            |
# |BAT0079    |Ecole Montpellier 79         |ecole      |2366      |119               |Montpellier  |2010              |B                 |2023-07-17|2    |electricite |8.06                |kWh  |0.003           |
# |BAT0046    |Ecole Bordeaux 46            |ecole      |1818      |198               |Bordeaux     |1974              |F                 |2023-07-17|20   |electricite |194.98              |kWh  |0.107           |
# |BAT0042    |Mediatheque Bordeaux 42      |mediatheque|1680      |90                |Bordeaux     |1981              |G                 |2023-05-08|23   |gaz         |25.09               |kWh  |0.015           |
# |BAT0050    |Piscine Lille 50             |piscine    |3471      |209               |Lille        |2001              |F                 |2023-05-08|3    |gaz         |225.14              |kWh  |0.065           |
# |BAT0052    |Piscine Lille 52             |piscine    |2668      |316               |Lille        |2012              |B                 |2023-10-24|14   |gaz         |510.79              |kWh  |0.191           |
# |BAT0139    |Piscine Toulon 139           |piscine    |2831      |193               |Toulon       |2012              |B                 |2023-10-24|18   |gaz         |649.74              |kWh  |0.23            |
# |BAT0024    |Piscine Marseille 24         |piscine    |3942      |132               |Marseille    |1999              |D                 |2023-05-20|2    |electricite |55.73               |kWh  |0.014           |
# |BAT0074    |Mairie Strasbourg 74         |mairie     |1180      |36                |Strasbourg   |1955              |F                 |2023-05-20|21   |electricite |27.87               |kWh  |0.024           |
# |BAT0022    |Mairie Marseille 22          |mairie     |1343      |83                |Marseille    |1961              |G                 |2023-07-16|5    |gaz         |3.33                |kWh  |0.002           |
# |BAT0113    |Mediatheque Reims 113        |mediatheque|1279      |91                |Reims        |1950              |G                 |2023-07-16|11   |gaz         |128.44              |kWh  |0.1             |
# |BAT0018    |Ecole Lyon 18                |ecole      |1664      |390               |Lyon         |1990              |D                 |2024-08-12|4    |gaz         |4.66                |kWh  |0.003           |
# |BAT0026    |Ecole Marseille 26           |ecole      |1269      |449               |Marseille    |2018              |D                 |2024-08-12|22   |gaz         |87.06               |kWh  |0.069           |
# |BAT0031    |Mediatheque Marseille 31     |mediatheque|501       |106               |Marseille    |1991              |E                 |2024-03-23|4    |electricite |3.23                |kWh  |0.006           |
# |BAT0003    |Ecole Paris 3                |ecole      |1695      |219               |Paris        |2014              |D                 |2024-03-23|10   |electricite |32.36               |kWh  |0.019           |
# |BAT0021    |Mediatheque Marseille 21     |mediatheque|1317      |76                |Marseille    |1978              |G                 |2024-08-21|16   |gaz         |310.06              |kWh  |0.235           |
# |BAT0056    |Ecole Nantes 56              |ecole      |1561      |135               |Nantes       |1958              |G                 |2024-08-21|2    |gaz         |27.42               |kWh  |0.018           |
# |BAT0006    |Mairie Paris 6               |mairie     |1165      |63                |Paris        |1985              |E                 |2023-01-01|3    |gaz         |5.5                 |kWh  |0.005           |
# |BAT0126    |Ecole Le Havre 126           |ecole      |1692      |338               |Le Havre     |1982              |G                 |2023-01-01|10   |gaz         |126.88              |kWh  |0.075           |
# |BAT0010    |Mediatheque Lyon 10          |mediatheque|1240      |103               |Lyon         |1974              |G                 |2024-05-15|17   |electricite |209.93              |kWh  |0.169           |
# |BAT0133    |Piscine Saint-Etienne 133    |piscine    |3507      |154               |Saint-Etienne|2005              |F                 |2024-05-15|3    |electricite |121.9               |kWh  |0.035           |
# |BAT0030    |Mairie Marseille 30          |mairie     |1065      |40                |Marseille    |2019              |D                 |2023-10-26|22   |electricite |75.65               |kWh  |0.071           |
# |BAT0011    |Ecole Lyon 11                |ecole      |1733      |495               |Lyon         |1987              |G                 |2023-10-26|9    |electricite |381.52              |kWh  |0.22            |
# |BAT0079    |Ecole Montpellier 79         |ecole      |2366      |119               |Montpellier  |2010              |B                 |2024-06-24|9    |electricite |97.42               |kWh  |0.041           |
# |BAT0136    |Piscine Toulon 136           |piscine    |3926      |237               |Toulon       |1991              |F                 |2024-06-24|4    |electricite |87.66               |kWh  |0.022           |
# |BAT0027    |Gymnase Marseille 27         |gymnase    |1228      |125               |Marseille    |2005              |D                 |2024-12-19|16   |electricite |262.16              |kWh  |0.213           |
# |BAT0065    |Mediatheque Nantes 65        |mediatheque|1113      |149               |Nantes       |1963              |G                 |2024-12-19|7    |electricite |280.79              |kWh  |0.252           |
# |BAT0016    |Gymnase Lyon 16              |gymnase    |2310      |226               |Lyon         |1978              |G                 |2024-10-25|8    |gaz         |701.61              |kWh  |0.304           |
# |BAT0119    |Piscine Le Havre 119         |piscine    |2055      |336               |Le Havre     |1973              |E                 |2024-10-25|14   |gaz         |1103.56             |kWh  |0.537           |
# |BAT0044    |Gymnase Bordeaux 44          |gymnase    |1867      |155               |Bordeaux     |2009              |F                 |2024-12-06|22   |gaz         |908.26              |kWh  |0.486           |
# |BAT0102    |Mairie Rennes 102            |mairie     |660       |86                |Rennes       |2009              |C                 |2024-12-06|13   |gaz         |98.67               |kWh  |0.15            |
# |BAT0119    |Piscine Le Havre 119         |piscine    |2055      |336               |Le Havre     |1973              |E                 |2024-01-05|0    |gaz         |94.4                |kWh  |0.046           |
# |BAT0045    |Ecole Bordeaux 45            |ecole      |1203      |131               |Bordeaux     |2001              |E                 |2024-01-05|16   |gaz         |198.1               |kWh  |0.165           |
# |BAT0011    |Ecole Lyon 11                |ecole      |1733      |495               |Lyon         |1987              |G                 |2024-12-12|16   |gaz         |877.29              |kWh  |0.506           |
# |BAT0020    |Mairie Lyon 20               |mairie     |1449      |88                |Lyon         |1983              |G                 |2024-12-12|3    |gaz         |30.58               |kWh  |0.021           |
# |BAT0059    |Gymnase Nantes 59            |gymnase    |1418      |221               |Nantes       |1990              |D                 |2024-04-21|10   |gaz         |205.49              |kWh  |0.145           |
# |BAT0114    |Gymnase Reims 114            |gymnase    |1798      |268               |Reims        |2003              |E                 |2024-04-21|14   |gaz         |331.03              |kWh  |0.184           |
# |BAT0134    |Piscine Saint-Etienne 134    |piscine    |2126      |322               |Saint-Etienne|1972              |G                 |2023-06-02|17   |electricite |580.68              |kWh  |0.273           |
# |BAT0028    |Ecole Marseille 28           |ecole      |1878      |356               |Marseille    |1972              |F                 |2023-06-02|5    |electricite |16.22               |kWh  |0.009           |
# |BAT0117    |Mairie Le Havre 117          |mairie     |1257      |36                |Le Havre     |2018              |A                 |2024-12-26|21   |gaz         |87.17               |kWh  |0.069           |
# |BAT0001    |Ecole Paris 1                |ecole      |1926      |225               |Paris        |1978              |E                 |2024-12-26|10   |gaz         |472.87              |kWh  |0.246           |
# |BAT0141    |Mediatheque Toulon 141       |mediatheque|891       |40                |Toulon       |1980              |G                 |2024-07-21|8    |gaz         |141.34              |kWh  |0.159           |
# |BAT0093    |Ecole Nice 93                |ecole      |2044      |246               |Nice         |1976              |F                 |2024-07-21|0    |gaz         |6.82                |kWh  |0.003           |
# |BAT0083    |Mediatheque Montpellier 83   |mediatheque|1178      |150               |Montpellier  |1953              |E                 |2023-03-16|13   |electricite |134.1               |kWh  |0.114           |
# |BAT0117    |Mairie Le Havre 117          |mairie     |1257      |36                |Le Havre     |2018              |A                 |2023-03-16|19   |electricite |32.25               |kWh  |0.026           |
# |BAT0141    |Mediatheque Toulon 141       |mediatheque|891       |40                |Toulon       |1980              |G                 |2023-05-17|16   |gaz         |290.65              |kWh  |0.326           |
# |BAT0055    |Mediatheque Lille 55         |mediatheque|1476      |94                |Lille        |2017              |B                 |2023-05-17|13   |gaz         |81.46               |kWh  |0.055           |
# |BAT0117    |Mairie Le Havre 117          |mairie     |1257      |36                |Le Havre     |2018              |A                 |2024-11-14|16   |electricite |74.35               |kWh  |0.059           |
# |BAT0121    |Piscine Le Havre 121         |piscine    |2639      |315               |Le Havre     |1982              |G                 |2024-11-14|17   |electricite |1420.59             |kWh  |0.538           |
# |BAT0050    |Piscine Lille 50             |piscine    |3471      |209               |Lille        |2001              |F                 |2024-08-27|16   |electricite |1306.96             |kWh  |0.377           |
# |BAT0012    |Mairie Lyon 12               |mairie     |506       |68                |Lyon         |1985              |F                 |2024-08-27|13   |electricite |32.66               |kWh  |0.065           |
# |BAT0004    |Mediatheque Paris 4          |mediatheque|907       |121               |Paris        |2019              |C                 |2023-05-24|19   |electricite |60.69               |kWh  |0.067           |
# |BAT0140    |Gymnase Toulon 140           |gymnase    |1697      |121               |Toulon       |1985              |F                 |2023-05-24|3    |electricite |32.91               |kWh  |0.019           |
# |BAT0116    |Gymnase Reims 116            |gymnase    |1892      |174               |Reims        |1953              |F                 |2024-10-19|5    |electricite |31.07               |kWh  |0.016           |
# |BAT0008    |Gymnase Paris 8              |gymnase    |2236      |117               |Paris        |1955              |G                 |2024-10-19|2    |electricite |41.56               |kWh  |0.019           |
# |BAT0074    |Mairie Strasbourg 74         |mairie     |1180      |36                |Strasbourg   |1955              |F                 |2024-05-27|6    |gaz         |141.34              |kWh  |0.12            |
# |BAT0050    |Piscine Lille 50             |piscine    |3471      |209               |Lille        |2001              |F                 |2024-05-27|4    |gaz         |173.54              |kWh  |0.05            |
# |BAT0137    |Ecole Toulon 137             |ecole      |1942      |330               |Toulon       |1981              |G                 |2023-09-05|5    |gaz         |36.6                |kWh  |0.019           |
# |BAT0084    |Gymnase Montpellier 84       |gymnase    |1365      |198               |Montpellier  |1983              |E                 |2023-09-05|11   |gaz         |334.46              |kWh  |0.245           |
# |BAT0103    |Mairie Rennes 103            |mairie     |548       |78                |Rennes       |1967              |G                 |2024-05-29|0    |electricite |8.36                |kWh  |0.015           |
# |BAT0136    |Piscine Toulon 136           |piscine    |3926      |237               |Toulon       |1991              |F                 |2024-05-29|12   |electricite |1021.24             |kWh  |0.26            |
# |BAT0077    |Mairie Montpellier 77        |mairie     |632       |42                |Montpellier  |2002              |C                 |2024-11-10|16   |electricite |17.2                |kWh  |0.027           |
# |BAT0062    |Mairie Nantes 62             |mairie     |1336      |53                |Nantes       |1966              |G                 |2024-11-10|20   |electricite |60.65               |kWh  |0.045           |
# |BAT0027    |Gymnase Marseille 27         |gymnase    |1228      |125               |Marseille    |2005              |D                 |2024-01-05|19   |electricite |194.74              |kWh  |0.159           |
# |BAT0084    |Gymnase Montpellier 84       |gymnase    |1365      |198               |Montpellier  |1983              |E                 |2024-01-05|0    |electricite |30.85               |kWh  |0.023           |
# |BAT0127    |Mairie Le Havre 127          |mairie     |534       |40                |Le Havre     |1989              |E                 |2024-06-18|4    |electricite |2.09                |kWh  |0.004           |
# |BAT0134    |Piscine Saint-Etienne 134    |piscine    |2126      |322               |Saint-Etienne|1972              |G                 |2024-06-18|0    |electricite |47.12               |kWh  |0.022           |
# |BAT0133    |Piscine Saint-Etienne 133    |piscine    |3507      |154               |Saint-Etienne|2005              |F                 |2023-08-07|21   |gaz         |1142.32             |kWh  |0.326           |
# |BAT0074    |Mairie Strasbourg 74         |mairie     |1180      |36                |Strasbourg   |1955              |F                 |2023-08-07|10   |gaz         |202.49              |kWh  |0.172           |
# |BAT0080    |Piscine Montpellier 80       |piscine    |2932      |256               |Montpellier  |1979              |F                 |2023-08-08|13   |gaz         |1256.73             |kWh  |0.429           |
# |BAT0085    |Mediatheque Montpellier 85   |mediatheque|1389      |74                |Montpellier  |1990              |E                 |2023-08-08|2    |gaz         |10.33               |kWh  |0.007           |
# ...
# |BAT0081    |Mairie Montpellier 81        |mairie     |1116      |62                |Montpellier  |1985              |G                 |2023-07-31|20   |electricite |120.15              |kWh  |0.108           |
# |BAT0029    |Ecole Marseille 29           |ecole      |2022      |427               |Marseille    |2014              |D                 |2023-11-06|16   |gaz         |38.95               |kWh  |0.019           |
# |BAT0002    |Ecole Paris 2                |ecole      |1156      |402               |Paris        |2004              |C                 |2023-06-01|12   |gaz         |104.5               |kWh  |0.09            |
# |BAT0140    |Gymnase Toulon 140           |gymnase    |1697      |121               |Toulon       |1985              |F                 |2023-09-10|18   |gaz         |342.49              |kWh  |0.202           |
# |BAT0127    |Mairie Le Havre 127          |mairie     |534       |40                |Le Havre     |1989              |E                 |2024-07-19|16   |gaz         |53.59               |kWh  |0.1             |
# |BAT0121    |Piscine Le Havre 121         |piscine    |2639      |315               |Le Havre     |1982              |G                 |2023-04-17|5    |gaz         |120.03              |kWh  |0.045           |
# |BAT0106    |Mairie Rennes 106            |mairie     |1272      |77                |Rennes       |1983              |G                 |2024-01-18|19   |gaz         |449.38              |kWh  |0.353           |
# |BAT0131    |Mediatheque Saint-Etienne 131|mediatheque|584       |74                |Saint-Etienne|2018              |C                 |2023-02-15|6    |electricite |63.53               |kWh  |0.109           |
# |BAT0029    |Ecole Marseille 29           |ecole      |2022      |427               |Marseille    |2014              |D                 |2023-04-16|22   |gaz         |53.39               |kWh  |0.026           |
# |BAT0017    |Ecole Lyon 17                |ecole      |1738      |116               |Lyon         |1990              |E                 |2023-06-12|16   |gaz         |555.4               |kWh  |0.32            |
# |BAT0035    |Mairie Toulouse 35           |mairie     |842       |87                |Toulouse     |2004              |F                 |2024-09-06|12   |electricite |96.49               |kWh  |0.115           |
# |BAT0084    |Gymnase Montpellier 84       |gymnase    |1365      |198               |Montpellier  |1983              |E                 |2024-09-13|22   |gaz         |236.28              |kWh  |0.173           |
# |BAT0041    |Mairie Bordeaux 41           |mairie     |870       |82                |Bordeaux     |1977              |F                 |2023-12-03|7    |electricite |21.89               |kWh  |0.025           |
# |BAT0100    |Mediatheque Rennes 100       |mediatheque|898       |121               |Rennes       |1999              |E                 |2024-03-03|15   |gaz         |154.98              |kWh  |0.173           |
# |BAT0059    |Gymnase Nantes 59            |gymnase    |1418      |221               |Nantes       |1990              |D                 |2024-07-16|19   |gaz         |164.47              |kWh  |0.116           |
# |BAT0114    |Gymnase Reims 114            |gymnase    |1798      |268               |Reims        |2003              |E                 |2023-09-18|19   |gaz         |375.83              |kWh  |0.209           |
# |BAT0052    |Piscine Lille 52             |piscine    |2668      |316               |Lille        |2012              |B                 |2024-09-15|18   |gaz         |701.01              |kWh  |0.263           |
# |BAT0074    |Mairie Strasbourg 74         |mairie     |1180      |36                |Strasbourg   |1955              |F                 |2024-10-15|12   |gaz         |233.41              |kWh  |0.198           |
# |BAT0074    |Mairie Strasbourg 74         |mairie     |1180      |36                |Strasbourg   |1955              |F                 |2023-03-19|18   |electricite |22.6                |kWh  |0.019           |
# |BAT0118    |Piscine Le Havre 118         |piscine    |3924      |388               |Le Havre     |1953              |E                 |2024-08-24|7    |electricite |617.41              |kWh  |0.157           |
# |BAT0057    |Mairie Nantes 57             |mairie     |1126      |35                |Nantes       |1981              |F                 |2024-12-05|5    |gaz         |31.06               |kWh  |0.028           |
# |BAT0014    |Gymnase Lyon 14              |gymnase    |2437      |289               |Lyon         |1959              |G                 |2024-04-22|23   |gaz         |65.81               |kWh  |0.027           |
# |BAT0122    |Piscine Le Havre 122         |piscine    |1579      |376               |Le Havre     |1956              |G                 |2024-12-06|7    |electricite |339.16              |kWh  |0.215           |
# |BAT0051    |Mairie Lille 51              |mairie     |1076      |20                |Lille        |1999              |D                 |2023-06-06|12   |electricite |50.58               |kWh  |0.047           |
# |BAT0122    |Piscine Le Havre 122         |piscine    |1579      |376               |Le Havre     |1956              |G                 |2023-08-06|15   |electricite |635.22              |kWh  |0.402           |
# |BAT0108    |Ecole Reims 108              |ecole      |1970      |220               |Reims        |1984              |F                 |2024-01-16|9    |gaz         |693.32              |kWh  |0.352           |
# |BAT0026    |Ecole Marseille 26           |ecole      |1269      |449               |Marseille    |2018              |D                 |2023-03-23|11   |gaz         |117.66              |kWh  |0.093           |
# |BAT0081    |Mairie Montpellier 81        |mairie     |1116      |62                |Montpellier  |1985              |G                 |2023-09-07|20   |gaz         |232.72              |kWh  |0.209           |
# |BAT0015    |Mairie Lyon 15               |mairie     |1393      |51                |Lyon         |1970              |F                 |2024-04-18|23   |gaz         |24.66               |kWh  |0.018           |
# |BAT0065    |Mediatheque Nantes 65        |mediatheque|1113      |149               |Nantes       |1963              |G                 |2023-04-05|8    |gaz         |328.2               |kWh  |0.295           |
# |BAT0082    |Gymnase Montpellier 82       |gymnase    |1719      |214               |Montpellier  |2015              |C                 |2023-06-03|11   |electricite |79.18               |kWh  |0.046           |
# |BAT0031    |Mediatheque Marseille 31     |mediatheque|501       |106               |Marseille    |1991              |E                 |2023-05-25|4    |electricite |5.22                |kWh  |0.01            |
# |BAT0089    |Gymnase Nice 89              |gymnase    |2276      |130               |Nice         |1965              |G                 |2023-06-23|8    |gaz         |648.31              |kWh  |0.285           |
# |BAT0023    |Ecole Marseille 23           |ecole      |1426      |421               |Marseille    |1970              |G                 |2023-12-13|18   |electricite |453.94              |kWh  |0.318           |
# |BAT0128    |Gymnase Saint-Etienne 128    |gymnase    |2179      |223               |Saint-Etienne|1998              |D                 |2023-10-21|7    |electricite |156.87              |kWh  |0.072           |
# |BAT0136    |Piscine Toulon 136           |piscine    |3926      |237               |Toulon       |1991              |F                 |2024-12-29|23   |gaz         |326.87              |kWh  |0.083           |
# |BAT0044    |Gymnase Bordeaux 44          |gymnase    |1867      |155               |Bordeaux     |2009              |F                 |2023-01-22|21   |electricite |539.81              |kWh  |0.289           |
# |BAT0138    |Mediatheque Toulon 138       |mediatheque|1749      |115               |Toulon       |1998              |D                 |2024-04-25|8    |gaz         |288.8               |kWh  |0.165           |
# |BAT0098    |Mairie Rennes 98             |mairie     |601       |23                |Rennes       |1955              |F                 |2024-01-25|1    |electricite |11.56               |kWh  |0.019           |
# |BAT0035    |Mairie Toulouse 35           |mairie     |842       |87                |Toulouse     |2004              |F                 |2023-04-12|2    |electricite |8.13                |kWh  |0.01            |
# |BAT0012    |Mairie Lyon 12               |mairie     |506       |68                |Lyon         |1985              |F                 |2023-01-07|15   |gaz         |33.75               |kWh  |0.067           |
# |BAT0145    |Mediatheque Toulon 145       |mediatheque|1204      |84                |Toulon       |2020              |C                 |2024-02-01|10   |gaz         |241.24              |kWh  |0.2             |
# |BAT0071    |Gymnase Strasbourg 71        |gymnase    |1330      |239               |Strasbourg   |2006              |E                 |2024-12-04|13   |gaz         |360.94              |kWh  |0.271           |
# |BAT0006    |Mairie Paris 6               |mairie     |1165      |63                |Paris        |1985              |E                 |2023-03-29|1    |electricite |11.6                |kWh  |0.01            |
# |BAT0100    |Mediatheque Rennes 100       |mediatheque|898       |121               |Rennes       |1999              |E                 |2023-06-26|13   |gaz         |73.5                |kWh  |0.082           |
# |BAT0052    |Piscine Lille 52             |piscine    |2668      |316               |Lille        |2012              |B                 |2024-04-11|12   |gaz         |614.04              |kWh  |0.23            |
# |BAT0087    |Piscine Nice 87              |piscine    |1506      |366               |Nice         |2018              |D                 |2023-06-25|9    |gaz         |520.42              |kWh  |0.346           |
# |BAT0060    |Piscine Nantes 60            |piscine    |2036      |253               |Nantes       |2008              |D                 |2023-07-12|9    |gaz         |589.45              |kWh  |0.29            |
# |BAT0106    |Mairie Rennes 106            |mairie     |1272      |77                |Rennes       |1983              |G                 |2023-01-23|0    |electricite |23.76               |kWh  |0.019           |
# |BAT0130    |Gymnase Saint-Etienne 130    |gymnase    |2401      |203               |Saint-Etienne|1965              |G                 |2023-02-24|3    |gaz         |92.35               |kWh  |0.038           |
# |BAT0093    |Ecole Nice 93                |ecole      |2044      |246               |Nice         |1976              |F                 |2024-06-28|10   |electricite |240.55              |kWh  |0.118           |
# |BAT0009    |Ecole Lyon 9                 |ecole      |2350      |140               |Lyon         |2020              |B                 |2023-09-09|16   |gaz         |51.03               |kWh  |0.022           |
# |BAT0080    |Piscine Montpellier 80       |piscine    |2932      |256               |Montpellier  |1979              |F                 |2024-07-24|2    |gaz         |78.5                |kWh  |0.027           |
# |BAT0057    |Mairie Nantes 57             |mairie     |1126      |35                |Nantes       |1981              |F                 |2023-04-01|10   |gaz         |48.16               |kWh  |0.043           |
# |BAT0038    |Mairie Toulouse 38           |mairie     |760       |28                |Toulouse     |1993              |C                 |2023-06-16|4    |electricite |3.39                |kWh  |0.004           |
# |BAT0007    |Gymnase Paris 7              |gymnase    |1209      |73                |Paris        |1998              |C                 |2024-10-10|10   |gaz         |267.0               |kWh  |0.221           |
# |BAT0043    |Piscine Bordeaux 43          |piscine    |2279      |148               |Bordeaux     |1962              |G                 |2024-03-13|17   |gaz         |1698.35             |kWh  |0.745           |
# |BAT0016    |Gymnase Lyon 16              |gymnase    |2310      |226               |Lyon         |1978              |G                 |2024-12-21|20   |gaz         |1384.18             |kWh  |0.599           |
# |BAT0103    |Mairie Rennes 103            |mairie     |548       |78                |Rennes       |1967              |G                 |2023-04-14|3    |electricite |6.4                 |kWh  |0.012           |
# |BAT0117    |Mairie Le Havre 117          |mairie     |1257      |36                |Le Havre     |2018              |A                 |2024-04-24|4    |gaz         |4.36                |kWh  |0.003           |
# |BAT0037    |Piscine Toulouse 37          |piscine    |3029      |324               |Toulouse     |2016              |C                 |2024-04-19|6    |gaz         |883.81              |kWh  |0.292           |
# |BAT0131    |Mediatheque Saint-Etienne 131|mediatheque|584       |74                |Saint-Etienne|2018              |C                 |2024-03-13|7    |electricite |30.08               |kWh  |0.052           |
# |BAT0033    |Mediatheque Toulouse 33      |mediatheque|661       |40                |Toulouse     |2012              |D                 |2023-12-29|16   |electricite |114.72              |kWh  |0.174           |
# |BAT0109    |Mediatheque Reims 109        |mediatheque|665       |47                |Reims        |1969              |F                 |2024-09-29|21   |electricite |60.58               |kWh  |0.091           |
# |BAT0089    |Gymnase Nice 89              |gymnase    |2276      |130               |Nice         |1965              |G                 |2023-04-08|7    |electricite |591.07              |kWh  |0.26            |
# |BAT0022    |Mairie Marseille 22          |mairie     |1343      |83                |Marseille    |1961              |G                 |2024-10-08|10   |electricite |173.83              |kWh  |0.129           |
# |BAT0078    |Gymnase Montpellier 78       |gymnase    |1843      |255               |Montpellier  |1981              |F                 |2023-02-18|20   |electricite |481.42              |kWh  |0.261           |
# |BAT0063    |Ecole Nantes 63              |ecole      |1800      |289               |Nantes       |1986              |E                 |2024-04-29|7    |electricite |201.76              |kWh  |0.112           |
# |BAT0003    |Ecole Paris 3                |ecole      |1695      |219               |Paris        |2014              |D                 |2024-05-09|0    |electricite |14.01               |kWh  |0.008           |
# |BAT0024    |Piscine Marseille 24         |piscine    |3942      |132               |Marseille    |1999              |D                 |2024-07-18|2    |electricite |63.94               |kWh  |0.016           |
# |BAT0056    |Ecole Nantes 56              |ecole      |1561      |135               |Nantes       |1958              |G                 |2024-11-18|2    |gaz         |48.42               |kWh  |0.031           |
# |BAT0075    |Ecole Strasbourg 75          |ecole      |2265      |207               |Strasbourg   |1981              |G                 |2024-04-27|17   |gaz         |128.17              |kWh  |0.057           |
# |BAT0137    |Ecole Toulon 137             |ecole      |1942      |330               |Toulon       |1981              |G                 |2024-10-23|13   |electricite |362.32              |kWh  |0.187           |
# |BAT0014    |Gymnase Lyon 14              |gymnase    |2437      |289               |Lyon         |1959              |G                 |2024-08-01|7    |gaz         |420.51              |kWh  |0.173           |
# +-----------+-----------------------------+-----------+----------+------------------+-------------+------------------+------------------+----------+-----+------------+--------------------+-----+----------------+
# only showing top 500 rows

# %% [markdown]
# ---

# %% [markdown]
# ## Identifier les batiments hors norme (>3x la mediane de leur categorie)
# 'Catégorie' => type de bâtiment (ecole, mairie, etc.).
# On calcule la médiane de l’intensité par type et type_energie, puis on marque hors norme.
#
# => En Spark, médiane = percentile_approx(col, 0.5) (standard).

# %%
# --- Calcule de la médiane par catégorie
df_median = (
    df
    .filter(F.col("intensite_kwh_m2").isNotNull())
    .groupBy("type") # catégorie
    .agg(
        F.expr("percentile_approx(intensite_kwh_m2, 0.5)").alias("mediane_intensite")
    )
)

# --- Joindre la médiane au dataframe
df_with_mediane = df.join(df_median, on="type", how="left")

# --- Identification des bâtiments hors norme
df_outliers = df_with_mediane.filter(
    F.col("intensite_kwh_m2") > 3 * F.col("mediane_intensite")
)

# --- Affichage des résultats
print("- Nombre de batiments hors norme (>3x la mediane de leur categorie) :", df_outliers.count())
print("- Apperçu de ces batiments hors normes :")
df_outliers.show()
# Out:
# - Nombre de batiments hors norme (>3x la mediane de leur categorie) : 97
# - Apperçu de ces batiments hors normes :
# +-----------+-----------+--------------------+----------+------------------+----------+------------------+------------------+----------+-----+------------+--------------------+-----+----------------+-----------------+
# |       type|batiment_id|                 nom|surface_m2|nb_occupants_moyen|   commune|annee_construction|classe_energetique|      date|heure|type_energie|consommation_moyenne|unite|intensite_kwh_m2|mediane_intensite|
# +-----------+-----------+--------------------+----------+------------------+----------+------------------+------------------+----------+-----+------------+--------------------+-----+----------------+-----------------+
# |mediatheque|    BAT0021|Mediatheque Marse...|      1317|                76| Marseille|              1978|                 G|2024-07-11|    8| electricite|               427.5|  kWh|           0.325|            0.106|
# |    piscine|    BAT0043| Piscine Bordeaux 43|      2279|               148|  Bordeaux|              1962|                 G|2023-02-20|   10|         gaz|             2592.59|  kWh|           1.138|            0.292|
# |     mairie|    BAT0106|   Mairie Rennes 106|      1272|                77|    Rennes|              1983|                 G|2024-09-17|   21|         gaz|              178.72|  kWh|           0.141|            0.029|
# |     mairie|    BAT0057|    Mairie Nantes 57|      1126|                35|    Nantes|              1981|                 F|2023-12-26|    9|         gaz|              275.54|  kWh|           0.245|            0.029|
# |     mairie|    BAT0051|     Mairie Lille 51|      1076|                20|     Lille|              1999|                 D|2023-03-16|    6|         gaz|               95.05|  kWh|           0.088|            0.029|
# |     mairie|    BAT0041|  Mairie Bordeaux 41|       870|                82|  Bordeaux|              1977|                 F|2023-02-20|   20|         gaz|              275.09|  kWh|           0.316|            0.029|
# |      ecole|    BAT0023|  Ecole Marseille 23|      1426|               421| Marseille|              1970|                 G|2023-11-02|   19| electricite|               460.9|  kWh|           0.323|            0.065|
# |      ecole|    BAT0075| Ecole Strasbourg 75|      2265|               207|Strasbourg|              1981|                 G|2023-11-02|   16| electricite|              889.98|  kWh|           0.393|            0.065|
# |      ecole|    BAT0124|  Ecole Le Havre 124|       927|               226|  Le Havre|              1975|                 G|2023-01-09|    7|         gaz|              269.27|  kWh|            0.29|            0.065|
# |      ecole|    BAT0108|     Ecole Reims 108|      1970|               220|     Reims|              1984|                 F|2023-03-16|   10|         gaz|              420.16|  kWh|           0.213|            0.065|
# |      ecole|    BAT0017|       Ecole Lyon 17|      1738|               116|      Lyon|              1990|                 E|2024-12-16|   13| electricite|              347.24|  kWh|             0.2|            0.065|
# |    piscine|    BAT0050|    Piscine Lille 50|      3471|               209|     Lille|              2001|                 F|2023-12-20|    7|         gaz|             3201.91|  kWh|           0.922|            0.292|
# |     mairie|    BAT0088|      Mairie Nice 88|      1045|                75|      Nice|              1958|                 G|2024-07-26|    6|         gaz|              128.66|  kWh|           0.123|            0.029|
# |     mairie|    BAT0073|Mairie Strasbourg 73|      1417|                24|Strasbourg|              1997|                 E|2023-03-06|    7|         gaz|              128.59|  kWh|           0.091|            0.029|
# |     mairie|    BAT0103|   Mairie Rennes 103|       548|                78|    Rennes|              1967|                 G|2023-03-17|   12|         gaz|                73.9|  kWh|           0.135|            0.029|
# |      ecole|    BAT0028|  Ecole Marseille 28|      1878|               356| Marseille|              1972|                 F|2024-01-29|   10| electricite|              542.21|  kWh|           0.289|            0.065|
# |mediatheque|    BAT0141|Mediatheque Toulo...|       891|                40|    Toulon|              1980|                 G|2023-05-17|   16|         gaz|              290.65|  kWh|           0.326|            0.106|
# |     mairie|    BAT0102|   Mairie Rennes 102|       660|                86|    Rennes|              2009|                 C|2024-12-06|   13|         gaz|               98.67|  kWh|            0.15|            0.029|
# |     mairie|    BAT0074|Mairie Strasbourg 74|      1180|                36|Strasbourg|              1955|                 F|2024-05-27|    6|         gaz|              141.34|  kWh|            0.12|            0.029|
# |     mairie|    BAT0074|Mairie Strasbourg 74|      1180|                36|Strasbourg|              1955|                 F|2023-08-07|   10|         gaz|              202.49|  kWh|           0.172|            0.029|
# +-----------+-----------+--------------------+----------+------------------+----------+------------------+------------------+----------+-----+------------+--------------------+-----+----------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ---

# %% [markdown]
# ## Calculer les totaux par commune et par type de batiment

# %%
df_totaux = (
    df
    .groupBy("commune", "type", "type_energie", "unite")
    .agg(
        F.round(F.sum("consommation_moyenne"), 3).alias("consommation_totale"),
        F.countDistinct("batiment_id").alias("nb_batiments")
    )
).select(
    "commune",
    "type",
    "nb_batiments",
    "type_energie",
    "consommation_totale",
    "unite"
)

print("- Apperçu des totaux par commune et type de bâtiment :")
df_totaux.show()
print(f"(Nombre total de lignes : {df_totaux.count()})")
# Out:
# - Apperçu des totaux par commune et type de bâtiment :
# +-------------+-----------+------------+------------+-------------------+-----+
# |      commune|       type|nb_batiments|type_energie|consommation_totale|unite|
# +-------------+-----------+------------+------------+-------------------+-----+
# |       Nantes|     mairie|           4| electricite|             602.88|  kWh|
# |        Reims|      ecole|           1|         gaz|            1123.17|  kWh|
# |         Lyon|      ecole|           4| electricite|            2540.14|  kWh|
# |       Nantes|     mairie|           3|         gaz|             737.64|  kWh|
# |         Lyon|      ecole|           4|         gaz|            1907.55|  kWh|
# |        Lille|    piscine|           3|         eau|            1822.75|   m3|
# |     Le Havre|      ecole|           2| electricite|             583.75|  kWh|
# |       Toulon|    piscine|           6|         eau|            2144.23|   m3|
# |         Nice|     mairie|           2|         gaz|             211.25|  kWh|
# |   Strasbourg|    gymnase|           3|         gaz|            3045.75|  kWh|
# |  Montpellier|    piscine|           1|         gaz|             2355.6|  kWh|
# |        Reims|      ecole|           1|         eau|              40.44|   m3|
# |Saint-Etienne|mediatheque|           1| electricite|             163.78|  kWh|
# |     Le Havre|    gymnase|           1| electricite|             530.21|  kWh|
# |     Bordeaux|    gymnase|           1| electricite|             591.84|  kWh|
# |        Paris|mediatheque|           1| electricite|              72.23|  kWh|
# |  Montpellier|    gymnase|           2|         gaz|            1568.67|  kWh|
# |Saint-Etienne|    piscine|           2|         gaz|            5468.66|  kWh|
# |         Nice|    piscine|           2|         gaz|             4131.8|  kWh|
# |     Le Havre|    piscine|           4| electricite|            9974.18|  kWh|
# +-------------+-----------+------------+------------+-------------------+-----+
# only showing top 20 rows
# (Nombre total de lignes : 193)

# %% [markdown]
# ---

# %% [markdown]
# ## Creer une vue SQL exploitable

# %%
# Création d’une vue SQL permettant l’exploration des consommations agrégées par commune et type de bâtiment.
df_totaux.createOrReplaceTempView("vw_totaux_commune_type")

# démo :
spark.sql("""
SELECT *
FROM vw_totaux_commune_type
ORDER BY consommation_totale DESC
LIMIT 10;
""").show(truncate=False)
# Out:
# +-------------+-------+------------+------------+-------------------+-----+
# |commune      |type   |nb_batiments|type_energie|consommation_totale|unite|
# +-------------+-------+------------+------------+-------------------+-----+
# |Toulon       |piscine|6           |gaz         |15555.22           |kWh  |
# |Toulon       |piscine|6           |electricite |14789.04           |kWh  |
# |Lille        |piscine|3           |gaz         |11984.68           |kWh  |
# |Le Havre     |piscine|4           |electricite |9974.18            |kWh  |
# |Le Havre     |piscine|4           |gaz         |9792.95            |kWh  |
# |Bordeaux     |piscine|1           |gaz         |8305.15            |kWh  |
# |Paris        |piscine|1           |gaz         |6228.5             |kWh  |
# |Saint-Etienne|piscine|2           |gaz         |5468.66            |kWh  |
# |Lyon         |gymnase|3           |gaz         |4254.1             |kWh  |
# |Nice         |piscine|2           |gaz         |4131.8             |kWh  |
# +-------------+-------+------------+------------+-------------------+-----+

# %% [markdown]
# ---

# %% [markdown]
# ## Table agregee consommations_agregees.parquet

# %%
df_totaux.coalesce(1).write.mode("overwrite").parquet(OUT_CONSO_AGG_PARQUET)
print(f"[ok]: Creation avec succès de la table agregee consommations_agregees.parquet : {OUT_CONSO_AGG_PARQUET}")
# Out:
# [ok]: Creation avec succès de la table agregee consommations_agregees.parquet : C:\Users\joel\Downloads\ecf_energie\output\03_consommations_agregees.parquet

# %% [markdown]
# ---

# %%
# --- Enregistrement du temps d'execution de ce script
temps_execution_03 = time.time() - start_time_03

# %% [markdown]
# ---

# %% [markdown]
# ## Fermer la session Spark

# %%
spark.stop()

# %% [markdown]
# ---

# %% [markdown]
# ## Optionel : enregistrement dans un fichier temporaire du temps d'execution + ressources pour utilisation ultérieure (dans le script run_pipeline_hybride.py ou autres)

# %%
temps_resources = f"""
    Date : {datetime.now().strftime("%d/%m/%Y %H:%M:%S")} (FR)

    temps_exec_sec={temps_execution_03:.2f}
    ram_gb={ram_available_03:.2f}
    cpu_pct={cpu_available_pct_03:.2f}
    logi_cores={available_logical_03:.1f}
    physi_cores={available_physical_03:.1f}
"""

# Ecrire des données du temps d'execution + ressources dans le fichier TMP_FILE_TXT
TMP_FILE_TXT.write_text(temps_resources, encoding="utf-8")
# Out:
# 137
