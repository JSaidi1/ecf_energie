# %% [markdown]
# # Etape 1.3 : Agregations avancees Spark
#
# ---
# ---

# %% [markdown]
# ## Imports

# %%
import sys
import os
from pathlib import Path
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ## Chemin des données

# %%
DATA_DIR = (Path.cwd() / ".." / "data").resolve()
OUTPUT_DIR = os.path.join(DATA_DIR, "output")
CONSOMMATION_PARQUET_DIR = os.path.join(OUTPUT_DIR, "consommations_clean")
BATIMENTS_PATH = os.path.join(DATA_DIR, "batiments.csv")
CONSO_AGREGEES_PARKET = os.path.join(OUTPUT_DIR, "consommations_agregees.parquet")

# %% [markdown]
# ---

# %% [markdown]
# ## Chargement des données

# %%
## Chargement des données batiments 
df_batiments = pd.read_csv(BATIMENTS_PATH)

## Affichage de quelques infos
print(f"- Shape: {df_batiments.shape}")
print(f"- Colonnes: {df_batiments.columns.tolist()}")
print()
# Info sur les types
print("- Infos sur les types : ")
df_batiments.info()
print()
## Appercu des donnees
print("- Appercu des donnees : ")
df_batiments.head(10)
# Out:
# - Shape: (146, 8)
# - Colonnes: ['batiment_id', 'nom', 'type', 'commune', 'surface_m2', 'annee_construction', 'classe_energetique', 'nb_occupants_moyen']
#
# - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   batiment_id         146 non-null    str
#  1   nom                 146 non-null    str
#  2   type                146 non-null    str
#  3   commune             146 non-null    str
#  4   surface_m2          146 non-null    int64
#  5   annee_construction  146 non-null    int64
#  6   classe_energetique  146 non-null    str
#  7   nb_occupants_moyen  146 non-null    int64
# dtypes: int64(3), str(5)
# memory usage: 15.1 KB
#
# - Appercu des donnees :
#   batiment_id                  nom         type commune  surface_m2  \
# 0     BAT0001        Ecole Paris 1        ecole   Paris        1926
# ...

# %%
## Chargement des données consommations à partir du parket (consommations_clean)
df_consommations = pd.read_parquet(CONSOMMATION_PARQUET_DIR)

## Affichage de quelques infos
print(f"- Shape: {df_consommations.shape}")
print(f"- Colonnes: {df_consommations.columns.tolist()}")
print()
# Info sur les types
print("- Infos sur les types : ")
df_consommations.info()
print()
## Appercu des donnees
print("- Appercu des donnees : ")
df_consommations.head(10)
# Out:
# - Shape: (320178, 14)
# - Colonnes: ['batiment_id', 'unite', 'year', 'month', 'timestamp_start', 'consommation_mean', 'consommation_min', 'consommation_max', 'measurement_count', 'nom', 'commune', 'type', 'date', 'type_energie']
#
# - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 320178 entries, 0 to 320177
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   batiment_id        320178 non-null  str
#  1   unite              320178 non-null  str
#  2   year               320178 non-null  int32
#  3   month              320178 non-null  int32
#  4   timestamp_start    320178 non-null  datetime64[ns]
#  5   consommation_mean  320178 non-null  float64
#  6   consommation_min   320178 non-null  float64
#  7   consommation_max   320178 non-null  float64
#  8   measurement_count  320178 non-null  int64
#  9   nom                320178 non-null  str
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Joindre consommations avec referentiel batiments

# %%
## jointure de df_consommations avec df_batiments
df_consommations_batiments = df_consommations.merge(
    df_batiments,
    on="batiment_id",
    how="left"
)

## Affichage de quelques infos
print(f"- Shape: {df_consommations_batiments.shape}")
print(f"- Colonnes: {df_consommations_batiments.columns.tolist()}")
print()
# Info sur les types
print("- Infos sur les types : ")
df_consommations_batiments.info()
print()
## Appercu des donnees
print("- Appercu des donnees : ")
df_consommations_batiments.head(10)
# Out:
# - Shape: (320178, 21)
# - Colonnes: ['batiment_id', 'unite', 'year', 'month', 'timestamp_start', 'consommation_mean', 'consommation_min', 'consommation_max', 'measurement_count', 'nom_x', 'commune_x', 'type_x', 'date', 'type_energie', 'nom_y', 'type_y', 'commune_y', 'surface_m2', 'annee_construction', 'classe_energetique', 'nb_occupants_moyen']
#
# - Infos sur les types :
# <class 'pandas.DataFrame'>
# RangeIndex: 320178 entries, 0 to 320177
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   batiment_id         320178 non-null  str
#  1   unite               320178 non-null  str
#  2   year                320178 non-null  int32
#  3   month               320178 non-null  int32
#  4   timestamp_start     320178 non-null  datetime64[ns]
#  5   consommation_mean   320178 non-null  float64
#  6   consommation_min    320178 non-null  float64
#  7   consommation_max    320178 non-null  float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Calculer l'intensite energetique (kWh/m2)

# %%
## Filtrer l’électricité
df_elec = df_consommations_batiments[df_consommations_batiments["type_energie"] == "electricite"].copy()
# df_elec.head()

## Calcul de l’intensité énergétique (kWh/m²)
df_elec["intensite_energetique_kwh_m2"] = (
    df_elec["consommation_mean"] / df_elec["surface_m2"]
).round(3)

df_elec.head()
# Out:
#     batiment_id unite  year  month timestamp_start  consommation_mean  \
# 146     BAT0004   kWh  2023      1      2023-01-01              73.15
# 147     BAT0001   kWh  2023      1      2023-01-01              53.21
# 148     BAT0134   kWh  2023      1      2023-01-01            1183.26
# 149     BAT0129   kWh  2023      1      2023-01-01               9.73
# 150     BAT0034   kWh  2023      1      2023-01-01              69.08
#
#      consommation_min  consommation_max  measurement_count  \
# 146              6.48            147.05                 24
# 147              5.70            105.18                 24
# 148            112.57           2096.11                 23
# 149              1.17             18.47                 23
# 150              8.08            128.66                 23
#
#                          nom_x  ...        date type_energie  \
# 146        Mediatheque Paris 4  ...  2023-01-01  electricite
# 147              Ecole Paris 1  ...  2023-01-01  electricite
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Identifier les batiments hors norme (>3x la mediane de leur categorie)
#
# - Catégorie = type_y
# - Indicateur = intensite_energetique_kwh_m2
# - Règle = > 3 × médiane de la catégorie

# %%
df_elec_med = df_elec.merge(
    df_elec.groupby("type_y")["intensite_energetique_kwh_m2"]
    .median()
    .rename("mediane_type"),
    on="type_y"
)

df_hors_norme = df_elec_med[
    df_elec_med["intensite_energetique_kwh_m2"] > 3 * df_elec_med["mediane_type"]
]

df_hors_norme.head()
# Out:
#      batiment_id unite  year  month     timestamp_start  consommation_mean  \
# 865      BAT0124   kWh  2023      1 2023-01-06 00:00:00             214.37
# 2543     BAT0075   kWh  2023      1 2023-01-18 00:00:00             522.67
# 4552     BAT0137   kWh  2023      2 2023-02-01 01:00:00             452.39
# 5488     BAT0023   kWh  2023      2 2023-02-07 00:00:00             329.35
# 5516     BAT0137   kWh  2023      2 2023-02-07 00:00:00             450.90
#
#       consommation_min  consommation_max  measurement_count  \
# 865              18.64            397.01                 22
# 2543             53.95            914.84                 23
# 4552             41.81            821.57                 23
# 5488             26.17            583.88                 23
# 5516             53.26            832.90                 23
#
#                     nom_x  ... type_energie                nom_y type_y  \
# 865    Ecole Le Havre 124  ...  electricite   Ecole Le Havre 124  ecole
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Calculer les totaux par commune et par type de batiment

# %%
df_totaux = (
    df_elec.groupby(["commune_y", "type_y"], as_index=False)
    .agg(
        consommation_totale_kwh=("consommation_mean", "sum"),
        nb_batiments=("batiment_id", "nunique"),
        intensite_energetique_moyenne=("intensite_energetique_kwh_m2", "mean")
    )
)
df_totaux.head()
# Out:
#   commune_y       type_y  consommation_totale_kwh  nb_batiments  \
# 0  Bordeaux        ecole                190599.98             2
# 1  Bordeaux      gymnase                211594.29             1
# 2  Bordeaux       mairie                118935.88             3
# 3  Bordeaux  mediatheque                156652.33             1
# 4  Bordeaux      piscine                607683.84             1
#
#    intensite_energetique_moyenne
# 0                       0.084094
# 1                       0.155042
# 2                       0.060515
# 3                       0.127557
# 4                       0.364766

# %% [markdown]
# ---

# %% [markdown]
# ## Creer une vue SQL exploitable

# %%
import sqlite3

## Création d'une base en mémoire
conn = sqlite3.connect(":memory:")

## Chargement du DataFrame df_elec comme table SQL
df_elec.to_sql("consommations", conn, index=False, if_exists="replace")

## Exemple de requêtes SQL exploitables (Tous les bâtiments électriques)
query = """
SELECT
    batiment_id,
    nom_y,
    type_y,
    commune_y,
    intensite_energetique_kwh_m2
FROM consommations
"""

df_sql = pd.read_sql(query, conn)
df_sql.head()
# Out:
#   batiment_id                      nom_y       type_y      commune_y  \
# 0     BAT0004        Mediatheque Paris 4  mediatheque          Paris
# 1     BAT0001              Ecole Paris 1        ecole          Paris
# 2     BAT0134  Piscine Saint-Etienne 134      piscine  Saint-Etienne
# 3     BAT0129   Mairie Saint-Etienne 129       mairie  Saint-Etienne
# 4     BAT0034    Mediatheque Toulouse 34  mediatheque       Toulouse
#
#    intensite_energetique_kwh_m2
# 0                         0.081
# 1                         0.028
# 2                         0.557
# 3                         0.021
# 4                         0.091

# %% [markdown]
# ---

# %% [markdown]
# ## Table agregee consommations_agregees.parquet
#
# - Agrégation par : commune, type de bâtiment, année, énergie
# - Avec : consommation totale, intensité énergétique moyenne, nombre de bâtiments

# %%
## Création d'une table agrégée
df_agregee = (
    df_elec
    .groupby(
        ["commune_y", "type_y", "year", "type_energie"],
        as_index=False
    )
    .agg(
        consommation_totale_kwh=("consommation_mean", "sum"),
        intensite_moyenne_kwh_m2=("intensite_energetique_kwh_m2", "mean"),
        nb_batiments=("batiment_id", "nunique")
    )
)

## Renommage des colonnes
df_agregee = df_agregee.rename(columns={
    "commune_y": "commune",
    "type_y": "type_batiment"
})

## Écriture de la table en Parquet
df_agregee.to_parquet(
    CONSO_AGREGEES_PARKET,
    engine="pyarrow",
    index=False
)

# %% [markdown]
# ---

# %% [markdown]
# ## Check du parquet

# %%
df_check = pd.read_parquet(CONSO_AGREGEES_PARKET)
df_check.head()
# Out:
#     commune type_batiment  year type_energie  consommation_totale_kwh  \
# 0  Bordeaux         ecole  2023  electricite                 94778.54
# 1  Bordeaux         ecole  2024  electricite                 95821.44
# 2  Bordeaux       gymnase  2023  electricite                105423.74
# 3  Bordeaux       gymnase  2024  electricite                106170.55
# 4  Bordeaux        mairie  2023  electricite                 59120.71
#
#    intensite_moyenne_kwh_m2  nb_batiments
# 0                  0.083773             2
# 1                  0.084415             2
# 2                  0.154696             1
# 3                  0.155388             1
# 4                  0.060212             3
