# %% [markdown]
# # Etape 1.3 : Agregations avancees Spark
#
# **Livrables** :
# - Ce notebook `03_agregations_spark.ipynb`
# - Table agregee `03_consommations_agregees.parquet`
# - Requetes Spark SQL demonstrant l'utilisation de la vue
#
# ---
# ---

# %% [markdown]
# ## Imports

# %%
import sys
import os
import platform
from pathlib import Path
import time
from datetime import datetime
import psutil
from pyspark.sql import SparkSession, functions as F, Window

# %% [markdown]
# ---

# %% [markdown]
# ## Mesure du temps de traitement global pour ce script - enregistrement de l'heure de début + estimation instantanée des ressources machine libres

# %%
## Heure de début
start_time_03 = time.time()

## Machine: current available RAM (in GB)
ram_available_03 = psutil.virtual_memory().available / (1024**3)

## Machine: current available CPU
logical = psutil.cpu_count()
physical = psutil.cpu_count(logical=False) or logical

cpu_used = psutil.cpu_percent(interval=2)
cpu_available_pct_03 = 100 - cpu_used

available_logical_03 = logical * cpu_available_pct_03 / 100
available_physical_03 = physical * cpu_available_pct_03 / 100

## Show available resources
print(f"- Current machine RAM available : {ram_available_03:.2f} GB")
print(f"- Current machine CPU available : {cpu_available_pct_03:.1f}%")
print(f"    Approx logical cores free  : {available_logical_03:.2f}")
print(f"    Approx physical cores free : {available_physical_03:.2f}")
# Out:
# - Current machine RAM available : 12.31 GB
# - Current machine CPU available : 86.7%
#     Approx logical cores free  : 13.87
#     Approx physical cores free : 6.94

# %% [markdown]
# ---

# %% [markdown]
# ## Chemins des données

# %%
# ==============================================================================================================
#                                                    DIRS
# ==============================================================================================================
DATA_DIR_PATH = (Path.cwd() / ".." / "data").resolve()
OUTPUT_DIR_PATH = (Path.cwd() / ".." / "output").resolve()
TMP_DIR_PATH = (Path.cwd() / ".." / "my_tmp").resolve()

# ==============================================================================================================
#                                                   INPUTS
# ==============================================================================================================
IN_BAT_PATH = os.path.join(DATA_DIR_PATH, "batiments.csv")
IN_CONSO_CLEAN_PATH = os.path.join(OUTPUT_DIR_PATH, "02_consommations_clean") # parquet partitionné

# ==============================================================================================================
#                                                   OUTPUTS
# ==============================================================================================================
OUT_AGG_PARQUET =  os.path.join(OUTPUT_DIR_PATH, "03_consommations_agregees.parquet")

# ==============================================================================================================
#                                                    OTHERS
# ==============================================================================================================
TMP_FILE_PATH = TMP_DIR_PATH / "tmp_03_resources.txt" # Enregistrer les metrics pour ce script

# %% [markdown]
# ---

# %% [markdown]
# ## Création d'une session Spark locale

# %%
# --- Creer une session Spark locale
spark = SparkSession.builder \
    .appName("ECF 2 - ENERGIE - Etape 1.3 : Agregations avancees Spark") \
    .master("local[*]") \
    .config("spark.driver.memory", "4g") \
    .config("spark.sql.shuffle.partitions", "8") \
    .getOrCreate()

# Reduire les logs
spark.sparkContext.setLogLevel("WARN")

# Affichage de l'actuelle version de Spark & de l'url de Spark UI ainsi que python & java
print(f"Spark version  : {spark.version}")
print(f"Spark UI       : {spark.sparkContext.uiWebUrl}")
print()
print(f"Hadoop version : {spark._jvm.org.apache.hadoop.util.VersionInfo.getVersion()}")
print(f"Hadoop home    : {spark._jvm.java.lang.System.getenv('HADOOP_HOME')}")
print()
print(f"Python version : {platform.python_version()}")
print(f"Python path    : { sys.executable}")
print()
print(f"Java version   : {spark._jvm.java.lang.System.getProperty('java.version')}")
print(f"Java home      : { spark._jvm.java.lang.System.getProperty('java.home')}")

# Check du module winutils.exe
print()
if os.path.exists(os.path.join(os.environ["HADOOP_HOME"], "bin", "winutils.exe")):
        print("[ok]: Hadoop module 'winutils.exe' exists at path:", os.path.join(os.environ["HADOOP_HOME"], "bin", "winutils.exe"))
else:
        print("[ko]: Required hadoop module 'winutils.exe' do not exists")
        sys.exit(1)
# Out:
# Spark version  : 3.5.7
# Spark UI       : http://joel:4041
#
# Hadoop version : 3.3.4
# Hadoop home    : C:\Users\joel\data-info\dev-tools\data-tools\hadoop
#
# Python version : 3.11.9
# Python path    : C:\Users\joel\Desktop\ecf_energie\.venv\Scripts\python.exe
#
# Java version   : 11.0.28
# Java home      : C:\Users\joel\data-info\dev-tools\languages\java\jdk-11
#
# [ok]: Hadoop module 'winutils.exe' exists at path: C:\Users\joel\data-info\dev-tools\data-tools\hadoop\bin\winutils.exe

# %% [markdown]
# ---

# %% [markdown]
# ## Chargement des données

# %%
# --- Chargement du référentil bâtiments
df_bat = (spark.read
          .option("header", True)
          .option("inferSchema", True)
          .csv(IN_BAT_PATH))

df_bat.printSchema()
df_bat.show(5, truncate=False)

# Information sur le nombre de lignes et de colonnes
print(f"- Nombre de lignes : {df_bat.count():,}")
print("- Nombre de colonnes :", len(df_bat.columns))
# Out:
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# |batiment_id|nom                |type       |commune|surface_m2|annee_construction|classe_energetique|nb_occupants_moyen|
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# |BAT0001    |Ecole Paris 1      |ecole      |Paris  |1926      |1978              |E                 |225               |
# |BAT0002    |Ecole Paris 2      |ecole      |Paris  |1156      |2004              |C                 |402               |
# |BAT0003    |Ecole Paris 3      |ecole      |Paris  |1695      |2014              |D                 |219               |
# |BAT0004    |Mediatheque Paris 4|mediatheque|Paris  |907       |2019              |C                 |121               |
# |BAT0005    |Piscine Paris 5    |piscine    |Paris  |3913      |1950              |G                 |242               |
# +-----------+-------------------+-----------+-------+----------+------------------+------------------+------------------+
# only showing top 5 rows
# - Nombre de lignes : 146
# - Nombre de colonnes : 8

# %%
# --- Chargement des données de consommation clean (à partir du parquet consommations_clean)
df_conso = spark.read.parquet(IN_CONSO_CLEAN_PATH)

# Information sur le schema, nombre de lignes et de colonnes
df_conso.printSchema()
df_conso.show(5, truncate=False)
print(f"- Nombre de lignes : {df_conso.count():,}")
print("- Nombre de colonnes :", len(df_conso.columns))
# Out:
# root
#  |-- batiment_id: string (nullable = true)
#  |-- heure: integer (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- type_energie: string (nullable = true)
# +-----------+-----+--------------------+-----+----------+------------+
# |batiment_id|heure|consommation_moyenne|unite|date      |type_energie|
# +-----------+-----+--------------------+-----+----------+------------+
# |BAT0097    |21   |250.98              |kWh  |2024-09-17|gaz         |
# |BAT0106    |21   |178.72              |kWh  |2024-09-17|gaz         |
# |BAT0141    |21   |199.88              |kWh  |2024-09-17|gaz         |
# |BAT0081    |0    |30.93               |kWh  |2023-11-12|gaz         |
# |BAT0081    |10   |60.31               |kWh  |2023-11-12|gaz         |
# +-----------+-----+--------------------+-----+----------+------------+
# only showing top 5 rows
# - Nombre de lignes : 990
# - Nombre de colonnes : 6

# %% [markdown]
# ---

# %% [markdown]
# ## Joindre consommations avec referentiel batiments

# %%
df_join = df_conso.join(df_bat, on="batiment_id", how="left").select("batiment_id", "nom", "type", "surface_m2", "nb_occupants_moyen", "commune", "annee_construction", "classe_energetique", "date", "type_energie", "consommation_moyenne", "unite")

# Information sur le schema, nombre de lignes et de colonnes
print("Infos sur df_join : ")
df_join.printSchema()
df_join.show(5, truncate=False)
print(f"- Nombre de lignes : {df_join.count():,}")
print("- Nombre de colonnes :", len(df_join.columns))

# Contrôle qualité jointure
print()
print("Contrôle qualité jointure :")
unmatched = df_join.filter(F.col("nom").isNull()).select("batiment_id").distinct().count()
if unmatched == 0:
    print("[ok]: Batiments non matchés (id inconnus) :", unmatched)
else:
    print("[ko]: Batiments non matchés (id inconnus) :", unmatched)
# Out:
# Infos sur df_join :
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- type_energie: string (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+------------+--------------------+-----+
# |batiment_id|nom                   |type       |surface_m2|nb_occupants_moyen|commune    |annee_construction|classe_energetique|date      |type_energie|consommation_moyenne|unite|
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+------------+--------------------+-----+
# |BAT0097    |Mediatheque Nice 97   |mediatheque|1186      |41                |Nice       |1980              |G                 |2024-09-17|gaz         |250.98              |kWh  |
# |BAT0106    |Mairie Rennes 106     |mairie     |1272      |77                |Rennes     |1983              |G                 |2024-09-17|gaz         |178.72              |kWh  |
# |BAT0141    |Mediatheque Toulon 141|mediatheque|891       |40                |Toulon     |1980              |G                 |2024-09-17|gaz         |199.88              |kWh  |
# |BAT0081    |Mairie Montpellier 81 |mairie     |1116      |62                |Montpellier|1985              |G                 |2023-11-12|gaz         |30.93               |kWh  |
# |BAT0081    |Mairie Montpellier 81 |mairie     |1116      |62                |Montpellier|1985              |G                 |2023-11-12|gaz         |60.31               |kWh  |
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+------------+--------------------+-----+
# only showing top 5 rows
# - Nombre de lignes : 990
# - Nombre de colonnes : 12
#
# Contrôle qualité jointure :
# [ok]: Batiments non matchés (id inconnus) : 0

# %% [markdown]
# ---

# %% [markdown]
# ## Calculer l'intensite energetique (kWh/m2)
# ``kWh/m²`` n’a du sens que pour l’électricité + gaz (pas pour l’eau en m³).
# => Donc on calcule ``intensite_kwh_m2`` uniquement sur electricite et gaz.

# %%
df_journaliere = df_join.withColumn(
    "intensite_kwh_m2",
    F.when(F.col("type_energie").isin("electricite", "gaz"),
           F.col("consommation_moyenne") / F.col("surface_m2"))
     .otherwise(F.lit(None))
)

# Information sur le schema, nombre de lignes et de colonnes
print("Infos sur df_journaliere : ")
df_journaliere.printSchema()
df_journaliere.show(5, truncate=False)
print(f"- Nombre de lignes : {df_journaliere.count():,}")
print("- Nombre de colonnes :", len(df_journaliere.columns))
# Out:
# Infos sur df_journaliere :
# root
#  |-- batiment_id: string (nullable = true)
#  |-- nom: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- surface_m2: integer (nullable = true)
#  |-- nb_occupants_moyen: integer (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- annee_construction: integer (nullable = true)
#  |-- classe_energetique: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- type_energie: string (nullable = true)
#  |-- consommation_moyenne: double (nullable = true)
#  |-- unite: string (nullable = true)
#  |-- intensite_kwh_m2: double (nullable = true)
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+------------+--------------------+-----+--------------------+
# |batiment_id|nom                   |type       |surface_m2|nb_occupants_moyen|commune    |annee_construction|classe_energetique|date      |type_energie|consommation_moyenne|unite|intensite_kwh_m2    |
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+------------+--------------------+-----+--------------------+
# |BAT0097    |Mediatheque Nice 97   |mediatheque|1186      |41                |Nice       |1980              |G                 |2024-09-17|gaz         |250.98              |kWh  |0.21161888701517706 |
# |BAT0106    |Mairie Rennes 106     |mairie     |1272      |77                |Rennes     |1983              |G                 |2024-09-17|gaz         |178.72              |kWh  |0.14050314465408806 |
# |BAT0141    |Mediatheque Toulon 141|mediatheque|891       |40                |Toulon     |1980              |G                 |2024-09-17|gaz         |199.88              |kWh  |0.22433221099887765 |
# |BAT0081    |Mairie Montpellier 81 |mairie     |1116      |62                |Montpellier|1985              |G                 |2023-11-12|gaz         |30.93               |kWh  |0.02771505376344086 |
# |BAT0081    |Mairie Montpellier 81 |mairie     |1116      |62                |Montpellier|1985              |G                 |2023-11-12|gaz         |60.31               |kWh  |0.054041218637992834|
# +-----------+----------------------+-----------+----------+------------------+-----------+------------------+------------------+----------+------------+--------------------+-----+--------------------+
# only showing top 5 rows
# - Nombre de lignes : 990
# - Nombre de colonnes : 13

# %% [markdown]
# ---

# %% [markdown]
# ## Identifier les batiments hors norme (>3x la mediane de leur categorie)
# 'Catégorie' => type de bâtiment (ecole, mairie, etc.).
# On calcule la médiane de l’intensité par type et type_energie, puis on marque hors norme.
#
# => En Spark, médiane = percentile_approx(col, 0.5) (standard).

# %%
df_med = (df_journaliere
    .filter(F.col("type_energie").isin("electricite", "gaz"))
    .groupBy("type", "type_energie")
    .agg(F.expr("percentile_approx(intensite_kwh_m2, 0.5)").alias("mediane_intensite"))
)

df_scored = (df_journaliere
    .join(df_med, on=["type", "type_energie"], how="left")
    .withColumn(
        "hors_norme",
        F.when(
            (F.col("type_energie").isin("electricite", "gaz")) &
            (F.col("intensite_kwh_m2") > 3 * F.col("mediane_intensite")),
            F.lit(True)
        ).otherwise(F.lit(False))
    )
)

# Top batiments les plus hors norme :
df_outliers = (df_scored
    .filter(F.col("hors_norme") == True)
    .select("batiment_id","nom","type","commune","date","type_energie","consommation_moyenne","surface_m2",
            "intensite_kwh_m2","mediane_intensite")
    .orderBy(F.desc("intensite_kwh_m2"))
)

df_outliers.show(20, truncate=False)
# Out:
# +-----------+------------------------+-----------+----------+----------+------------+--------------------+----------+-------------------+--------------------+
# |batiment_id|nom                     |type       |commune   |date      |type_energie|consommation_moyenne|surface_m2|intensite_kwh_m2   |mediane_intensite   |
# +-----------+------------------------+-----------+----------+----------+------------+--------------------+----------+-------------------+--------------------+
# |BAT0043    |Piscine Bordeaux 43     |piscine    |Bordeaux  |2023-12-06|gaz         |2701.95             |2279      |1.1855857832382624 |0.3341426282051282  |
# |BAT0043    |Piscine Bordeaux 43     |piscine    |Bordeaux  |2023-02-20|gaz         |2592.59             |2279      |1.137599824484423  |0.3341426282051282  |
# |BAT0005    |Piscine Paris 5         |piscine    |Paris     |2024-11-26|gaz         |4109.11             |3913      |1.050117556861743  |0.3341426282051282  |
# |BAT0048    |Piscine Lille 48        |piscine    |Lille     |2024-11-20|gaz         |3898.54             |3754      |1.0385029302077784 |0.3341426282051282  |
# |BAT0146    |Piscine Toulon 146      |piscine    |Toulon    |2024-11-20|gaz         |2700.92             |2609      |1.0352318896128785 |0.3341426282051282  |
# |BAT0122    |Piscine Le Havre 122    |piscine    |Le Havre  |2023-11-20|electricite |1305.85             |1579      |0.8270107663077897 |0.2705689102564103  |
# |BAT0123    |Gymnase Le Havre 123    |gymnase    |Le Havre  |2023-02-04|gaz         |1024.14             |1459      |0.7019465387251543 |0.20182086034177962 |
# |BAT0011    |Ecole Lyon 11           |ecole      |Lyon      |2024-12-12|gaz         |877.29              |1733      |0.5062261973456433 |0.056587196467991166|
# |BAT0076    |Gymnase Strasbourg 76   |gymnase    |Strasbourg|2024-12-14|electricite |944.81              |2146      |0.4402656104380242 |0.09023851076207097 |
# |BAT0036    |Mediatheque Toulouse 36 |mediatheque|Toulouse  |2023-08-01|gaz         |866.64              |1994      |0.4346238716148445 |0.12926325247079964 |
# |BAT0093    |Ecole Nice 93           |ecole      |Nice      |2024-12-24|gaz         |853.86              |2044      |0.4177397260273973 |0.056587196467991166|
# |BAT0097    |Mediatheque Nice 97     |mediatheque|Nice      |2023-01-14|gaz         |481.82              |1186      |0.406256323777403  |0.12926325247079964 |
# |BAT0036    |Mediatheque Toulouse 36 |mediatheque|Toulouse  |2024-01-14|gaz         |794.73              |1994      |0.3985606820461384 |0.12926325247079964 |
# |BAT0075    |Ecole Strasbourg 75     |ecole      |Strasbourg|2023-11-02|electricite |889.98              |2265      |0.3929271523178808 |0.064618138424821   |
# |BAT0106    |Mairie Rennes 106       |mairie     |Rennes    |2024-01-18|gaz         |449.38              |1272      |0.3532861635220126 |0.043952011291460834|
# |BAT0108    |Ecole Reims 108         |ecole      |Reims     |2024-01-16|gaz         |693.32              |1970      |0.3519390862944163 |0.056587196467991166|
# |BAT0076    |Gymnase Strasbourg 76   |gymnase    |Strasbourg|2023-01-04|electricite |741.08              |2146      |0.3453308480894688 |0.09023851076207097 |
# |BAT0123    |Gymnase Le Havre 123    |gymnase    |Le Havre  |2024-12-31|electricite |477.54              |1459      |0.32730637422892395|0.09023851076207097 |
# |BAT0021    |Mediatheque Marseille 21|mediatheque|Marseille |2024-07-11|electricite |427.5               |1317      |0.3246013667425968 |0.08818452380952381 |
# |BAT0023    |Ecole Marseille 23      |ecole      |Marseille |2023-11-02|electricite |460.9               |1426      |0.3232117812061711 |0.064618138424821   |
# +-----------+------------------------+-----------+----------+----------+------------+--------------------+----------+-------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ---

# %% [markdown]
# ## Calculer les totaux par commune et par type de batiment

# %%
# --- Total par commune et type de bâtiment (toutes énergies confondues) :
print("=> Total par commune et type de bâtiment (toutes énergies confondues) : ")
df_tot_commune_typebat = (
    df_join
    .groupBy("commune", "type")
    .agg(
        F.sum("consommation_moyenne").alias("consommation_totale"),
        F.countDistinct("batiment_id").alias("nb_batiments")
    )
    .orderBy("commune", "type")
)

df_tot_commune_typebat.show(truncate=False)
# Out:
# => Total par commune et type de bâtiment (toutes énergies confondues) :
# +---------+-----------+-------------------+------------+
# |commune  |type       |consommation_totale|nb_batiments|
# +---------+-----------+-------------------+------------+
# |Bordeaux |ecole      |2009.9899999999998 |2           |
# |Bordeaux |gymnase    |1651.39            |1           |
# |Bordeaux |mairie     |1063.49            |3           |
# |Bordeaux |mediatheque|1090.79            |1           |
# |Bordeaux |piscine    |9931.619999999999  |1           |
# |Le Havre |ecole      |1081.1600000000003 |2           |
# |Le Havre |gymnase    |2114.16            |1           |
# |Le Havre |mairie     |632.0199999999999  |2           |
# |Le Havre |mediatheque|468.88999999999993 |1           |
# |Le Havre |piscine    |22506.67           |5           |
# |Lille    |gymnase    |1044.39            |1           |
# |Lille    |mairie     |294.80999999999995 |1           |
# |Lille    |mediatheque|919.1700000000001  |3           |
# |Lille    |piscine    |17489.23           |3           |
# |Lyon     |ecole      |4538.22            |4           |
# |Lyon     |gymnase    |5888.240000000001  |3           |
# |Lyon     |mairie     |415.9599999999999  |3           |
# |Lyon     |mediatheque|310.82000000000005 |1           |
# |Lyon     |piscine    |4351.24            |1           |
# |Marseille|ecole      |2800.71            |4           |
# +---------+-----------+-------------------+------------+
# only showing top 20 rows

# %%
# --- Total par commune et type de bâtiment (pour chaque type d'énergies) :
print("=> Total par commune et type de bâtiment (pour chaque type d'énergies) : ")
df_tot_commune_typebat_energie = (
    df_join
    .groupBy("commune", "type", "type_energie")
    .agg(
        F.sum("consommation_moyenne").alias("consommation_totale"),
        F.countDistinct("batiment_id").alias("nb_batiments"),
        F.first("unite").alias("unite")
    )
    .select(
        "commune", "type", "type_energie", "consommation_totale", "unite"
    )
)

df_tot_commune_typebat_energie.show(truncate=False)
# Out:
# => Total par commune et type de bâtiment (pour chaque type d'énergies) :
# +--------+-----------+------------+-------------------+-----+
# |commune |type       |type_energie|consommation_totale|unite|
# +--------+-----------+------------+-------------------+-----+
# |Bordeaux|ecole      |eau         |10.98              |m3   |
# |Bordeaux|ecole      |electricite |962.72             |kWh  |
# |Bordeaux|ecole      |gaz         |1036.29            |kWh  |
# |Bordeaux|gymnase    |eau         |151.29             |m3   |
# |Bordeaux|gymnase    |electricite |591.8399999999999  |kWh  |
# |Bordeaux|gymnase    |gaz         |908.26             |kWh  |
# |Bordeaux|mairie     |eau         |12.84              |m3   |
# |Bordeaux|mairie     |electricite |647.76             |kWh  |
# |Bordeaux|mairie     |gaz         |402.89             |kWh  |
# |Bordeaux|mediatheque|eau         |15.12              |m3   |
# |Bordeaux|mediatheque|electricite |851.17             |kWh  |
# |Bordeaux|mediatheque|gaz         |224.5              |kWh  |
# |Bordeaux|piscine    |eau         |559.97             |m3   |
# |Bordeaux|piscine    |electricite |1066.5             |kWh  |
# |Bordeaux|piscine    |gaz         |8305.15            |kWh  |
# |Le Havre|ecole      |eau         |41.959999999999994 |m3   |
# |Le Havre|ecole      |electricite |583.75             |kWh  |
# |Le Havre|ecole      |gaz         |455.45             |kWh  |
# |Le Havre|gymnase    |electricite |530.21             |kWh  |
# |Le Havre|gymnase    |gaz         |1583.95            |kWh  |
# +--------+-----------+------------+-------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ---

# %% [markdown]
# ## Creer une vue SQL exploitable

# %%
# Création d’une vue SQL permettant l’exploration des consommations agrégées par commune et type de bâtiment.
df_tot_commune_typebat.createOrReplaceTempView("vw_totaux_commune_type")

# démo :
spark.sql("""
SELECT *
FROM vw_totaux_commune_type
ORDER BY consommation_totale DESC
LIMIT 10;
""").show(truncate=False)
# Out:
# +-------------+-------+-------------------+------------+
# |commune      |type   |consommation_totale|nb_batiments|
# +-------------+-------+-------------------+------------+
# |Toulon       |piscine|32488.489999999998 |6           |
# |Le Havre     |piscine|22506.67           |5           |
# |Lille        |piscine|17489.23           |3           |
# |Saint-Etienne|piscine|10113.54           |2           |
# |Bordeaux     |piscine|9931.619999999999  |1           |
# |Paris        |piscine|9632.15            |1           |
# |Nice         |piscine|7316.7699999999995 |3           |
# |Lyon         |gymnase|5888.240000000001  |3           |
# |Rennes       |piscine|5717.59            |2           |
# |Saint-Etienne|gymnase|5693.600000000001  |4           |
# +-------------+-------+-------------------+------------+

# %%
# Création d’une autre vue SQL permettant l’exploration des consommations agrégées par commune et type de bâtiment (par type d'energie).
df_tot_commune_typebat_energie.createOrReplaceTempView("vw_totaux_commune_type_energie")

# démo :
spark.sql("""
SELECT *
FROM vw_totaux_commune_type_energie
ORDER BY consommation_totale DESC
LIMIT 10;
""").show(truncate=False)
# Out:
# +-------------+-------+------------+-------------------+-----+
# |commune      |type   |type_energie|consommation_totale|unite|
# +-------------+-------+------------+-------------------+-----+
# |Toulon       |piscine|gaz         |15555.220000000001 |kWh  |
# |Toulon       |piscine|electricite |14789.039999999999 |kWh  |
# |Lille        |piscine|gaz         |11984.679999999998 |kWh  |
# |Le Havre     |piscine|electricite |9974.179999999998  |kWh  |
# |Le Havre     |piscine|gaz         |9792.949999999999  |kWh  |
# |Bordeaux     |piscine|gaz         |8305.15            |kWh  |
# |Paris        |piscine|gaz         |6228.5             |kWh  |
# |Saint-Etienne|piscine|gaz         |5468.66            |kWh  |
# |Lyon         |gymnase|gaz         |4254.1             |kWh  |
# |Nice         |piscine|gaz         |4131.8             |kWh  |
# +-------------+-------+------------+-------------------+-----+

# %% [markdown]
# ---

# %% [markdown]
# ## Table agregee consommations_agregees.parquet

# %%
df_tot_commune_typebat_energie.coalesce(1).write.mode("overwrite").parquet(OUT_AGG_PARQUET)
#df_tot_commune_typebat_energie.write.mode("overwrite").parquet(OUT_AGG_PARQUET)
print(f"[ok]: Creation avec succès de la table agregee consommations_agregees.parquet : {OUT_AGG_PARQUET}")
# Out:
# [ok]: Creation avec succès de la table agregee consommations_agregees.parquet : C:\Users\joel\Desktop\ecf_energie\output\03_consommations_agregees.parquet

# %% [markdown]
# ---

# %%
# --- Enregistrement du temps d'execution de ce script
temps_execution_03 = time.time() - start_time_03

# %% [markdown]
# ---

# %% [markdown]
# ## Fermer la session Spark

# %%
spark.stop()

# %% [markdown]
# ---

# %% [markdown]
# ## Optionel : enregistrement dans un fichier temporaire du temps d'execution + ressources pour utilisation ultérieure (dans le script run_pipeline_hybride.py ou autres)

# %%
temps_resources = f"""
    Date : {datetime.now().strftime("%d/%m/%Y %H:%M:%S")} (FR)

    temps_exec_sec={temps_execution_03:.2f}
    ram_gb={ram_available_03:.2f}
    cpu_pct={cpu_available_pct_03:.2f}
    logi_cores={available_logical_03:.1f}
    physi_cores={available_physical_03:.1f}
"""

# Ecrire des données du temps d'execution + ressources dans le fichier TMP_FILE_PATH
TMP_FILE_PATH.write_text(temps_resources, encoding="utf-8")
# Out:
# 138
